# %% [markdown]
# # Profiling
#
# This notebook goes over the problems that we found while exploring the sample dataset (i.e. the sample dataset with ~5 million rows). We broke down the problems that we found into the following sections: **Uniformity, Accuracy, Inconsistency, Completeness, and Outlier**. Each section will contain cells that can be run to explore the dataset and observe the problems that we found.

# %% [markdown]
# ## Mount Google Drive & Create Dataset Folder
#
# ****NOTE: THIS IS FOR GOOGLE COLAB!**
# (If you are not running on colab, you should manually create the directories, upload the dataset, and set the **WORKING_DIRECTORY** and **datafile** paths)
#
# Before we start exploring the dataset, we need to mount our Google Drive to this notebook. Run the following cells to mount Google Drive, create directories leading to the dataset, and define the path to dataset.

# %%
# Mount Google Drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Create evq_311_service_proj and evq_311_service_proj/dataset folders
import os

WORKING_DIRECTORY = "/content/drive/MyDrive/evq_311_service_proj"

# Create path if the path does not already exist
if not os.path.exists(WORKING_DIRECTORY):
  os.chdir('/content/drive/MyDrive/')
  os.mkdir('evq_311_service_proj')
  os.chdir('evq_311_service_proj')
  os.mkdir('dataset')
  

os.chdir(WORKING_DIRECTORY)  # Change directory to WORKING_DIRECTORY
os.getcwd()     # Display current working directory
                # (Note: this should display WORKING_DIRECTORY)
# Out:
# '/content/drive/MyDrive/evq_311_service_proj'

# %%
# Define dataset path (NOTE: replace "erm2-nwe9_5M.csv.gz" with your dataset name)
datafile = "./dataset/erm2-nwe9_5M.csv.gz"

# %% [markdown]
# By the end of this section, the current directory should be the **WORKING_DIRECTORY** path and the **datafile** path should be set. The final thing left to do is to **upload the dataset** into the folder that is expected by the **datafile** path, if this has not already been done so.

# %% [markdown]
# ## Set Up pyspark
#
# Now that the dataset path is set up and the dataset is uploaded, we need to set up pyspark to begin profiling and exploring our dataset.
#
# Run through the following cells to set up pyspark.

# %%
# Run this cell if pyspark is not already installed
# %pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.2.0.tar.gz (281.3 MB)
#      |████████████████████████████████| 281.3 MB 37 kB/s
# Collecting py4j==0.10.9.2
#   Downloading py4j-0.10.9.2-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 11.6 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.2.0-py2.py3-none-any.whl size=281805912 sha256=35981a8bbe6861ea30c0658186038a76e78090b2261799c3f8e622ee3ee9b16b
#   Stored in directory: /root/.cache/pip/wheels/0b/de/d2/9be5d59d7331c6c2a7c1b6d1a4f463ce107332b1ecd4e80718
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.2 pyspark-3.2.0

# %%
# Set up pyspark session
from pyspark.sql import SparkSession

spark = SparkSession \
            .builder \
            .appName("Python Spark SQL basic example") \
            .config("spark.some.config.option", "some-value") \
            .config("spark.executor.memory", "20g") \
            .config("spark.driver.memory", "20g") \
            .getOrCreate()

df = spark.read.csv(datafile, header=True)

# %% [markdown]
# ****WARNING:** If you run into a java heap memory, configure the following lines in the cell above:
#
#
# *  .config("spark.executor.memory", "30g") \
# *  .config("spark.driver.memory", "30g") \
#
# Change the number infront of the g (ex:20g)
#
# Changing this number could also change the amount of RAM needed to download the final file

# %% [markdown]
# Run the following cell to check that pyspark is set up properly (you should be able to view the schema of the dataset that you loaded).

# %%
# Run this code to see the schema of the loaded dataset 
df.printSchema()
# Out:
# root
#  |-- Unique Key: string (nullable = true)
#  |-- Created Date: string (nullable = true)
#  |-- Closed Date: string (nullable = true)
#  |-- Agency: string (nullable = true)
#  |-- Agency Name: string (nullable = true)
#  |-- Complaint Type: string (nullable = true)
#  |-- Descriptor: string (nullable = true)
#  |-- Location Type: string (nullable = true)
#  |-- Incident Zip: string (nullable = true)
#  |-- Incident Address: string (nullable = true)
#  |-- Street Name: string (nullable = true)
#  |-- Cross Street 1: string (nullable = true)
#  |-- Cross Street 2: string (nullable = true)
#  |-- Intersection Street 1: string (nullable = true)
#  |-- Intersection Street 2: string (nullable = true)
#  |-- Address Type: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Landmark: string (nullable = true)
#  |-- Facility Type: string (nullable = true)
#  |-- Status: string (nullable = true)
#  |-- Due Date: string (nullable = true)
#  |-- Resolution Description: string (nullable = true)
#  |-- Resolution Action Updated Date: string (nullable = true)
#  |-- Community Board: string (nullable = true)
#  |-- BBL: string (nullable = true)
#  |-- Borough: string (nullable = true)
#  |-- X Coordinate (State Plane): string (nullable = true)
#  |-- Y Coordinate (State Plane): string (nullable = true)
#  |-- Open Data Channel Type: string (nullable = true)
#  |-- Park Facility Name: string (nullable = true)
#  |-- Park Borough: string (nullable = true)
#  |-- Vehicle Type: string (nullable = true)
#  |-- Taxi Company Borough: string (nullable = true)
#  |-- Taxi Pick Up Location: string (nullable = true)
#  |-- Bridge Highway Name: string (nullable = true)
#  |-- Bridge Highway Direction: string (nullable = true)
#  |-- Road Ramp: string (nullable = true)
#  |-- Bridge Highway Segment: string (nullable = true)
#  |-- Latitude: string (nullable = true)
#  |-- Longitude: string (nullable = true)
#  |-- Location: string (nullable = true)

# %% [markdown]
# Notice in the result of running the above cell that every item in the schema is of type string, even if it is not the expected type. To modify the dataset such that the types of each column is what we would expect, we perform type casting for each column that should not be type string.
#
# Run the following cell to complete the type casting and view the updated schema.

# %%
from pyspark.sql.types import IntegerType, DoubleType
from pyspark.sql.functions import to_timestamp

# Type casting to expected types
df = df.withColumn("Unique Key",df["Unique Key"].cast(IntegerType()))
df = df.withColumn("Due Date",to_timestamp(df["Due Date"],"MM/dd/yyyy hh:mm:ss a"))
df = df.withColumn("Created Date", to_timestamp(df["Created Date"],"MM/dd/yyyy hh:mm:ss a"))
df = df.withColumn("Closed Date",to_timestamp(df["Closed Date"],"MM/dd/yyyy hh:mm:ss a"))
df = df.withColumn("Incident Zip",df["Incident Zip"].cast(IntegerType()))
df = df.withColumn("BBL",df["BBL"].cast(IntegerType()))
df = df.withColumn("X Coordinate (State Plane)",df["X Coordinate (State Plane)"].cast(IntegerType()))
df = df.withColumn("Y Coordinate (State Plane)",df["Y Coordinate (State Plane)"].cast(IntegerType()))
df = df.withColumn("Latitude",df["Latitude"].cast(DoubleType()))
df = df.withColumn("Longitude",df["Longitude"].cast(DoubleType()))
df = df.withColumn("Resolution Action Updated Date",to_timestamp(df["Resolution Action Updated Date"],"MM/dd/yyyy hh:mm:ss a"))

df.printSchema()
# Out:
# root
#  |-- Unique Key: integer (nullable = true)
#  |-- Created Date: timestamp (nullable = true)
#  |-- Closed Date: timestamp (nullable = true)
#  |-- Agency: string (nullable = true)
#  |-- Agency Name: string (nullable = true)
#  |-- Complaint Type: string (nullable = true)
#  |-- Descriptor: string (nullable = true)
#  |-- Location Type: string (nullable = true)
#  |-- Incident Zip: integer (nullable = true)
#  |-- Incident Address: string (nullable = true)
#  |-- Street Name: string (nullable = true)
#  |-- Cross Street 1: string (nullable = true)
#  |-- Cross Street 2: string (nullable = true)
#  |-- Intersection Street 1: string (nullable = true)
#  |-- Intersection Street 2: string (nullable = true)
#  |-- Address Type: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Landmark: string (nullable = true)
#  |-- Facility Type: string (nullable = true)
#  |-- Status: string (nullable = true)
#  |-- Due Date: timestamp (nullable = true)
#  |-- Resolution Description: string (nullable = true)
#  |-- Resolution Action Updated Date: timestamp (nullable = true)
#  |-- Community Board: string (nullable = true)
#  |-- BBL: integer (nullable = true)
#  |-- Borough: string (nullable = true)
#  |-- X Coordinate (State Plane): integer (nullable = true)
#  |-- Y Coordinate (State Plane): integer (nullable = true)
#  |-- Open Data Channel Type: string (nullable = true)
#  |-- Park Facility Name: string (nullable = true)
#  |-- Park Borough: string (nullable = true)
#  |-- Vehicle Type: string (nullable = true)
#  |-- Taxi Company Borough: string (nullable = true)
#  |-- Taxi Pick Up Location: string (nullable = true)
#  |-- Bridge Highway Name: string (nullable = true)
#  |-- Bridge Highway Direction: string (nullable = true)
#  |-- Road Ramp: string (nullable = true)
#  |-- Bridge Highway Segment: string (nullable = true)
#  |-- Latitude: double (nullable = true)
#  |-- Longitude: double (nullable = true)
#  |-- Location: string (nullable = true)

# %% [markdown]
# Now that pyspark is set up and the columns of the dataset are updated to types that we expect, we can start using pyspark to explore the dataset!

# %% [markdown]
# ## I. Uniformity
#
# We describe uniform data as data that use the same format and unit of measure. As we explored our dataset, we found five columns with values that have non-uniform casing (i.e. some values are fully uppercased, some are fully lowercased, and some only have the first letter of each word uppercased).
#
# Run through the following cells to observe the problem in the five columns.

# %% [markdown]
# "Complaint Type" column has values that have nonuniform casing (ex: one row is "Traffic Signal Condition" while another row is "SAFETY").

# %%
# View column "Complaint Type" 
df.select("Complaint Type").distinct().collect()
# Out:
# [Row(Complaint Type='Traffic Signal Condition'),
#  Row(Complaint Type='SAFETY'),
#  Row(Complaint Type='Cranes and Derricks'),
#  Row(Complaint Type='ELECTRIC'),
#  Row(Complaint Type='Animal-Abuse'),
#  Row(Complaint Type='Street Sweeping Complaint'),
#  Row(Complaint Type='Tanning'),
#  Row(Complaint Type='DOOR/WINDOW'),
#  Row(Complaint Type='Comments'),
#  Row(Complaint Type='Noise - Helicopter'),
#  Row(Complaint Type='STRUCTURAL'),
#  Row(Complaint Type='Broken Parking Meter'),
#  Row(Complaint Type='Fire Alarm - New System'),
#  Row(Complaint Type='Window Guard'),
#  Row(Complaint Type='Broken Muni Meter'),
#  Row(Complaint Type='Highway Condition'),
#  Row(Complaint Type='FLOORING/STAIRS'),
#  Row(Complaint Type='Street Condition'),
#  Row(Complaint Type='Hazardous Materials'),
#  Row(Complaint Type='Illegal Dumping'),
#  Row(Complaint Type='Vending'),
#  Row(Complaint Type='Ferry Permit'),
#  Row(Complaint Type='PAINT - PLASTER'),
#  Row(Complaint Type='OUTSIDE BUILDING'),
#  Row(Complaint Type='Taxi Report'),
#  Row(Complaint Type='Advocate-Prop Refunds/Credits'),
#  Row(Complaint Type='Drinking Water'),
#  Row(Complaint Type='UNSANITARY CONDITION'),
#  Row(Complaint Type='Bus Stop Shelter Complaint'),
#  Row(Complaint Type='Public Toilet'),
#  Row(Complaint Type="Misc. Comments'+(function()..."),
#  Row(Complaint Type='GENERAL CONSTRUCTION'),
#  Row(Complaint Type='Commercial Disposal Complaint'),
#  Row(Complaint Type='DSNY Internal'),
#  Row(Complaint Type='DOF Property - RPIE Issue'),
#  Row(Complaint Type='Municipal Parking Facility'),
#  Row(Complaint Type='Mosquitoes'),
#  Row(Complaint Type='DOF Property - Reduction Issue'),
#  Row(Complaint Type='Animal Abuse'),
#  Row(Complaint Type='Animal in a Park'),
#  Row(Complaint Type='Taxi Compliment'),
#  Row(Complaint Type='Misc. Comments../../../../....'),
#  Row(Complaint Type='Transfer Station Complaint'),
#  Row(Complaint Type='Open Flame Permit'),
#  Row(Complaint Type='Smoking'),
#  Row(Complaint Type='Illegal Animal Kept as Pet'),
#  Row(Complaint Type='Parking Card'),
#  Row(Complaint Type='Incorrect Data'),
#  Row(Complaint Type='Injured Wildlife'),
#  Row(Complaint Type='Noise - House of Worship'),
#  Row(Complaint Type='AGENCY'),
#  Row(Complaint Type='DHS Advantage -Landlord/Broker'),
#  Row(Complaint Type='Asbestos/Garbage Nuisance'),
#  Row(Complaint Type='Abandoned Bike'),
#  Row(Complaint Type='Sanitation Condition'),
#  Row(Complaint Type='Homeless Street Condition'),
#  Row(Complaint Type='COVID-19 Non-essential Construction'),
#  Row(Complaint Type='Special Natural Area District (SNAD)'),
#  Row(Complaint Type='qfix4${695*589}lixaf'),
#  Row(Complaint Type='Rangehood'),
#  Row(Complaint Type='Snow or Ice'),
#  Row(Complaint Type='Home Delivered Meal Complaint'),
#  Row(Complaint Type='Uprooted Stump'),
#  Row(Complaint Type='Illegal Parking'),
#  Row(Complaint Type='APPLIANCE'),
#  Row(Complaint Type='Building Condition'),
#  Row(Complaint Type='Taxi Licensee Complaint'),
#  Row(Complaint Type='/./validate_form.php'),
#  Row(Complaint Type='Noise - Residential'),
#  Row(Complaint Type='Obstruction'),
#  Row(Complaint Type='Unsanitary Condition'),
#  Row(Complaint Type='Portable Toilet'),
#  Row(Complaint Type='Sewer'),
#  Row(Complaint Type='Drug Activity'),
#  Row(Complaint Type='Registration and Transfers'),
#  Row(Complaint Type='Executive Inspections'),
#  Row(Complaint Type='DEP Street Condition'),
#  Row(Complaint Type='DOF Parking - DMV Clearance'),
#  Row(Complaint Type='Snow Removal'),
#  Row(Complaint Type='Noise Survey'),
#  Row(Complaint Type='Dirty Condition'),
#  Row(Complaint Type='Noise - Commercial'),
#  Row(Complaint Type='Highway Sign - Dangling'),
#  Row(Complaint Type='Building Marshals office'),
#  Row(Complaint Type='Water System'),
#  Row(Complaint Type='Adopt-A-Basket'),
#  Row(Complaint Type='Squeegee'),
#  Row(Complaint Type='Internal Code'),
#  Row(Complaint Type='Air Quality'),
#  Row(Complaint Type='Advocate-Co-opCondo Abatement'),
#  Row(Complaint Type='Lead'),
#  Row(Complaint Type='Street Sign - Missing'),
#  Row(Complaint Type='Home Delivered Meal - Missed Delivery'),
#  Row(Complaint Type="Misc. Comments' and 6049=60..."),
#  Row(Complaint Type='Single Occupancy Bathroom'),
#  Row(Complaint Type='Lost Property'),
#  Row(Complaint Type='Health'),
#  Row(Complaint Type='DRIE'),
#  Row(Complaint Type='General'),
#  Row(Complaint Type='DCA / DOH New License Application Request'),
#  Row(Complaint Type='CONSTRUCTION'),
#  Row(Complaint Type='Derelict Vehicle'),
#  Row(Complaint Type='ELEVATOR'),
#  Row(Complaint Type='OEM Literature Request'),
#  Row(Complaint Type='../../../../../../../../../...'),
#  Row(Complaint Type='Fire Alarm - Reinspection'),
#  Row(Complaint Type='DOF Property - Property Value'),
#  Row(Complaint Type='NONCONST'),
#  Row(Complaint Type='LinkNYC'),
#  Row(Complaint Type='Outdoor Dining'),
#  Row(Complaint Type='ZSYSTEST'),
#  Row(Complaint Type='Senior Center Complaint'),
#  Row(Complaint Type='Sweeping/Missed-Inadequate'),
#  Row(Complaint Type='Utility Program'),
#  Row(Complaint Type='DOF Property - City Rebate'),
#  Row(Complaint Type='X-Ray Machine/Equipment'),
#  Row(Complaint Type="Misc. Comments'||(select ex..."),
#  Row(Complaint Type='Misc. Comments|nslookup -q=...'),
#  Row(Complaint Type='Water Maintenance'),
#  Row(Complaint Type='Advocate-Commercial Exemptions'),
#  Row(Complaint Type='Blocked Driveway'),
#  Row(Complaint Type='Beach/Pool/Sauna Complaint'),
#  Row(Complaint Type='Lot Condition'),
#  Row(Complaint Type='Housing - Low Income Senior'),
#  Row(Complaint Type='Homeless Encampment'),
#  Row(Complaint Type='Bike/Roller/Skate Chronic'),
#  Row(Complaint Type='Taxi Complaint'),
#  Row(Complaint Type='HEAT/HOT WATER'),
#  Row(Complaint Type='Sidewalk Condition'),
#  Row(Complaint Type='NonCompliance with Phased Reopening'),
#  Row(Complaint Type='Green Taxi Complaint'),
#  Row(Complaint Type='HEAP Assistance'),
#  Row(Complaint Type='Litter Basket / Request'),
#  Row(Complaint Type='Lifeguard'),
#  Row(Complaint Type='E-Scooter'),
#  Row(Complaint Type='Stalled Sites'),
#  Row(Complaint Type='DOF Parking - Address Update'),
#  Row(Complaint Type='Consumer Complaint'),
#  Row(Complaint Type='For Hire Vehicle Complaint'),
#  Row(Complaint Type='Maintenance or Facility'),
#  Row(Complaint Type='Water Conservation'),
#  Row(Complaint Type='Research Questions'),
#  Row(Complaint Type='HPD Literature Request'),
#  Row(Complaint Type='Illegal Tree Damage'),
#  Row(Complaint Type='Advocate - Lien'),
#  Row(Complaint Type='file:///c:/windows/win.ini'),
#  Row(Complaint Type='DOF Parking - Tax Exemption'),
#  Row(Complaint Type='Request Xmas Tree Collection'),
#  Row(Complaint Type='DSNY Spillage'),
#  Row(Complaint Type='Benefit Card Replacement'),
#  Row(Complaint Type='Indoor Sewage'),
#  Row(Complaint Type='Weatherization'),
#  Row(Complaint Type='Asbestos'),
#  Row(Complaint Type='Unsanitary Animal Pvt Property'),
#  Row(Complaint Type='Quality of Life'),
#  Row(Complaint Type="Misc. Comments'|ping -c 21 ..."),
#  Row(Complaint Type='Discipline and Suspension'),
#  Row(Complaint Type='DEP Sidewalk Condition'),
#  Row(Complaint Type='Construction Lead Dust'),
#  Row(Complaint Type='Derelict Bicycle'),
#  Row(Complaint Type='Water Quality'),
#  Row(Complaint Type='Sweeping/Missed'),
#  Row(Complaint Type='Eviction'),
#  Row(Complaint Type='Private or Charter School Reopening'),
#  Row(Complaint Type='GENERAL'),
#  Row(Complaint Type='Standing Water'),
#  Row(Complaint Type='Noise - Park'),
#  Row(Complaint Type='Construction'),
#  Row(Complaint Type='Cooling Tower'),
#  Row(Complaint Type='Bus Stop Shelter Placement'),
#  Row(Complaint Type='DOR Literature Request'),
#  Row(Complaint Type='Mass Gathering Complaint'),
#  Row(Complaint Type='Poison Ivy'),
#  Row(Complaint Type='FHV Licensee Complaint'),
#  Row(Complaint Type='Missed Collection (All Materials)'),
#  Row(Complaint Type='Disorderly Youth'),
#  Row(Complaint Type='Highway Sign - Damaged'),
#  Row(Complaint Type='Electronics Waste Appointment'),
#  Row(Complaint Type='Special Operations'),
#  Row(Complaint Type='PAINT/PLASTER'),
#  Row(Complaint Type='Bike Rack Condition'),
#  Row(Complaint Type='Non-Residential Heat'),
#  Row(Complaint Type='Illegal Animal Sold'),
#  Row(Complaint Type='Forensic Engineering'),
#  Row(Complaint Type='Home Care Provider Complaint'),
#  Row(Complaint Type='Green Taxi Report'),
#  Row(Complaint Type='Other Enforcement'),
#  Row(Complaint Type='Found Property'),
#  Row(Complaint Type='Litter Basket Complaint'),
#  Row(Complaint Type='Homeless Person Assistance'),
#  Row(Complaint Type='Posting Advertisement'),
#  Row(Complaint Type='Legal Services Provider Complaint'),
#  Row(Complaint Type='Dead Animal'),
#  Row(Complaint Type="eval(compile('for x in rang..."),
#  Row(Complaint Type='Scaffold Safety'),
#  Row(Complaint Type="Misc. Comments'+sleep(20.to..."),
#  Row(Complaint Type='Miscellaneous Categories'),
#  Row(Complaint Type='Recycling Enforcement'),
#  Row(Complaint Type='Facades'),
#  Row(Complaint Type='Residential Disposal Complaint'),
#  Row(Complaint Type='Noise'),
#  Row(Complaint Type='Home Repair'),
#  Row(Complaint Type='.../.\\.../.\\.../.\\.../.\\......'),
#  Row(Complaint Type='Elder Abuse'),
#  Row(Complaint Type='Borough Office'),
#  Row(Complaint Type='Peeling Paint'),
#  Row(Complaint Type='Sustainability Enforcement'),
#  Row(Complaint Type='Employee Behavior'),
#  Row(Complaint Type='Abandoned Vehicle'),
#  Row(Complaint Type='Advocate - Other'),
#  Row(Complaint Type='New Tree Request'),
#  Row(Complaint Type='Boilers'),
#  Row(Complaint Type='DOF Property - Update Account'),
#  Row(Complaint Type='Industrial Waste'),
#  Row(Complaint Type='Sweeping/Inadequate'),
#  Row(Complaint Type='DOF Property - Owner Issue'),
#  Row(Complaint Type='Tattooing'),
#  Row(Complaint Type='Construction Safety Enforcement'),
#  Row(Complaint Type='Sprinkler - Mechanical'),
#  Row(Complaint Type='Dead/Dying Tree'),
#  Row(Complaint Type='Forms'),
#  Row(Complaint Type="Alzheimer's Care"),
#  Row(Complaint Type='Vaccine Mandate Non-Compliance'),
#  Row(Complaint Type='Mold'),
#  Row(Complaint Type='Change Collection Schedule'),
#  Row(Complaint Type='Collection Truck Noise'),
#  Row(Complaint Type='SNW'),
#  Row(Complaint Type='Street Light Condition'),
#  Row(Complaint Type='Plumbing'),
#  Row(Complaint Type='Storm'),
#  Row(Complaint Type='`sleep 11`'),
#  Row(Complaint Type='Calorie Labeling'),
#  Row(Complaint Type='Institution Disposal Complaint'),
#  Row(Complaint Type='Ferry Complaint'),
#  Row(Complaint Type='DOF Parking - Payment Issue'),
#  Row(Complaint Type='Day Care'),
#  Row(Complaint Type='Elevator'),
#  Row(Complaint Type='Litter Basket Request'),
#  Row(Complaint Type='DOF Property - Request Copy'),
#  Row(Complaint Type='Building/Use'),
#  Row(Complaint Type='Trans Fat'),
#  Row(Complaint Type='Advocate-UBT'),
#  Row(Complaint Type='Drinking'),
#  Row(Complaint Type='Bridge Condition'),
#  Row(Complaint Type='Request Large Bulky Item Collection'),
#  Row(Complaint Type='Housing Options'),
#  Row(Complaint Type='Public Payphone Complaint'),
#  Row(Complaint Type='Transportation Provider Complaint'),
#  Row(Complaint Type='Summer Camp'),
#  Row(Complaint Type='Special Enforcement'),
#  Row(Complaint Type='PLUMBING'),
#  Row(Complaint Type='BEST/Site Safety'),
#  Row(Complaint Type='NORC Complaint'),
#  Row(Complaint Type='Taxpayer Advocate Inquiry'),
#  Row(Complaint Type='Encampment'),
#  Row(Complaint Type='Case Management Agency Complaint'),
#  Row(Complaint Type='Dumpster Complaint'),
#  Row(Complaint Type='No Child Left Behind'),
#  Row(Complaint Type='Sanitation Worker or Vehicle Complaint'),
#  Row(Complaint Type='Question'),
#  Row(Complaint Type='Emergency Response Team (ERT)'),
#  Row(Complaint Type='Animal Facility - No Permit'),
#  Row(Complaint Type='Advocate - RPIE'),
#  Row(Complaint Type='Electric'),
#  Row(Complaint Type='Standpipe - Mechanical'),
#  Row(Complaint Type='Root/Sewer/Sidewalk Condition'),
#  Row(Complaint Type='City Vehicle Placard Complaint'),
#  Row(Complaint Type='Mobile Food Vendor'),
#  Row(Complaint Type='Parent Leadership'),
#  Row(Complaint Type='DHS Advantage - Third Party'),
#  Row(Complaint Type='Street Sign - Damaged'),
#  Row(Complaint Type='Investigations and Discipline (IAD)'),
#  Row(Complaint Type='Safety'),
#  Row(Complaint Type='Dispatched Taxi Complaint'),
#  Row(Complaint Type='Non-Emergency Police Matter'),
#  Row(Complaint Type='Food Poisoning'),
#  Row(Complaint Type='Unlicensed Dog'),
#  Row(Complaint Type='General Construction/Plumbing'),
#  Row(Complaint Type='Panhandling'),
#  Row(Complaint Type='Teaching/Learning/Instruction'),
#  Row(Complaint Type='HEATING'),
#  Row(Complaint Type='DOF Parking - Request Status'),
#  Row(Complaint Type='Dead Tree'),
#  Row(Complaint Type='Street Sign - Dangling'),
#  Row(Complaint Type='Damaged Tree'),
#  Row(Complaint Type='Advocate-SCRIE/DRIE'),
#  Row(Complaint Type='Select Message Type...'),
#  Row(Complaint Type='Noise - Vehicle'),
#  Row(Complaint Type='Special Projects Inspection Team (SPIT)'),
#  Row(Complaint Type='SCRIE'),
#  Row(Complaint Type='Traffic/Illegal Parking'),
#  Row(Complaint Type='Interior Demo'),
#  Row(Complaint Type='..././..././..././..././......'),
#  Row(Complaint Type='Snow'),
#  Row(Complaint Type='Overflowing Recycling Baskets'),
#  Row(Complaint Type='ZTESTINT'),
#  Row(Complaint Type='DEP Highway Condition'),
#  Row(Complaint Type='Rodent'),
#  Row(Complaint Type='Radioactive Material'),
#  Row(Complaint Type='Foam Ban Enforcement'),
#  Row(Complaint Type='Unsanitary Animal Facility'),
#  Row(Complaint Type='Highway Sign - Missing'),
#  Row(Complaint Type='Overflowing Litter Baskets'),
#  Row(Complaint Type='Bottled Water'),
#  Row(Complaint Type='Harboring Bees/Wasps'),
#  Row(Complaint Type='Wood Pile Remaining'),
#  Row(Complaint Type='Hazardous Material'),
#  Row(Complaint Type='Illegal Fireworks'),
#  Row(Complaint Type='Unleashed Dog'),
#  Row(Complaint Type='Traffic'),
#  Row(Complaint Type='Food Establishment'),
#  Row(Complaint Type='WATER LEAK'),
#  Row(Complaint Type='Derelict Vehicles'),
#  Row(Complaint Type='Advocate-Personal Exemptions'),
#  Row(Complaint Type='Outside Building'),
#  Row(Complaint Type='Graffiti'),
#  Row(Complaint Type='yw97y0gi2s'),
#  Row(Complaint Type='DPR Internal'),
#  Row(Complaint Type='OEM Disabled Vehicle'),
#  Row(Complaint Type='Public Assembly'),
#  Row(Complaint Type='Noise - Street/Sidewalk'),
#  Row(Complaint Type='Dirty Conditions'),
#  Row(Complaint Type='Plant'),
#  Row(Complaint Type='FCST'),
#  Row(Complaint Type='Electronics Waste'),
#  Row(Complaint Type='Violation of Park Rules'),
#  Row(Complaint Type='Curb Condition'),
#  Row(Complaint Type="Misc. Comments'&quot;`0&amp..."),
#  Row(Complaint Type='Tunnel Condition'),
#  Row(Complaint Type='Indoor Air Quality'),
#  Row(Complaint Type='DOF Property - State Rebate'),
#  Row(Complaint Type='SRDE'),
#  Row(Complaint Type='Bereavement Support Group'),
#  Row(Complaint Type='Illegal Posting'),
#  Row(Complaint Type='For Hire Vehicle Report'),
#  Row(Complaint Type='DOF Parking - Request Copy'),
#  Row(Complaint Type='Dept of Investigations'),
#  Row(Complaint Type='Urinating in Public'),
#  Row(Complaint Type='Unsanitary Pigeon Condition'),
#  Row(Complaint Type='Ferry Inquiry'),
#  Row(Complaint Type='Missed Collection'),
#  Row(Complaint Type='g0oii1s4s5)(objectClass=*'),
#  Row(Complaint Type="Misc. Comments' and 7702=77..."),
#  Row(Complaint Type='Vacant Lot'),
#  Row(Complaint Type='DHS Income Savings Requirement'),
#  Row(Complaint Type="&quot;--&gt;'--&gt;`--&gt;&..."),
#  Row(Complaint Type='General Question'),
#  Row(Complaint Type='DOF Property - Payment Issue'),
#  Row(Complaint Type='Overgrown Tree/Branches'),
#  Row(Complaint Type='Advocate-Prop Class Incorrect'),
#  Row(Complaint Type='FATF'),
#  Row(Complaint Type='Misc. Comments&gt;  BCC:bl0...'),
#  Row(Complaint Type='School Maintenance'),
#  Row(Complaint Type='Advocate-Property Value'),
#  Row(Complaint Type='ATF'),
#  Row(Complaint Type='DHS Advantage - Tenant'),
#  Row(Complaint Type='Electrical'),
#  Row(Complaint Type='Pet Shop')]

# %% [markdown]
# "Descriptor" column has the same problem of nonuniform casing, as previously observed in "Complaint Type" column.

# %%
# View column "Descriptor" 
df.select("Descriptor").distinct().collect()
# Out:
# [Row(Descriptor='Lamppost Damaged'),
#  Row(Descriptor='Plate Condition - Shifted'),
#  Row(Descriptor='BBQ Outside Authorized Area'),
#  Row(Descriptor='Ready NY - Seniors and Disabled - Spanish'),
#  Row(Descriptor='4 DSNY Spillage'),
#  Row(Descriptor='Containers Set Out Too Early'),
#  Row(Descriptor='Hydrant Running Full (WA4)'),
#  Row(Descriptor='Miscellaneous'),
#  Row(Descriptor='E10 Street Obstruction'),
#  Row(Descriptor='Glassware Hanging'),
#  Row(Descriptor='Personal Veteran Exemption'),
#  Row(Descriptor='Inside Apartment'),
#  Row(Descriptor='High Grass'),
#  Row(Descriptor='SCRIE Assistance'),
#  Row(Descriptor='ER9 FOAM VIOL. RETAILER'),
#  Row(Descriptor='Apartment'),
#  Row(Descriptor='SHOWER-STALL'),
#  Row(Descriptor='Broken Curb'),
#  Row(Descriptor='Tortured'),
#  Row(Descriptor='Tax Commission Rules'),
#  Row(Descriptor='Garbage'),
#  Row(Descriptor='Fire Alarm Lamp Out'),
#  Row(Descriptor='List of Outstanding Tickets'),
#  Row(Descriptor='Illegal Activity by Phone'),
#  Row(Descriptor='Home Instruction'),
#  Row(Descriptor='Oil Spill Into Basin/Sewer - Small (IABS)'),
#  Row(Descriptor='HEAT'),
#  Row(Descriptor='Payment Not Shown'),
#  Row(Descriptor='Ethernet Cable'),
#  Row(Descriptor='Amount Owed Dispute'),
#  Row(Descriptor='E11 Litter Surveillance'),
#  Row(Descriptor='Other (Explain Below)'),
#  Row(Descriptor='Copy of Notice of Property Value'),
#  Row(Descriptor='Labor violation'),
#  Row(Descriptor='Student/Parent Rights'),
#  Row(Descriptor='Birth Certificate Before 1910 Order Form'),
#  Row(Descriptor='Human Feces'),
#  Row(Descriptor='Roadway'),
#  Row(Descriptor='Signs of Rodents'),
#  Row(Descriptor='Decision and Order'),
#  Row(Descriptor='E10 Obstruction (Street/Sidewalk)'),
#  Row(Descriptor='Sign'),
#  Row(Descriptor='Smoking Ban - Smoking on Construction Site'),
#  Row(Descriptor='Shisha'),
#  Row(Descriptor='Water'),
#  Row(Descriptor='Stoop Line'),
#  Row(Descriptor='Non-Public Schools'),
#  Row(Descriptor='Payment Not Received from Tenant'),
#  Row(Descriptor='Table Not in Compliance'),
#  Row(Descriptor='Posted Parking Sign Violation'),
#  Row(Descriptor='Truck Route Violation'),
#  Row(Descriptor='Double Parked Blocking Vehicle'),
#  Row(Descriptor='Open Excavation (WZZ2)'),
#  Row(Descriptor='Lost Coin'),
#  Row(Descriptor='Cellar Door New'),
#  Row(Descriptor='Laundry License'),
#  Row(Descriptor='Employment Agency Manager License'),
#  Row(Descriptor='License Violation'),
#  Row(Descriptor='Bees/Wasps - Private Property'),
#  Row(Descriptor='Culvert Blocked/Needs Cleaning (SE)'),
#  Row(Descriptor='E5 Loose Rubbish'),
#  Row(Descriptor='Plumbing Work - Illegal/No Permit/Standpipe/Sprinkler'),
#  Row(Descriptor='Other Billing Issue'),
#  Row(Descriptor='Trunk Damaged'),
#  Row(Descriptor='SPRINKLER'),
#  Row(Descriptor='Non-Delivery of Papers'),
#  Row(Descriptor='Fleet'),
#  Row(Descriptor='Stoop Line Stand License'),
#  Row(Descriptor='Controller Flasher'),
#  Row(Descriptor='Non Retail Food Processing Establishment License'),
#  Row(Descriptor='Wind'),
#  Row(Descriptor='Food Contains Foreign Object'),
#  Row(Descriptor='Building Permit - None'),
#  Row(Descriptor='Property Value'),
#  Row(Descriptor='GUTTER/LEADER'),
#  Row(Descriptor='JANITOR-SUPER'),
#  Row(Descriptor='Loft Building'),
#  Row(Descriptor='Exchange/Refund/Return'),
#  Row(Descriptor='Remove Mortgage'),
#  Row(Descriptor='New Bus Stop Shelter Placement'),
#  Row(Descriptor='The ABCs of Housing - Spanish'),
#  Row(Descriptor='ELECTRIC-WIRING'),
#  Row(Descriptor='Copy of Account Information'),
#  Row(Descriptor='Commercial 421A Exemption'),
#  Row(Descriptor='Overcharge'),
#  Row(Descriptor='JANITOR/SUPER'),
#  Row(Descriptor='Defective/Missing Curb Piece (SC4)'),
#  Row(Descriptor='Structure - Indoors'),
#  Row(Descriptor='Plants- Odor Related Problems (PO1)'),
#  Row(Descriptor='Application Portability'),
#  Row(Descriptor='Ticket Scalping'),
#  Row(Descriptor='9 Spill/Oil etc'),
#  Row(Descriptor='Scale Dealer/Repairer'),
#  Row(Descriptor='Bwso Referral To Water Quality (For Dep Internal Use Only) (QBWSO)'),
#  Row(Descriptor='Retaining Wall Tracking Complaint'),
#  Row(Descriptor='DAMP SPOT'),
#  Row(Descriptor='Sidewalk Blocked'),
#  Row(Descriptor='Unauthorized Tree Removal'),
#  Row(Descriptor='Other - Explain Below'),
#  Row(Descriptor='Safety Equipment/Signs'),
#  Row(Descriptor='Rough, Pitted or Cracked Roads'),
#  Row(Descriptor='Personal Other Exemption'),
#  Row(Descriptor='Plate Missing/Moved-Exposing Hole (SB4)'),
#  Row(Descriptor='Hurricane Preparedness - English'),
#  Row(Descriptor='Seasonal Food Cart Vendor Permit'),
#  Row(Descriptor='Secondhand Dealer'),
#  Row(Descriptor='Dust Cover'),
#  Row(Descriptor='Documents/Paperwork Missing'),
#  Row(Descriptor='Tree Trunk Split'),
#  Row(Descriptor='Air: Odor, Nail Salon (AD8)'),
#  Row(Descriptor='Plumbing Problem'),
#  Row(Descriptor='Illegal Use Of Hose - Other (CCO)'),
#  Row(Descriptor='Barbershop License'),
#  Row(Descriptor='Public Area'),
#  Row(Descriptor='Electrical Enforcement Work Order (DOB)'),
#  Row(Descriptor='Homebound Senior'),
#  Row(Descriptor='RADIATOR'),
#  Row(Descriptor='SEWAGE'),
#  Row(Descriptor='Chemical Spill (IAC)'),
#  Row(Descriptor='Illegal Dumping'),
#  Row(Descriptor='Illegal Use Of Hose - Private Residence'),
#  Row(Descriptor='New Lead Law Rights and Requirements'),
#  Row(Descriptor='Hurricane Preparedness - Spanish'),
#  Row(Descriptor='NO WATER - WNW'),
#  Row(Descriptor='Tow Truck Driver License'),
#  Row(Descriptor='Recurring after SOAP *FOR DEP INTERNAL USE ONLY* (SRAS)'),
#  Row(Descriptor='Business not allowed to be open'),
#  Row(Descriptor='Air: Open Fire, Construction/Demolition (AC4)'),
#  Row(Descriptor='Used Gun Dealer'),
#  Row(Descriptor='Equipment Not Safe'),
#  Row(Descriptor='ENTIRE BUILDING'),
#  Row(Descriptor='Street Light Dayburning'),
#  Row(Descriptor='Card - DOF Confirmation Number Issued'),
#  Row(Descriptor='Pet/Animal'),
#  Row(Descriptor='DRIE Exemption'),
#  Row(Descriptor='Gasoline Spill (IAA)'),
#  Row(Descriptor='Education Support, Policy, and Practice'),
#  Row(Descriptor='Dismiss Violation Owner Fixed'),
#  Row(Descriptor='Warning Buzzer'),
#  Row(Descriptor='Broken Window'),
#  Row(Descriptor='Tenant and Landlord Disputes Brochure - Spanish'),
#  Row(Descriptor='Rodents/Mice'),
#  Row(Descriptor='Scale Inaccurate/Broken'),
#  Row(Descriptor='Sewer or Drain'),
#  Row(Descriptor='Not Received - Vending Machine'),
#  Row(Descriptor='Building Under Structural Monitoring'),
#  Row(Descriptor='Sidewalk Cafe License'),
#  Row(Descriptor='Grocery Store'),
#  Row(Descriptor='Branch or Limb Has Fallen Down'),
#  Row(Descriptor='LED Lense'),
#  Row(Descriptor='Plate Condition - Anti-Skid'),
#  Row(Descriptor='Lost/Missing Person'),
#  Row(Descriptor='Speed Board Sign'),
#  Row(Descriptor='Tobacco Retail Dealer License Application'),
#  Row(Descriptor='Ready NY - Pets - English'),
#  Row(Descriptor='Animal Grooming License'),
#  Row(Descriptor='With License Plate'),
#  Row(Descriptor='E15 Illegal Postering'),
#  Row(Descriptor='Use Indoor'),
#  Row(Descriptor='Flashing Hazard'),
#  Row(Descriptor='Other Animal'),
#  Row(Descriptor='Billing Dispute'),
#  Row(Descriptor='Employment Agency License'),
#  Row(Descriptor='Damage Assessment Request (Disaster)'),
#  Row(Descriptor='ELECTRIC/GAS-RANGE'),
#  Row(Descriptor='Amusement Arcade License'),
#  Row(Descriptor='Promotion/Grad Requirements'),
#  Row(Descriptor='Vocational or Trade School'),
#  Row(Descriptor='Certificate of No Harassment (CONH) Application'),
#  Row(Descriptor='Damaged/Defective'),
#  Row(Descriptor='Structural Stability Impacted - New Building Under Construction'),
#  Row(Descriptor='Warning Signal Lamp'),
#  Row(Descriptor='Gas Utility Referral'),
#  Row(Descriptor='The ABCs of Housing - Korean'),
#  Row(Descriptor='Street Fair Vendor'),
#  Row(Descriptor='Motion Picture Operator License'),
#  Row(Descriptor='Card - No DOF Confirmation Number Issued'),
#  Row(Descriptor='Classroom Learning'),
#  Row(Descriptor='Unhealthy Condition in School'),
#  Row(Descriptor='Trench (SZZ1)'),
#  Row(Descriptor='Contrary To LL 58/87(Handicapped Access)'),
#  Row(Descriptor='Woodside Settlement Project'),
#  Row(Descriptor='Landlord Requesting Additonal Rent'),
#  Row(Descriptor='Ticket Broker'),
#  Row(Descriptor='Branch Cracked and Will Fall'),
#  Row(Descriptor='SMOKE DETECTOR'),
#  Row(Descriptor='Lamppost Wire Exposed'),
#  Row(Descriptor='Refund/Credit Info or Status'),
#  Row(Descriptor='Graffiti/Litter on Phone'),
#  Row(Descriptor='Public Complaint - Comm Location'),
#  Row(Descriptor='Glassware Broken'),
#  Row(Descriptor='Beach/Pool Water'),
#  Row(Descriptor='Insects / Pests'),
#  Row(Descriptor='Debt Collection Agency License'),
#  Row(Descriptor='Locksmith'),
#  Row(Descriptor='NO LIGHTING'),
#  Row(Descriptor='Plumbing-Defective/Leaking/Not Maintained'),
#  Row(Descriptor='St Name - Attached to Pole'),
#  Row(Descriptor='Electronic Sign - Overhead'),
#  Row(Descriptor='Remove Debris'),
#  Row(Descriptor='Wireless'),
#  Row(Descriptor='Cancellation/Closure without Notice'),
#  Row(Descriptor='Cars Parked on Sidewalk/Street'),
#  Row(Descriptor='House/Property Damaged'),
#  Row(Descriptor='Inadequate Support Shoring'),
#  Row(Descriptor='Dirt, Debris, Litter Complaint'),
#  Row(Descriptor='Plants- Noise Related Problems (PN1)'),
#  Row(Descriptor='Ready NY - Haitian Creole - Full Size'),
#  Row(Descriptor='Marshal - Not Reflected'),
#  Row(Descriptor='HEAT RELATED'),
#  Row(Descriptor='Home Heating Oil Company'),
#  Row(Descriptor='Collection Days'),
#  Row(Descriptor='Face Covering Violation'),
#  Row(Descriptor='E1 Improper Disposal'),
#  Row(Descriptor='DOOR/FRAME'),
#  Row(Descriptor='Real Property Tax Assessment/Correction'),
#  Row(Descriptor='Dry Cleaning Vapors (PERC)'),
#  Row(Descriptor='PAVEMENT'),
#  Row(Descriptor='SCRIE Miscellaneous'),
#  Row(Descriptor='Customer Proof of Vaccination Not Checked'),
#  Row(Descriptor='Sports Equipment'),
#  Row(Descriptor='Graffiti - Tunnel'),
#  Row(Descriptor='Cabaret'),
#  Row(Descriptor='E1A Litter Basket / Improper Use'),
#  Row(Descriptor='BUILDING COLLAPSE/FIRE, (ASBESTOS RELATED) *FOR DEP INTERNAL USE ONLY* (HH2)'),
#  Row(Descriptor='Facility Maint./Cleanliness'),
#  Row(Descriptor='Controller'),
#  Row(Descriptor='TOILET'),
#  Row(Descriptor='SLOW LEAK'),
#  Row(Descriptor='ROOFING'),
#  Row(Descriptor='Sewage Odor'),
#  Row(Descriptor='Unsecured Facility'),
#  Row(Descriptor='Smoking'),
#  Row(Descriptor='Injured Wildlife'),
#  Row(Descriptor='Defective Street Cut (WZZ1)'),
#  Row(Descriptor='Blank Out Matrix Sgn'),
#  Row(Descriptor='Traffic Camera'),
#  Row(Descriptor='Pool or Billiard Hall License'),
#  Row(Descriptor='Summer School'),
#  Row(Descriptor='Other (complaint details)'),
#  Row(Descriptor='Street Cleaning - ASP'),
#  Row(Descriptor='Chemical Odor (HD1)'),
#  Row(Descriptor='E3A Dirty Area/Alleyway'),
#  Row(Descriptor='Status of Payment Adjustment'),
#  Row(Descriptor='Missing/Stump'),
#  Row(Descriptor='Driver Complaint - Non Passenger'),
#  Row(Descriptor='Sample Suspected Gas Leak Notice'),
#  Row(Descriptor='Container - Over 5 Gallons'),
#  Row(Descriptor='Personal Clergy Exemption'),
#  Row(Descriptor='Ready NY My Emergency Plan - Russian'),
#  Row(Descriptor='Electronics Repair Store'),
#  Row(Descriptor='Hydrant Defect'),
#  Row(Descriptor='Street Flooding (SJ)'),
#  Row(Descriptor='Dead Branches in Tree'),
#  Row(Descriptor='Metal Protruding - Sign Stump'),
#  Row(Descriptor='Inattentive'),
#  Row(Descriptor='Guard Rail - Highway'),
#  Row(Descriptor='Air Conditioning Problem'),
#  Row(Descriptor='People Created Noise'),
#  Row(Descriptor='Interruption of Essential Services Notice'),
#  Row(Descriptor='MAIL-BOX'),
#  Row(Descriptor='Genealogy Research Application'),
#  Row(Descriptor='Misuse'),
#  Row(Descriptor='Mouse Sighting'),
#  Row(Descriptor='8 Request to Clean Vacant Lot'),
#  Row(Descriptor='Fixture/Luminaire Door Open'),
#  Row(Descriptor='Noise:  lawn care equipment (NCL)'),
#  Row(Descriptor='Mass Gathering'),
#  Row(Descriptor='Pothole - Tunnel'),
#  Row(Descriptor='Milk Not Pasteurized'),
#  Row(Descriptor='Dealer in Devices for Disabled License'),
#  Row(Descriptor='Possible Landlord Foreclosure'),
#  Row(Descriptor='MOLD'),
#  Row(Descriptor='Curb Cut/Driveway/Carport - Illegal'),
#  Row(Descriptor='Returns Not Filed'),
#  Row(Descriptor='Bees/Wasps - Not a beekeper'),
#  Row(Descriptor='Fountain - Under 5 Gallons'),
#  Row(Descriptor='Suspected Street Cut'),
#  Row(Descriptor='City Planning Commission'),
#  Row(Descriptor='Food Spoiled'),
#  Row(Descriptor='Personal DHE Exemption'),
#  Row(Descriptor='Secondhand Dealer General License'),
#  Row(Descriptor='Shelter for Homeless Animals License'),
#  Row(Descriptor='Energy'),
#  Row(Descriptor='Possible Water Main Break (Use Comments) (WA1)'),
#  Row(Descriptor='Copy of Approval Order'),
#  Row(Descriptor='Noise: Air Condition/Ventilation Equip, Commercial (NJ2)'),
#  Row(Descriptor='HPD Guide to Programs and Services'),
#  Row(Descriptor='Failure To Maintain'),
#  Row(Descriptor='Snow or Ice'),
#  Row(Descriptor='Property Refunds and Credits'),
#  Row(Descriptor='Excavation Undermining Adjacent Building'),
#  Row(Descriptor='Remove Hydrant Locking Device (WC6)'),
#  Row(Descriptor='Graffiti/Dirty Condition'),
#  Row(Descriptor='Raccoon'),
#  Row(Descriptor='Lighting/Electrical'),
#  Row(Descriptor='Chained'),
#  Row(Descriptor='Broken/Defective'),
#  Row(Descriptor='Milk Expired'),
#  Row(Descriptor='14 Derelict Vehicles'),
#  Row(Descriptor='Arcade'),
#  Row(Descriptor='Not Certified'),
#  Row(Descriptor='Noise: Construction Before/After Hours (NM1)'),
#  Row(Descriptor='Bicycle Chained to Tree'),
#  Row(Descriptor='ID Requirement Not Posted'),
#  Row(Descriptor='On Messenger'),
#  Row(Descriptor='Transducer-Loop'),
#  Row(Descriptor='Reflector/Louvre'),
#  Row(Descriptor='In Person - Not Reflected or Mailed - Not Reflected'),
#  Row(Descriptor='Ready NY - French - Full Size'),
#  Row(Descriptor='1RO Missed Recycling Organics'),
#  Row(Descriptor='Parking Card Stuck in Meter'),
#  Row(Descriptor='Playing in Unsuitable Place'),
#  Row(Descriptor='General Vendor Waiting List Application'),
#  Row(Descriptor='Tie Rods'),
#  Row(Descriptor='AIR-CONDITIONER'),
#  Row(Descriptor='No or Defective Headphones'),
#  Row(Descriptor='E9 Snow / Icy Sidewalk'),
#  Row(Descriptor='22 Weeds'),
#  Row(Descriptor='Removing Wildlife'),
#  Row(Descriptor='Unsanitary Condition'),
#  Row(Descriptor='SCRIE Recertification'),
#  Row(Descriptor='Zoning and Land Use Questions/Information'),
#  Row(Descriptor='Loan Brochures'),
#  Row(Descriptor='Hyd Valve Box Defective - See Comments *For Dep Use Only* (WV3)'),
#  Row(Descriptor='Finance Business Center - Not Reflected'),
#  Row(Descriptor='Unauthorized Restaurant'),
#  Row(Descriptor='BBS Failure'),
#  Row(Descriptor='FENCING'),
#  Row(Descriptor='Nuisance/Truant'),
#  Row(Descriptor='Vehicle Owner Address Update'),
#  Row(Descriptor='Existing Building'),
#  Row(Descriptor='Noise: air condition/ventilation equipment (NV1)'),
#  Row(Descriptor='Food Stamp'),
#  Row(Descriptor='Food Worker Hygiene'),
#  Row(Descriptor='Animal Odor'),
#  Row(Descriptor='Stalled Construction Site'),
#  Row(Descriptor='Canopy Complaint'),
#  Row(Descriptor='Passing By'),
#  Row(Descriptor='Because of Violation'),
#  Row(Descriptor='Illegal. Commercial Use In Resident Zone'),
#  Row(Descriptor='Credit Card Limitations Not Posted'),
#  Row(Descriptor='Lead Kit Request (Residential) (L10)'),
#  Row(Descriptor='Construction - Change Grade/Watercourse'),
#  Row(Descriptor='WATER-LEAKS'),
#  Row(Descriptor=None),
#  Row(Descriptor='Advertising Sign/Billboard/Posters/Flexible Fabric - Illegal'),
#  Row(Descriptor='Installation/Work Quality'),
#  Row(Descriptor='Laundry'),
#  Row(Descriptor='Locksmith License'),
#  Row(Descriptor='Site Conditions Endangering Workers'),
#  Row(Descriptor='No Permit or License'),
#  Row(Descriptor='Sidewalk Consultation'),
#  Row(Descriptor='Ped Flasher'),
#  Row(Descriptor='Facility Maintenance'),
#  Row(Descriptor='Bulky Trash'),
#  Row(Descriptor='Lead, Outdoor (HJ2)'),
#  Row(Descriptor='23 Change Collection Schedule'),
#  Row(Descriptor='Depression'),
#  Row(Descriptor='Health Instruction in School'),
#  Row(Descriptor='Other Housing Options'),
#  Row(Descriptor='Veh Sgnl Mult Lamps'),
#  Row(Descriptor='Re-Inspect - Rslve Objections'),
#  Row(Descriptor='Plate Condition - Open'),
#  Row(Descriptor='Dogs or Cats Sold'),
#  Row(Descriptor='Fire Hydrant Emergency (FHE)'),
#  Row(Descriptor='Semi-Annual Homeless Shelter Inspection: Construction'),
#  Row(Descriptor='Other Issue'),
#  Row(Descriptor='In Person - Not Reflected'),
#  Row(Descriptor='Child Care Information'),
#  Row(Descriptor='Noise: Construction Equipment (NC1)'),
#  Row(Descriptor='Bill Received in Error'),
#  Row(Descriptor='In-Line Fuse Missing'),
#  Row(Descriptor='Initial - CO'),
#  Row(Descriptor='Employee Proof of Vaccination Not Checked'),
#  Row(Descriptor='HEAT-PLANT'),
#  Row(Descriptor='Air: Open Fire, Residential (AC1)'),
#  Row(Descriptor='Storage Warehouse License'),
#  Row(Descriptor='Mental Health'),
#  Row(Descriptor='1RB Missed Recycling - M/G/Pl'),
#  Row(Descriptor='DOOR FRAME'),
#  Row(Descriptor='Incorrect Amount Paid'),
#  Row(Descriptor='Copy of Statement'),
#  Row(Descriptor='School Crossing'),
#  Row(Descriptor='Office of Preventive Technical Assistance/OPTA'),
#  Row(Descriptor='Noise: Air Condition/Ventilation Equip, Residential (NJ1)'),
#  Row(Descriptor='Chronic Speeding'),
#  Row(Descriptor='Catch Basin Search (SC2)'),
#  Row(Descriptor='Death Certificate Before 1949 Order Form'),
#  Row(Descriptor='Snow Removal'),
#  Row(Descriptor='Swimming Pool/Waterfront'),
#  Row(Descriptor='Air: Open Fire, Commercial (AC2)'),
#  Row(Descriptor='Jewelry/Dentistry Torch: Gas Piping Removed W/O Permit'),
#  Row(Descriptor='Kitchen/Food Prep Area'),
#  Row(Descriptor='Air: Odor/Fumes, Vehicle Idling (AD3)'),
#  Row(Descriptor='Street Zone Blocked'),
#  Row(Descriptor='Complaince Inspection'),
#  Row(Descriptor='Messenger'),
#  Row(Descriptor='Dog Waste'),
#  Row(Descriptor='Jewelry Appraiser'),
#  Row(Descriptor='Plate Condition - DEP'),
#  Row(Descriptor='Condition Attracting Rodents'),
#  Row(Descriptor='Information Technology'),
#  Row(Descriptor='Handwashing'),
#  Row(Descriptor='Crash Cushion Defect'),
#  Row(Descriptor='Large Number of Mosquitoes'),
#  Row(Descriptor='Trash'),
#  Row(Descriptor='Electrical - Unlicensed/Illegal/Improper Work In Progress'),
#  Row(Descriptor='Senior Citizen Home Assistance Program (SCHAP) Loan'),
#  Row(Descriptor='WINDOW GUARDS'),
#  Row(Descriptor='Electronics Store'),
#  Row(Descriptor='Facilities Management'),
#  Row(Descriptor='Dissatisfaction with Provider'),
#  Row(Descriptor='Commercial 421B Exemption'),
#  Row(Descriptor='Sustainability Enforcement Work Order'),
#  Row(Descriptor='Best - High-Rise Tracking Complaint'),
#  Row(Descriptor='Indoor Pool Over Capacity'),
#  Row(Descriptor='False Advertising'),
#  Row(Descriptor='Food Contaminated'),
#  Row(Descriptor='CABINET'),
#  Row(Descriptor='Highway Flooding (SH)'),
#  Row(Descriptor='Mandated Reporters'),
#  Row(Descriptor='Equipment'),
#  Row(Descriptor='Illegal Activity'),
#  Row(Descriptor='Ready NY - Chinese Traditional - Full Size'),
#  Row(Descriptor='High Interest Loan'),
#  Row(Descriptor='15S Re-Plow/Spread/Ice-Snow Cond.'),
#  Row(Descriptor='Retail Store'),
#  Row(Descriptor='General Inquiry'),
#  Row(Descriptor='Guard Rail - Bridge'),
#  Row(Descriptor='General Vendor Distributor License'),
#  Row(Descriptor='Vehicle Complaint'),
#  Row(Descriptor='Property Value Dispute'),
#  Row(Descriptor='SKYLIGHT'),
#  Row(Descriptor='Portable Amusement Ride License'),
#  Row(Descriptor='Sidewalk Pull Box Co'),
#  Row(Descriptor='COOKING GAS'),
#  Row(Descriptor='Partial Access'),
#  Row(Descriptor='Illness Caused by Drinking Water'),
#  Row(Descriptor='Wasting Faucets,Sinks,Flushometer,Urinal,Etc. - Private Residence (CWR)'),
#  Row(Descriptor='No Sampling Required, Requested Information (QG2)'),
#  Row(Descriptor='Bird Bath'),
#  Row(Descriptor='Clear Water With Organisms (Insects, Worms) (QE2)'),
#  Row(Descriptor='Fallen Debris from Tunnel'),
#  Row(Descriptor='Donation Collection Bin'),
#  Row(Descriptor='SCRIE Initial Application'),
#  Row(Descriptor='Veh Signal Lamp'),
#  Row(Descriptor='LIGHTING'),
#  Row(Descriptor='Loose Plate'),
#  Row(Descriptor='Wrong Amount Paid or Withdrawn'),
#  Row(Descriptor='Property - Other Billing Issue'),
#  Row(Descriptor='Initial Application'),
#  Row(Descriptor='Grease In Sewer/Catch Basin (IDG)'),
#  Row(Descriptor='Temporary Tattoo License'),
#  Row(Descriptor='Returning Payment'),
#  Row(Descriptor='Auction House License'),
#  Row(Descriptor='Wastewater Into Catch Basin (IEB)'),
#  Row(Descriptor='Safety Netting/Guard Rails - Damaged/Inadequate/None (6 Stories/75 Feet Or Less)'),
#  Row(Descriptor='Damaged Toilet/Sink'),
#  Row(Descriptor='Non-Compliance w/Lightweight Materials'),
#  Row(Descriptor='M.A.R.C.H. Program (Interagency)'),
#  Row(Descriptor='Horse Stable License'),
#  Row(Descriptor='Car/Truck Music'),
#  Row(Descriptor='Unauthorized Bus Layover'),
#  Row(Descriptor='Building - Vacant, Open And Unguarded'),
#  Row(Descriptor='ER4 City Agency (Inst. Recycling)'),
#  Row(Descriptor='Telco Connection Blk'),
#  Row(Descriptor='1 Missed Collection'),
#  Row(Descriptor='Car Service Company Report'),
#  Row(Descriptor='Illegal Tow'),
#  Row(Descriptor='MICROWAVE'),
#  Row(Descriptor='Relocation of Bus Stop Shelter'),
#  Row(Descriptor='Flood Light Lamp Dim'),
#  Row(Descriptor='Bird'),
#  Row(Descriptor='Detour'),
#  Row(Descriptor='Accident - Cranes/Derricks/Suspension Scaffold'),
#  Row(Descriptor='Broken Lock'),
#  Row(Descriptor='FIRE-ESCAPE'),
#  Row(Descriptor='Ready NY - Arabic - Full Size'),
#  Row(Descriptor='Dry weather discharge (DWD)'),
#  Row(Descriptor='Manhole Cover Broken/Making Noise (SB)'),
#  Row(Descriptor='Commercial Green Roof or Solar Panel Exemption'),
#  Row(Descriptor='Unsafe Worksite'),
#  Row(Descriptor='Honorary'),
#  Row(Descriptor='Elevator In (Fdny) Readiness - None'),
#  Row(Descriptor='Sightseeing Bus License'),
#  Row(Descriptor='Accessing Medical Care'),
#  Row(Descriptor='Dust'),
#  Row(Descriptor='WALL'),
#  Row(Descriptor='Blocked Bike Lane'),
#  Row(Descriptor='Cellar Door Open/Unprotected'),
#  Row(Descriptor='Loud Television'),
#  Row(Descriptor='21 Collection Truck Noise'),
#  Row(Descriptor='Snow on Overpass'),
#  Row(Descriptor='After Hours - Licensed Est'),
#  Row(Descriptor='Taste/Odor, Chemical (QA2)'),
#  Row(Descriptor='CMU Communication'),
#  Row(Descriptor='Lost Property'),
#  Row(Descriptor='Material Storage - Unsafe'),
#  Row(Descriptor='Fence'),
#  Row(Descriptor='Dry Cleaner'),
#  Row(Descriptor='Ready NY - Russian - Pocket Size'),
#  Row(Descriptor='Sticker or Decal'),
#  Row(Descriptor='Syringes'),
#  Row(Descriptor='LOW WATER PRESSURE - WLWP'),
#  Row(Descriptor='Ped Lamp'),
#  Row(Descriptor='Investigative Inspection'),
#  Row(Descriptor='Turtle Under 4 inches Long'),
#  Row(Descriptor='Roof Gutters'),
#  Row(Descriptor='Summer Heat - Chinese'),
#  Row(Descriptor='RTMS'),
#  Row(Descriptor='Excise Taxes-Refund'),
#  Row(Descriptor='Veh Signal Sec Door'),
#  Row(Descriptor='Registration Clearance Request'),
#  Row(Descriptor='Puddle on Sidewalk'),
#  Row(Descriptor='Trash and Bulky Trash'),
#  Row(Descriptor='Announcements'),
#  Row(Descriptor='Amusement Ride Accident/Incident'),
#  Row(Descriptor='Commercial ICP or ICAP Exemption'),
#  Row(Descriptor='Non-Delivery Goods/Services'),
#  Row(Descriptor='Landmark Bldg - Illegal Work'),
#  Row(Descriptor='Chained Bike'),
#  Row(Descriptor='Horse Drawn Carriage Driver License'),
#  Row(Descriptor='Marine Flasher'),
#  Row(Descriptor='DRIE'),
#  Row(Descriptor='Contract Dispute'),
#  Row(Descriptor='ER5 Comm. Recyc. (Bldg Mgmt)'),
#  Row(Descriptor='Personal DRIE Exemption'),
#  Row(Descriptor='Retail Laundry License Application'),
#  Row(Descriptor='No Status Call'),
#  Row(Descriptor='Neighborhood Entrepreneurs Program (NEP) Guide'),
#  Row(Descriptor='Dumpster - Causing Damage'),
#  Row(Descriptor='Spanish Transaction'),
#  Row(Descriptor='Ped Visor'),
#  Row(Descriptor='Commercial Not For Profit Exemption'),
#  Row(Descriptor='ACRIS Incorrect'),
#  Row(Descriptor='E7 Private Carter Spillage'),
#  Row(Descriptor='Air: Smoke, Commercial (AA2)'),
#  Row(Descriptor='Out of Order'),
#  Row(Descriptor='Underground'),
#  Row(Descriptor='Sidewalk Grating - Missing'),
#  Row(Descriptor='Noise: Loud Music/Nighttime(Mark Date And Time) (NP1)'),
#  Row(Descriptor='Graffiti - Bridge'),
#  Row(Descriptor='NYPD'),
#  Row(Descriptor='Time Insufficient'),
#  Row(Descriptor='ELEVATOR'),
#  Row(Descriptor='Clear Street Light'),
#  Row(Descriptor='Initial - PA'),
#  Row(Descriptor='Ready NY - Russian - Full Size'),
#  Row(Descriptor='HomeFirst Down Payment Information'),
#  Row(Descriptor='Crane/Suspension Scaffold - No Permit/License/Cert./Unsafe/Illegal'),
#  Row(Descriptor='Sidewalk Collapsed'),
#  Row(Descriptor='12P Dead Deer'),
#  Row(Descriptor='Door'),
#  Row(Descriptor='Trauma Counseling'),
#  Row(Descriptor='Engine Idling'),
#  Row(Descriptor='Hyd Valve Box Cover Missing (WV2)'),
#  Row(Descriptor='Taste/Odor, Bitter/Metallic (QA3)'),
#  Row(Descriptor='Unauthorized Film Shoot'),
#  Row(Descriptor='Required Signage Not Posted'),
#  Row(Descriptor='Peeling Paint Inside Home'),
#  Row(Descriptor='Debris from Car Accident'),
#  Row(Descriptor='Do Not Block the Box'),
#  Row(Descriptor='BELL-BUZZER/INTERCOM'),
#  Row(Descriptor='Status of Refund'),
#  Row(Descriptor='Storage Area Not Provided'),
#  Row(Descriptor='PESTS'),
#  Row(Descriptor='Pothole - Highway'),
#  Row(Descriptor='Bag/Wallet'),
#  Row(Descriptor='5 Un-Plowed/Spread Street'),
#  Row(Descriptor='Strip Paving'),
#  Row(Descriptor='Booting Company License'),
#  Row(Descriptor='Going Out of Business'),
#  Row(Descriptor='Platform Condition'),
#  Row(Descriptor='ELECTRIC/GAS RANGE'),
#  Row(Descriptor='Vent/Exhaust - Illegal/Improper'),
#  Row(Descriptor='Garage/Parking Lot'),
#  Row(Descriptor='Driver Compliment'),
#  Row(Descriptor='General Maintenance'),
#  Row(Descriptor='Semi-Annual Homeless Shelter Inspection: Plumbing'),
#  Row(Descriptor='School Choice/Transfer'),
#  Row(Descriptor='Credit Card Stuck in Meter'),
#  Row(Descriptor='Entire Tree Has Fallen Down'),
#  Row(Descriptor='No Parking, Standing, Stopping'),
#  Row(Descriptor='1R Missed Recycling-All Materials'),
#  Row(Descriptor='Posted Notice Or Order Removed/Tampered With'),
#  Row(Descriptor='Noise: Boat(Engine,Music,Etc) (NR10)'),
#  Row(Descriptor='Damaged/Defective Parts'),
#  Row(Descriptor='Noise: Vehicle (NR2)'),
#  Row(Descriptor='Blocked Crosswalk'),
#  Row(Descriptor='Waste Left in Front of Residence'),
#  Row(Descriptor='Advice Request'),
#  Row(Descriptor='Cons - Contrary/Beyond Approved Plans/Permits'),
#  Row(Descriptor='Other Water Problem (Use Comments) (QZZ)'),
#  Row(Descriptor='Closed without Notice'),
#  Row(Descriptor='Leaky Roof'),
#  Row(Descriptor='Executive'),
#  Row(Descriptor='Routine Inspection'),
#  Row(Descriptor='Ready NY - Seniors and Disabled - Audio Cassette'),
#  Row(Descriptor='Sidewalk Cafe'),
#  Row(Descriptor='Facility Unregistered'),
#  Row(Descriptor='E30 Transfer Station'),
#  Row(Descriptor='Air: Smoke, Residential (AA1)'),
#  Row(Descriptor='Food Worker Illness'),
#  Row(Descriptor='Flavored Tobacco'),
#  Row(Descriptor='EEO'),
#  Row(Descriptor='Day Care Facility'),
#  Row(Descriptor='Driver Report - Non Passenger'),
#  Row(Descriptor='Exposure from Nearby Facility'),
#  Row(Descriptor='Ready NY - Pets - Spanish'),
#  Row(Descriptor='Academic Intervention Services'),
#  Row(Descriptor='Smoking Violation'),
#  Row(Descriptor='Stop'),
#  Row(Descriptor='Blocking Street'),
#  Row(Descriptor='Tenant Refusal'),
#  Row(Descriptor='Removal Request'),
#  Row(Descriptor='Puddle on Driveway'),
#  Row(Descriptor='Placement'),
#  Row(Descriptor='OTHER INDUSTRIAL WASTE PROBLEM (USE COMMENTS) FOR DEP INTERNAL USE ONLY (IZ)'),
#  Row(Descriptor='Leak (Use Comments) (WA2)'),
#  Row(Descriptor='E2A Storage Of Receptacles'),
#  Row(Descriptor='Fixture/Luminaire Out Of Position'),
#  Row(Descriptor='Condo or Co-op Abatement'),
#  Row(Descriptor='Graffiti or Vandalism'),
#  Row(Descriptor='Hours of Operation'),
#  Row(Descriptor='Summer Heat - Spanish'),
#  Row(Descriptor='Inhalation Therapy Supervising Technician License'),
#  Row(Descriptor='Pathogens License'),
#  Row(Descriptor='Commercial Government Exemption'),
#  Row(Descriptor='WATER SUPPLY'),
#  Row(Descriptor='Wear & Tear'),
#  Row(Descriptor='Illegal Conversion Of Manufacturing/Industrial Space'),
#  Row(Descriptor='Relocation of Muni Meter'),
#  Row(Descriptor='Accident/Explosion - Boiler'),
#  Row(Descriptor='WINDOW GUARD BROKEN/MISSING'),
#  Row(Descriptor='Trespassing'),
#  Row(Descriptor='Air: Dust, Residential (AE1)'),
#  Row(Descriptor='Poster or Sign'),
#  Row(Descriptor='Other Health Matters'),
#  Row(Descriptor='Accessibility Accommodations'),
#  Row(Descriptor='Elevator Not Inspected/Illegal/No Permit'),
#  Row(Descriptor='Construction Debris'),
#  Row(Descriptor='Wood Pole Leaning'),
#  Row(Descriptor='SIGNAGE'),
#  Row(Descriptor='Spilled Garbage'),
#  Row(Descriptor='For Violation'),
#  Row(Descriptor='MAILBOX'),
#  Row(Descriptor='Defacement'),
#  Row(Descriptor='E13 Throw-Out'),
#  Row(Descriptor='Maintenance Cover'),
#  Row(Descriptor='Foundation'),
#  Row(Descriptor='Accident - Elevator'),
#  Row(Descriptor='Lack of Safety Equipment'),
#  Row(Descriptor='Commercial DAMP Exemption'),
#  Row(Descriptor='Mitchell-Lama Housing List'),
#  Row(Descriptor='CABINETS'),
#  Row(Descriptor='Non-Compliance w/TTPN 1/00 - Vertical Enlargements'),
#  Row(Descriptor='Loud Music/Party'),
#  Row(Descriptor='Insurance Information Requested'),
#  Row(Descriptor='Food Protection'),
#  Row(Descriptor='Working Contrary To Stop Work Order'),
#  Row(Descriptor='High Water Pressure (WHP)'),
#  Row(Descriptor='Driver Complaint - Passenger'),
#  Row(Descriptor='Touchscreen/Button Not Working'),
#  Row(Descriptor='Licensed Home Improvement Contractor Bumper Sticker'),
#  Row(Descriptor='Bicycle Access Waiver Request - Elevator Safety'),
#  Row(Descriptor='ER1 Resident Recyc. (Owner/Manager'),
#  Row(Descriptor='Media Inquiries'),
#  Row(Descriptor='Warning Signal'),
#  Row(Descriptor='Delays'),
#  Row(Descriptor='Lack of Supplies'),
#  Row(Descriptor='Commercial UDAAP Exemption'),
#  Row(Descriptor='Ready NY - Reference Card'),
#  Row(Descriptor='Garage or Parking Lot License'),
#  Row(Descriptor='CSC - Monitoring Tracking'),
#  Row(Descriptor='Housing Quality Standards (HQS) Inspections FAQs - English'),
#  Row(Descriptor='Minor Access'),
#  Row(Descriptor='1 or 2'),
#  Row(Descriptor='Tree Alive - in Poor Condition'),
#  Row(Descriptor='In Prohibited Area'),
#  Row(Descriptor='Street Light Cycling'),
#  Row(Descriptor='Application Renewal'),
#  Row(Descriptor='Yield'),
#  Row(Descriptor='Rodent Bite - PCS Only'),
#  Row(Descriptor='Sign Blocked by Tree'),
#  Row(Descriptor='Best - Low-Rise Tracking Complaint'),
#  Row(Descriptor='Tow Truck Exemption License'),
#  Row(Descriptor='Mssg Sign Multi Lamp'),
#  Row(Descriptor='Lamppost Knocked Down'),
#  Row(Descriptor='Unsafe Chemical, Storage (HC1)'),
#  Row(Descriptor='EFT or Online Payment Problem'),
#  Row(Descriptor='In Public'),
#  Row(Descriptor='Broken Glass'),
#  Row(Descriptor='Police Report Requested'),
#  Row(Descriptor='Box Cover'),
#  Row(Descriptor='Unsafe Chemical, Unknown (HC3)'),
#  Row(Descriptor='Pedestrian Sign'),
#  Row(Descriptor='Unenroll from Advantage Program'),
#  Row(Descriptor='Other'),
#  Row(Descriptor='Payment Not Posted'),
#  Row(Descriptor='Push Button'),
#  Row(Descriptor='Cat'),
#  Row(Descriptor='Color'),
#  Row(Descriptor='City Rebate'),
#  Row(Descriptor='Minor Received Tattoo'),
#  Row(Descriptor='Trash or Recycling Not Secure'),
#  Row(Descriptor='Chronic'),
#  Row(Descriptor='Ready NY My Emergency Plan - Korean'),
#  Row(Descriptor='Tree Leaning/Uprooted'),
#  Row(Descriptor='Lighting'),
#  Row(Descriptor='3B Sweeping/Inadequate'),
#  Row(Descriptor='Transfer'),
#  Row(Descriptor='CP1 Employee Behavior-Bcc'),
#  Row(Descriptor='Material Stored Improperly'),
#  Row(Descriptor='Ventilation'),
#  Row(Descriptor='Elevator - Dangerous Condition/Shaft Open/Unguarded'),
#  Row(Descriptor='Gas Station'),
#  Row(Descriptor='No Statement of Job Conditions'),
#  Row(Descriptor='Status Call'),
#  Row(Descriptor='For One Address'),
#  Row(Descriptor='3 or More'),
#  Row(Descriptor='Price Not Posted'),
#  Row(Descriptor='Snow/Ice'),
#  Row(Descriptor='"E4 18"" Law"'),
#  Row(Descriptor='Turn Signal'),
#  Row(Descriptor='Animal Boarding License'),
#  Row(Descriptor='Trash or Recycling'),
#  Row(Descriptor='Street Cave-In'),
#  Row(Descriptor='Milk/Dairy Products'),
#  Row(Descriptor='Debris'),
#  Row(Descriptor='Property Misclassified'),
#  Row(Descriptor='Failure To Retain Water/Improper Drainage- (LL103/89)'),
#  Row(Descriptor='Construction and Technical Services'),
#  Row(Descriptor='RPIE - Filing and Technical Issues'),
#  Row(Descriptor='Bulk Recycling'),
#  Row(Descriptor='Double Parked Blocking Traffic'),
#  Row(Descriptor='Glassware Missing'),
#  Row(Descriptor='WiFi/Internet Not Working/Slow'),
#  Row(Descriptor='Electronics/Phones'),
#  Row(Descriptor='New Basket'),
#  Row(Descriptor='Capital Construction'),
#  Row(Descriptor='Full Term Tattoo License'),
#  Row(Descriptor='Other Hazmat Problem (HZZ)'),
#  Row(Descriptor='Fire Alarm Lamp Missing'),
#  Row(Descriptor='Permanent Amusement Device License'),
#  Row(Descriptor='About NYC Opportunity'),
#  Row(Descriptor='Facility General'),
#  Row(Descriptor='15X ICE-SNOW COND./PEDESTRN ACCESS'),
#  Row(Descriptor='Obstructing Public Use'),
#  Row(Descriptor='Support Bracket'),
#  Row(Descriptor='Street Con Game'),
#  Row(Descriptor='Wood Pole Knocked Down'),
#  Row(Descriptor='Process Server Organization License'),
#  Row(Descriptor='Garbage or Litter'),
#  Row(Descriptor='Base Door'),
#  Row(Descriptor='Illegal Tree Removal/Topo. Change in SNAD'),
#  Row(Descriptor='Fixture/Luminaire Missing'),
#  Row(Descriptor='Fallen Debris from Bridge'),
#  Row(Descriptor='Damaged or Missing Ad Box'),
#  Row(Descriptor='Asbestos'),
#  Row(Descriptor='Car Rental'),
#  Row(Descriptor='No Private Carter'),
#  Row(Descriptor='Hurricane Preparedness - Yiddish'),
#  Row(Descriptor='Plate Missing/Moved-Exposing Hole (WF4)'),
#  Row(Descriptor='Inadequate Sweeping'),
#  Row(Descriptor='American Flag'),
#  Row(Descriptor='Second Avenue Subway Construction'),
#  Row(Descriptor='Building Shaking/Vibrating/Structural Stability'),
#  Row(Descriptor='Ready NY - Polish - Full Size'),
#  Row(Descriptor='ELECTRIC-SUPPLY'),
#  Row(Descriptor='Process Server'),
#  Row(Descriptor='School Safety'),
#  Row(Descriptor='Check Lost or Not Received'),
#  Row(Descriptor='Temporary Amusement Device License'),
#  Row(Descriptor='Highway Tracking'),
#  Row(Descriptor='Catch Basin Sunken/Damaged/Raised (SC1)'),
#  Row(Descriptor='OUTLET COVER'),
#  Row(Descriptor='RAIN LEADER'),
#  Row(Descriptor='Child or Minor Tanning'),
#  Row(Descriptor='15 Street Cond/Dump-Out/Drop-Off'),
#  Row(Descriptor='Summer Heat - English'),
#  Row(Descriptor='Dirty/Inadequate Eqp/Facility'),
#  Row(Descriptor='PLANTS- OTHER RELATED PROBLEMS FOR DEP INTERNAL USE ONLY'),
#  Row(Descriptor='Summer Heat - Russian'),
#  Row(Descriptor='Banging/Pounding'),
#  Row(Descriptor='Sewage'),
#  Row(Descriptor='2S Bulk-Storm Related'),
#  Row(Descriptor='"Smoking Signs - ""No Smoking"" Signs Not Observed on Construction Site"'),
#  Row(Descriptor='Air: Dust, Commercial (AE2)'),
#  Row(Descriptor='6 Overflowing Litter Baskets'),
#  Row(Descriptor='ER2 Resident Recyc. (Tenant)'),
#  Row(Descriptor='SIGNAGE MISSING'),
#  Row(Descriptor='In Post Base'),
#  Row(Descriptor='Rooftank Leak Or Overflow (CKO)'),
#  Row(Descriptor='Damaged Leg or Pole Bent'),
#  Row(Descriptor='Catering Establishment License'),
#  Row(Descriptor='EXPY Sign Reflector'),
#  Row(Descriptor='Trash Not Separated from Recycling'),
#  Row(Descriptor='12 Dead Animals'),
#  Row(Descriptor='2 Bulk-Missed Collection'),
#  Row(Descriptor='Pigeon Waste'),
#  Row(Descriptor='Bodega/Deli/Supermarket'),
#  Row(Descriptor='Construction'),
#  Row(Descriptor='1C Uncollected Xmas Trees'),
#  Row(Descriptor='Hangers'),
#  Row(Descriptor='Compressed Air License'),
#  Row(Descriptor='C1 Request Xmas Trees Collection'),
#  Row(Descriptor='Coax Cable'),
#  Row(Descriptor='Billing Address Incorrect'),
#  Row(Descriptor='Lamppost Base Door/Cover Missing'),
#  Row(Descriptor='Excessive Water In Basement (WEFB)'),
#  Row(Descriptor='Relocation of Parking Meter'),
#  Row(Descriptor='Locker Break-in/Incident'),
#  Row(Descriptor='Cash Assistance'),
#  Row(Descriptor='Newsstand License'),
#  Row(Descriptor='Air: Odor/Fumes, Private Carting (AD4)'),
#  Row(Descriptor='Recycling - Metal/Glass/Rigid Plastic'),
#  Row(Descriptor='Emergency Notice'),
#  Row(Descriptor='Annual Report'),
#  Row(Descriptor='Blocked - Construction'),
#  Row(Descriptor='Furniture Store'),
#  Row(Descriptor='ER6 Comm. Recyc. (Comm. Tenant)'),
#  Row(Descriptor='Underage - Licensed Est'),
#  Row(Descriptor='Personal Exemptions'),
#  Row(Descriptor='Abandoned'),
#  Row(Descriptor='LOCKS'),
#  Row(Descriptor='Damaged Door'),
#  Row(Descriptor='No Access'),
#  Row(Descriptor='POWER OUTAGE'),
#  Row(Descriptor='Detached Trailer'),
#  Row(Descriptor='Vehicle Signal'),
#  Row(Descriptor='Home Improvement Contractor'),
#  Row(Descriptor='Absent'),
#  Row(Descriptor='Bracket Arm Loose'),
#  Row(Descriptor='APS'),
#  Row(Descriptor='Tax Preparer'),
#  Row(Descriptor='Removing Flowers/Plants'),
#  Row(Descriptor='Interior Demo Tracking Complaint'),
#  Row(Descriptor='Construction Safety Compliance Action'),
#  Row(Descriptor='Scrap Metal Processor'),
#  Row(Descriptor='Poison Ivy'),
#  Row(Descriptor='OUTLET/SWITCH'),
#  Row(Descriptor='Ferret'),
#  Row(Descriptor='Electronic Fund Transfer (EFT) Problem'),
#  Row(Descriptor='Hotel'),
#  Row(Descriptor='Sidewalk Zone Blocked'),
#  Row(Descriptor='Hurricane Preparedness - Chinese'),
#  Row(Descriptor='Ver Message Sign'),
#  Row(Descriptor='Driver Report'),
#  Row(Descriptor='Traffic Signal Light'),
#  Row(Descriptor='St Name - Over Intersection'),
#  Row(Descriptor='Sidewalk Grating - Defective'),
#  Row(Descriptor='Demolition - Unsafe'),
#  Row(Descriptor='Beach/Pool Closure'),
#  Row(Descriptor='Certificate of No Harassment - Zoning'),
#  Row(Descriptor='Recycling Electronics'),
#  Row(Descriptor='Wall/Retaining Wall - Bulging/Cracked'),
#  Row(Descriptor='Fence - None/Inadequate'),
#  Row(Descriptor='Re-Inspect - No Show'),
#  Row(Descriptor='Illegal Use Of Hose - Private Residence  (CCR)'),
#  Row(Descriptor='Veh Signal Lens'),
#  Row(Descriptor='Petroleum Spill (HE1)'),
#  Row(Descriptor='Sightseeing Guide License'),
#  Row(Descriptor='Dirt, Litter, Debris - Garage'),
#  Row(Descriptor='Opossum'),
#  Row(Descriptor='EXPY Lamp'),
#  Row(Descriptor='WINDOW/FRAME'),
#  Row(Descriptor='Unauthorized Tree Pruning'),
#  Row(Descriptor='Site Setup Condition'),
#  Row(Descriptor='DOOR TO DUMBWAITER'),
#  Row(Descriptor='Illness/Injury'),
#  Row(Descriptor='Conduit'),
#  Row(Descriptor='Beach/Pool/Sauna Unpermitted'),
#  Row(Descriptor='Barrier Condition'),
#  Row(Descriptor='Depression Maintenance'),
#  Row(Descriptor='Inspection Work Order (DOB)'),
#  Row(Descriptor='Electronics and Home Appliance Service Dealer License'),
#  Row(Descriptor='No Bill of Rights'),
#  Row(Descriptor='Graffiti - Highway'),
#  Row(Descriptor='E12 Illegal Dumping Surveillance'),
#  Row(Descriptor='Noise: Alarms (NR3)'),
#  Row(Descriptor='Other Agency Charge'),
#  Row(Descriptor='Taste/Odor, Sewer (QA5)'),
#  Row(Descriptor='Waterway-Sewage (IHA)'),
#  Row(Descriptor='Restrooms'),
#  Row(Descriptor='Seasonal Mobile Food Vendor License'),
#  Row(Descriptor='Controller Cabinet'),
#  Row(Descriptor='Unlicensed Vendors'),
#  Row(Descriptor='Vehicle Report'),
#  Row(Descriptor='Snake'),
#  Row(Descriptor='Ready NY - English - Pocket Size'),
#  Row(Descriptor='Demolition Notification Received'),
#  Row(Descriptor='Storage Warehouse'),
#  Row(Descriptor='Payment Made to Wrong BBL'),
#  Row(Descriptor='Gaming Cafe'),
#  Row(Descriptor='Monopole Tracking Complaint'),
#  Row(Descriptor='Cave-in'),
#  Row(Descriptor='No Water (WNW)'),
#  Row(Descriptor='Dead Animal'),
#  Row(Descriptor='Lamppost Leaning'),
#  Row(Descriptor='Rough Pavement'),
#  Row(Descriptor='Puddle in Ground'),
#  Row(Descriptor='Container - Under 5 Gallons'),
#  Row(Descriptor='Chained to Public Property'),
#  Row(Descriptor='Det-Sens Cabinet'),
#  Row(Descriptor='Secondhand Dealer Firearms License'),
#  Row(Descriptor='Dust from Construction'),
#  Row(Descriptor='Street Light Lamp Missing'),
#  Row(Descriptor='Use Outside'),
#  Row(Descriptor='Facility Construction'),
#  Row(Descriptor='Over Capacity'),
#  Row(Descriptor='Elevator - Single Device On Property/No Alternate Service'),
#  Row(Descriptor='Sign Defect - Garage'),
#  Row(Descriptor='Electronic Sign - Portable'),
#  Row(Descriptor='Vaccine Rules Not Posted'),
#  Row(Descriptor='Special Education'),
#  Row(Descriptor='Pedestrian Signal'),
#  Row(Descriptor='Sign/Awning/Marquee - Illegal/No Permit'),
#  Row(Descriptor='Food Temperature'),
#  Row(Descriptor='Demand for Cash'),
#  Row(Descriptor='Swimming Pool - Unmaintained'),
#  Row(Descriptor='Staff/Supervision/Permits'),
#  Row(Descriptor='HOUSING QUALITY STANDARDS'),
#  Row(Descriptor='Social Distancing'),
#  Row(Descriptor='Sodium Warning'),
#  Row(Descriptor='Ready NY - Chinese Simplified - Full Size'),
#  Row(Descriptor='Pool/Billiard Hall'),
#  Row(Descriptor='Gas Hook-Up/Piping - Illegal Or Defective'),
#  Row(Descriptor='Permit/License/Certificate'),
#  Row(Descriptor='Status of PV Refund'),
#  Row(Descriptor='BOILER'),
#  Row(Descriptor='Cellar Door Defective'),
#  Row(Descriptor='PORCH/BALCONY'),
#  Row(Descriptor='Biking/Rollerblading off Path'),
#  Row(Descriptor='Ready NY - Businesses - English'),
#  Row(Descriptor='Language Access Coordinator'),
#  Row(Descriptor='Highway Fence'),
#  Row(Descriptor='Gender Pricing'),
#  Row(Descriptor='Noise'),
#  Row(Descriptor='Car/Truck Horn'),
#  Row(Descriptor='Unleashed Dog in Public'),
#  Row(Descriptor='Veh Signal Head'),
#  Row(Descriptor='News Gathering'),
#  Row(Descriptor='Concrete Barrier'),
#  Row(Descriptor='High Pressure to Take on Loan/Debt'),
#  Row(Descriptor='Locksmith Apprentice License'),
#  Row(Descriptor='GAS'),
#  Row(Descriptor='V.E.S.T. Program (DOB & NYPD)'),
#  Row(Descriptor='Defective Catch Basin'),
#  Row(Descriptor='Broken Sidewalk'),
#  Row(Descriptor='FOIL Request - Request for Records'),
#  Row(Descriptor='Filing and Technical Issues'),
#  Row(Descriptor='Oil, Grease In Water (QD1)'),
#  Row(Descriptor='Affecting Sewer or Foundation'),
#  Row(Descriptor='Noise, Ice Cream Truck (NR4)'),
#  Row(Descriptor='Food Worker Activity'),
#  Row(Descriptor='Hitting Phone/Cable Lines'),
#  Row(Descriptor='Excavation Tracking Complaint'),
#  Row(Descriptor='ERR Other Request For Recyc. Enf'),
#  Row(Descriptor='No Receipt'),
#  Row(Descriptor='Cable'),
#  Row(Descriptor='Non-Disclosure of Fees'),
#  Row(Descriptor='Noise: Manufacturing Noise (NK1)'),
#  Row(Descriptor='Time Clock Maladjusted'),
#  Row(Descriptor='Damaged Other'),
#  Row(Descriptor='WATER-SUPPLY'),
#  Row(Descriptor='Deer'),
#  Row(Descriptor='Plumbing Enforcement Work Order (DOB)'),
#  Row(Descriptor='Certificate of No Harassment or Exemption - SRO'),
#  Row(Descriptor='Multi Agency Joint Inspection'),
#  Row(Descriptor='Medicaid'),
#  Row(Descriptor='Congestion/Gridlock'),
#  Row(Descriptor='STEAM PIPE/RISER'),
#  Row(Descriptor='No Dial Tone'),
#  Row(Descriptor='Egress - Doors Locked/Blocked/Improper/No Secondary Means'),
#  Row(Descriptor='Citywide Procurement'),
#  Row(Descriptor='Pedicab Driver'),
#  Row(Descriptor='Animal Training License'),
#  Row(Descriptor='Squirrel'),
#  Row(Descriptor='Driver Complaint'),
#  Row(Descriptor='Pothole'),
#  Row(Descriptor='Street Light Feed'),
#  Row(Descriptor='Sewage Leak'),
#  Row(Descriptor='installation of hydrant side post (WHFP)'),
#  Row(Descriptor='Disbursement Form Request'),
#  Row(Descriptor='Housing Quality Standards (HQS) Inspections FAQs - Spanish'),
#  Row(Descriptor='Debris - Falling Or In Danger Of Falling'),
#  Row(Descriptor='Foreign Attachment On Lamppost'),
#  Row(Descriptor='Wasting Faucets,Sinks,Flushometer,Urinal,Etc. - Other (CWO)'),
#  Row(Descriptor='DOORS'),
#  Row(Descriptor='SMOKE-DETECTOR'),
#  Row(Descriptor='Monkey'),
#  Row(Descriptor='Public Event Seating'),
#  Row(Descriptor='BASIN/SINK'),
#  Row(Descriptor='Air: Smoke, Vehicular (AA4)'),
#  Row(Descriptor='15N Needle/Syringe on Street/Sidewalk'),
#  Row(Descriptor='Advance Fee'),
#  Row(Descriptor='Illegal Commercial Or Manufacturing Use In a C1 Or C2 Zone'),
#  Row(Descriptor='Odor'),
#  Row(Descriptor='Do Not Enter'),
#  ...]

# %% [markdown]
# "Location Type" column is generally uniform except for a single row with the value "RESIDENTIAL BUILDING".

# %%
# View column "Location Type"
df.select("Location Type").distinct().collect()
# Out:
# [Row(Location Type='Apartment'),
#  Row(Location Type='House and Store'),
#  Row(Location Type='Ferry'),
#  Row(Location Type='Private School'),
#  Row(Location Type='Other (Explain Below)'),
#  Row(Location Type='Public Park/Garden'),
#  Row(Location Type='Roadway'),
#  Row(Location Type='Loft Residence'),
#  Row(Location Type='Condo Unit'),
#  Row(Location Type='Cafeteria'),
#  Row(Location Type='House of Worship'),
#  Row(Location Type='Store/Commercial'),
#  Row(Location Type='1-3 Family Mixed Use Building'),
#  Row(Location Type='Building (Non-Residential)'),
#  Row(Location Type='Public Area'),
#  Row(Location Type='Golf'),
#  Row(Location Type='Home'),
#  Row(Location Type='Grocery Store'),
#  Row(Location Type='Street Vendor'),
#  Row(Location Type='Cafeteria - Private School'),
#  Row(Location Type='Tanning Salon'),
#  Row(Location Type='Abandoned Building'),
#  Row(Location Type='Cemetery'),
#  Row(Location Type='Subway'),
#  Row(Location Type='Street Fair Vendor'),
#  Row(Location Type='Co-Op Unit'),
#  Row(Location Type='Parking Lot'),
#  Row(Location Type='Roadway Tunnel'),
#  Row(Location Type='Bar/Restaurant'),
#  Row(Location Type='Construction Site'),
#  Row(Location Type='Terminal'),
#  Row(Location Type='Vacant Land'),
#  Row(Location Type='Sauna'),
#  Row(Location Type='Health Club or Gym'),
#  Row(Location Type='Senior Address'),
#  Row(Location Type='Residential'),
#  Row(Location Type='Bike Lane'),
#  Row(Location Type='Senior Center'),
#  Row(Location Type='Public Garden'),
#  Row(Location Type='Petting Zoo/Animal Exhibit'),
#  Row(Location Type='Mixed Use'),
#  Row(Location Type='School/Pre-School'),
#  Row(Location Type=None),
#  Row(Location Type='Above Address'),
#  Row(Location Type='Cafeteria - Public School'),
#  Row(Location Type='Building-Wide'),
#  Row(Location Type='Residential Building/House'),
#  Row(Location Type='School'),
#  Row(Location Type='Swamp or Pond'),
#  Row(Location Type='Commercial Property'),
#  Row(Location Type='Traffic Island or Median'),
#  Row(Location Type='School - K-12 Private'),
#  Row(Location Type='Community Organization'),
#  Row(Location Type='Street Area'),
#  Row(Location Type='Retail Store'),
#  Row(Location Type='Street'),
#  Row(Location Type="Dentist's Office"),
#  Row(Location Type='Catering Hall'),
#  Row(Location Type='3+ Family Apartment Building'),
#  Row(Location Type='Horse Stable'),
#  Row(Location Type='Intersection'),
#  Row(Location Type='Soup Kitchen'),
#  Row(Location Type='Day Care/Nursery'),
#  Row(Location Type='Government/Not-for Profit'),
#  Row(Location Type='Residential Building'),
#  Row(Location Type='Non-Profit'),
#  Row(Location Type='Beach'),
#  Row(Location Type='Common Area'),
#  Row(Location Type='Permanent Food Stand'),
#  Row(Location Type='Club/Bar/Restaurant'),
#  Row(Location Type='Lot'),
#  Row(Location Type='Street/Curbside'),
#  Row(Location Type='Airport or Train/Bus Station'),
#  Row(Location Type='3+Family Apt.'),
#  Row(Location Type='Sidewalk'),
#  Row(Location Type='Street/Sidewalk'),
#  Row(Location Type='Property Address'),
#  Row(Location Type='Roof'),
#  Row(Location Type='3+ Family Mixed Use Building'),
#  Row(Location Type='Other'),
#  Row(Location Type='Office Building'),
#  Row(Location Type='Wooded Area'),
#  Row(Location Type='Speed Reducer'),
#  Row(Location Type='Homeless Shelter'),
#  Row(Location Type='Medical Facility'),
#  Row(Location Type='Taxi'),
#  Row(Location Type='P.O. Box'),
#  Row(Location Type='Bridge'),
#  Row(Location Type='1-2 FamilyDwelling'),
#  Row(Location Type='Store'),
#  Row(Location Type='Public Stairs'),
#  Row(Location Type='Hallway'),
#  Row(Location Type='Pool'),
#  Row(Location Type='Vacant Lot/Property'),
#  Row(Location Type="DRIE Tenant's Address"),
#  Row(Location Type='Garage'),
#  Row(Location Type='Building Entrance'),
#  Row(Location Type='Government Building - Foreign'),
#  Row(Location Type='Parking Lot/Garage'),
#  Row(Location Type='Residential Property'),
#  Row(Location Type='Health Club'),
#  Row(Location Type='Overpass'),
#  Row(Location Type='Public/Unfenced Area'),
#  Row(Location Type='Utility'),
#  Row(Location Type='1-, 2- and 3- Family Home'),
#  Row(Location Type="Doctor's Office"),
#  Row(Location Type='Correctional Facility - City'),
#  Row(Location Type='Address Unknown'),
#  Row(Location Type='Public Plaza'),
#  Row(Location Type='Private House'),
#  Row(Location Type='Private Residence'),
#  Row(Location Type='Subway Station'),
#  Row(Location Type='Restaurant/Bar/Deli/Bakery'),
#  Row(Location Type='Single Room Occupancy (SRO)'),
#  Row(Location Type='Vehicle Lane'),
#  Row(Location Type='Service Provider'),
#  Row(Location Type='Sports Arena'),
#  Row(Location Type='Bridge/Underpass'),
#  Row(Location Type='Private Property'),
#  Row(Location Type='Bus Stop Shelter'),
#  Row(Location Type='Alley'),
#  Row(Location Type='3+ Family Apt. Building'),
#  Row(Location Type='Pvt Residnt Proprty'),
#  Row(Location Type='Caller Address'),
#  Row(Location Type='Stairwell'),
#  Row(Location Type='Recreation Center'),
#  Row(Location Type='N/A'),
#  Row(Location Type='Crosswalk'),
#  Row(Location Type='Hospital'),
#  Row(Location Type='School Safety Zone'),
#  Row(Location Type='Apartment Building'),
#  Row(Location Type='Restaurant'),
#  Row(Location Type='Park/Playground'),
#  Row(Location Type='Summer Camp'),
#  Row(Location Type='Gutter'),
#  Row(Location Type='Street Address'),
#  Row(Location Type='Kennel/Animal Shelter'),
#  Row(Location Type='Nursing Home'),
#  Row(Location Type='Business'),
#  Row(Location Type='Pier'),
#  Row(Location Type='Cafeteria - Private'),
#  Row(Location Type='Public School'),
#  Row(Location Type='Mobile Food Vendor'),
#  Row(Location Type='Comercial'),
#  Row(Location Type='3+ Family Mixed'),
#  Row(Location Type='School - College/University'),
#  Row(Location Type='3+ Family'),
#  Row(Location Type='3+ Family ApT'),
#  Row(Location Type='Address Outside of NYC'),
#  Row(Location Type='1-2 Family Mixed Use Building'),
#  Row(Location Type='Steam Room'),
#  Row(Location Type='Food Cart Vendor'),
#  Row(Location Type='RESIDENTIAL BUILDING'),
#  Row(Location Type='Tattoo Parlor'),
#  Row(Location Type='NYC Street Address'),
#  Row(Location Type='Park'),
#  Row(Location Type='Ground'),
#  Row(Location Type='1-2 Family Dwelling'),
#  Row(Location Type='3+ Family Apt.'),
#  Row(Location Type='Correctional Facility - State'),
#  Row(Location Type='School - K-12 Public'),
#  Row(Location Type='Commercial Building'),
#  Row(Location Type='Lobby'),
#  Row(Location Type='Loft Building - Common Areas'),
#  Row(Location Type='Curb'),
#  Row(Location Type='Theater'),
#  Row(Location Type='Yard'),
#  Row(Location Type='Tire Shop'),
#  Row(Location Type='1-3 Family Dwelling'),
#  Row(Location Type='Catering Service'),
#  Row(Location Type='Commercial'),
#  Row(Location Type='Highway'),
#  Row(Location Type='Cafeteria - College/University'),
#  Row(Location Type='Vacant Building'),
#  Row(Location Type='Street and Sidewalk'),
#  Row(Location Type='Catch Basin/Sewer'),
#  Row(Location Type='Other (explain in Complaint Details)'),
#  Row(Location Type='Address'),
#  Row(Location Type='Residence'),
#  Row(Location Type='Public Garden/Park'),
#  Row(Location Type='Groomer'),
#  Row(Location Type='Spa Pool'),
#  Row(Location Type='Vacant Lot'),
#  Row(Location Type='Tenant Address'),
#  Row(Location Type='Building'),
#  Row(Location Type='Government Building'),
#  Row(Location Type='Green Cart Vendor'),
#  Row(Location Type='Pet Shop')]

# %% [markdown]
# "Street Name" column has nonuniform casing as well (ex: one row has "east gun hill road" while majority of the rows are uppercased like "ALBERTA AVE").

# %%
# View column "Street Name" 
df.select("Street Name").distinct().collect()
# Out:
# [Row(Street Name='47 AVENUE'),
#  Row(Street Name='WEST  148 STREET'),
#  Row(Street Name='148 AVENUE'),
#  Row(Street Name='KING STREET'),
#  Row(Street Name='THORNHILL AVENUE'),
#  Row(Street Name='SHARON AVENUE'),
#  Row(Street Name='150 PLACE'),
#  Row(Street Name='BARCLAY AVENUE'),
#  Row(Street Name='WELDON STREET'),
#  Row(Street Name='STARR STREET'),
#  Row(Street Name='RUPERT AVENUE'),
#  Row(Street Name='WEST   46 STREET'),
#  Row(Street Name='132 AVENUE'),
#  Row(Street Name='EAST 232 STREET'),
#  Row(Street Name='205 PLACE'),
#  Row(Street Name='HONEYWELL STREET'),
#  Row(Street Name='EAST 145 STREET'),
#  Row(Street Name='MUNDY LANE'),
#  Row(Street Name='COURT SQUARE'),
#  Row(Street Name='MACORMAC PLACE'),
#  Row(Street Name='EAST  121 STREET'),
#  Row(Street Name='WEST 12 STREET'),
#  Row(Street Name='ANNA DALE ROAD'),
#  Row(Street Name='BEACH  105 STREET'),
#  Row(Street Name='ABINGDON ROAD'),
#  Row(Street Name='BETHUNE STREET'),
#  Row(Street Name='WILLETT AVENUE'),
#  Row(Street Name="ST ANTHONY'S PLACE"),
#  Row(Street Name='TIFFANY PLACE'),
#  Row(Street Name='BEACH 99 STREET'),
#  Row(Street Name='COURTNEY LOOP'),
#  Row(Street Name='KETCHAM STREET'),
#  Row(Street Name='140TH STREET'),
#  Row(Street Name='KNOLLWOOD AVENUE'),
#  Row(Street Name='VISTA PLACE'),
#  Row(Street Name='MCCORMICK PLACE'),
#  Row(Street Name='68TH AVE'),
#  Row(Street Name='GRAND CENTRAL PARKWAY NORTH'),
#  Row(Street Name='ANDREA COURT'),
#  Row(Street Name='JOSEPH LANE'),
#  Row(Street Name='HYLAND BLVD'),
#  Row(Street Name='8 ST W'),
#  Row(Street Name='LEWISTON AVENUE'),
#  Row(Street Name='OSBOURNE PLACE'),
#  Row(Street Name='HARLEM RIVER PARK BRIDGE'),
#  Row(Street Name='CORLEARS HOOK PARK'),
#  Row(Street Name='SHERIDAN AVE'),
#  Row(Street Name='MARVIN STREET'),
#  Row(Street Name='NEVINS ST'),
#  Row(Street Name='VAUGHAN STREET'),
#  Row(Street Name='WEST LOOP ROAD'),
#  Row(Street Name='BARROWS COURT'),
#  Row(Street Name='HARDING CAMP'),
#  Row(Street Name='ROSE STREET'),
#  Row(Street Name='PRINCEWOOD AVENUE'),
#  Row(Street Name='87TH DRIVE'),
#  Row(Street Name='10TH AVENUE'),
#  Row(Street Name='CLINTON COURT'),
#  Row(Street Name='EAST 132ND STREET'),
#  Row(Street Name='14th ave'),
#  Row(Street Name='103 ESSEX ST'),
#  Row(Street Name='WEST 10 ROAD'),
#  Row(Street Name='RICHE AVENUE'),
#  Row(Street Name='RANDALLS ISLAND'),
#  Row(Street Name='DAVID MARCUS MEMORIAL PLGD'),
#  Row(Street Name='LEON S KAISER PLGD'),
#  Row(Street Name='ALBEE SQR'),
#  Row(Street Name='BOX'),
#  Row(Street Name='STREET ROAD'),
#  Row(Street Name='240TH ST'),
#  Row(Street Name='ASSER LEVY PARK AQUARIUM'),
#  Row(Street Name='PS149 PLGD NORTHERN'),
#  Row(Street Name='FORT HILL PARK'),
#  Row(Street Name='WEST 10TH ROAD'),
#  Row(Street Name='EAST 38TH STREET'),
#  Row(Street Name='SETON HOSPITAL SITE'),
#  Row(Street Name='WEST FIFTH STREET'),
#  Row(Street Name='MILL AVE'),
#  Row(Street Name='E 56TH ST'),
#  Row(Street Name='TERMINAL C'),
#  Row(Street Name='TOWER ROAD'),
#  Row(Street Name='9030'),
#  Row(Street Name='PENINTULA BLVD.'),
#  Row(Street Name='GERALD H CHAMBERS SQUARE'),
#  Row(Street Name='CORBETT RD'),
#  Row(Street Name='GARFIELD ST'),
#  Row(Street Name='E 31 ST'),
#  Row(Street Name='W 110 ST'),
#  Row(Street Name='ARGYLE RD'),
#  Row(Street Name='33 RD'),
#  Row(Street Name='94 RD'),
#  Row(Street Name='THROGS NECK BLVD'),
#  Row(Street Name='PLAZA ST'),
#  Row(Street Name='KIMBALL RD'),
#  Row(Street Name='MILFORD ST'),
#  Row(Street Name='20-09 STEINWAY STREET'),
#  Row(Street Name='BAYSIDE FIELDS'),
#  Row(Street Name='BARTHOLDI ST'),
#  Row(Street Name='CLEOPATRA PLGD'),
#  Row(Street Name='POYER ST'),
#  Row(Street Name='ASCOT AVENUE'),
#  Row(Street Name='CROSS RD'),
#  Row(Street Name='89th street'),
#  Row(Street Name='601 182 street'),
#  Row(Street Name='PS   68'),
#  Row(Street Name='879 wyckoff ave'),
#  Row(Street Name='bivona st'),
#  Row(Street Name='VANDERVORT AVENUE'),
#  Row(Street Name='3502 HULL AVENUE'),
#  Row(Street Name='KINGS HIGHWAY HWY'),
#  Row(Street Name='richmond road'),
#  Row(Street Name='CONC VILLAGE EAST'),
#  Row(Street Name='INTERNATIONAL AIRPORT CENTER BL'),
#  Row(Street Name='E 57TH ST'),
#  Row(Street Name='W  WASHINGTON ST'),
#  Row(Street Name='ROCKAAY BLVD'),
#  Row(Street Name='GLENNON PL'),
#  Row(Street Name='S OGDEN ST'),
#  Row(Street Name='BRONX RIVER PARKWAY NB ET    8 W'),
#  Row(Street Name='101 JAMES DOOLITTLE BLVD UNIONDALE, NY 11553'),
#  Row(Street Name='145 ST W PARK'),
#  Row(Street Name='SYLVAN PL'),
#  Row(Street Name='19TH DRIVE'),
#  Row(Street Name='LA GUARDIA HOUSES'),
#  Row(Street Name='HAMILTON PLAYGROUND'),
#  Row(Street Name='TINTON AVENUE'),
#  Row(Street Name='ADRIAN AVENUE'),
#  Row(Street Name='WEST  218 STREET'),
#  Row(Street Name='SCHENECTADY AVENUE'),
#  Row(Street Name='EAST   29 STREET'),
#  Row(Street Name='27 AVENUE'),
#  Row(Street Name='FREEMAN STREET'),
#  Row(Street Name='GREENWICH STREET'),
#  Row(Street Name='HILL STREET'),
#  Row(Street Name='WHITEWOOD AVENUE'),
#  Row(Street Name='DISOSWAY PLACE'),
#  Row(Street Name='WILLOWWOOD LANE'),
#  Row(Street Name='EAST 222 STREET'),
#  Row(Street Name='DAHILL ROAD'),
#  Row(Street Name='POWELL AVENUE'),
#  Row(Street Name='26 STREET'),
#  Row(Street Name='CHISHOLM STREET'),
#  Row(Street Name='WEST 1 STREET'),
#  Row(Street Name='MACOMBS PLACE'),
#  Row(Street Name='WEST   39 STREET'),
#  Row(Street Name='HASTINGS STREET'),
#  Row(Street Name='MAYBERRY PROMENADE'),
#  Row(Street Name='HECKER STREET'),
#  Row(Street Name='WEST 167 STREET'),
#  Row(Street Name='MC DERMOTT AVENUE'),
#  Row(Street Name='BENNETT COURT'),
#  Row(Street Name='BENT STREET'),
#  Row(Street Name='WHITMAN AVENUE'),
#  Row(Street Name='PAUW STREET'),
#  Row(Street Name='BAY 19 STREET'),
#  Row(Street Name='ROWLAND STREET'),
#  Row(Street Name='EDSALL AVE'),
#  Row(Street Name='8 ST E'),
#  Row(Street Name='WASHINGTON SQUARE NORTH'),
#  Row(Street Name='IVAN COURT'),
#  Row(Street Name='228 ST E'),
#  Row(Street Name='MOTLEY AVENUE'),
#  Row(Street Name='JAMES COURT'),
#  Row(Street Name='FOREST  AVE'),
#  Row(Street Name='TENEYCK WALK'),
#  Row(Street Name='FRANK D OCONNOR PLGD'),
#  Row(Street Name='CHARLECOTE RDG'),
#  Row(Street Name='SILVERLAKE ROAD'),
#  Row(Street Name='PUTNAM AVENUE WEST'),
#  Row(Street Name='MONTICELLO TERRACE'),
#  Row(Street Name='LILLIAN PLACE'),
#  Row(Street Name='66TH STREET'),
#  Row(Street Name='GROVER CLEVELAND PLGD'),
#  Row(Street Name='VERMILYEA'),
#  Row(Street Name='LT LIA PLGD'),
#  Row(Street Name='west 167 street'),
#  Row(Street Name='PROSPECT EXPY'),
#  Row(Street Name='CLOVIS ROAD'),
#  Row(Street Name='CROMMELIN STREET'),
#  Row(Street Name='PACAFIC STREET'),
#  Row(Street Name='LAMA COURT'),
#  Row(Street Name='IRWIN STREET'),
#  Row(Street Name='COLD SPRING ROAD'),
#  Row(Street Name='QUEENS WALK'),
#  Row(Street Name='GEN GEORGE J LAWRENCE SQR'),
#  Row(Street Name='MILWAUKEE AVENUE'),
#  Row(Street Name='LAKEVIEW BOULEVARD EAST'),
#  Row(Street Name='86TH AVENUE'),
#  Row(Street Name='WEST SECOND STREET'),
#  Row(Street Name='2236 E 59 PLACE'),
#  Row(Street Name='NORTH 8TH STREET'),
#  Row(Street Name='DE SALES PL'),
#  Row(Street Name='BRIGHTN 6ST STREET'),
#  Row(Street Name='WILLOW RD E'),
#  Row(Street Name='READE ST'),
#  Row(Street Name='CROMWELL AVE'),
#  Row(Street Name='WELLS AVENUE'),
#  Row(Street Name='9003'),
#  Row(Street Name='214 ST E'),
#  Row(Street Name='GRENADA PL'),
#  Row(Street Name='ALEXANDER AVE'),
#  Row(Street Name='BRUCKNER AVE'),
#  Row(Street Name='MERRILL ST'),
#  Row(Street Name='WIMAN PL'),
#  Row(Street Name='144 RD'),
#  Row(Street Name='BEACH 115 ST'),
#  Row(Street Name='BRONXDALE AVE'),
#  Row(Street Name='BEACH 79 ST'),
#  Row(Street Name='VAN BRUNT ST'),
#  Row(Street Name='ST MARYS AVE'),
#  Row(Street Name='HALPERIN AVE'),
#  Row(Street Name='BIRCHALL AVE'),
#  Row(Street Name='COBBLE HILL PARK'),
#  Row(Street Name='HALPIN AVE'),
#  Row(Street Name='MAHONEY PLAYGROUND'),
#  Row(Street Name='HUDSON RIVER PARKWAY'),
#  Row(Street Name='PLAINVIEW AVE'),
#  Row(Street Name='VESUVIO PLGD'),
#  Row(Street Name='EAST RIV'),
#  Row(Street Name='FLIGHT  587 MEMORIAL PARK'),
#  Row(Street Name='W39TH ST'),
#  Row(Street Name='eagle avenue and east 159 street'),
#  Row(Street Name='east 165th street'),
#  Row(Street Name='BELMONT PLAYGROUND'),
#  Row(Street Name='GALASSO PLACE'),
#  Row(Street Name='2 AV'),
#  Row(Street Name='Roosevelt ave'),
#  Row(Street Name='STAUBER DR'),
#  Row(Street Name='DAVIS HALL'),
#  Row(Street Name='HILLVIEW LANE'),
#  Row(Street Name='3517'),
#  Row(Street Name='SEDAR AVENUE'),
#  Row(Street Name='CORPORATE EXCHANGE DR'),
#  Row(Street Name='MARISA STREET'),
#  Row(Street Name='133RD STREET'),
#  Row(Street Name='110TH ST'),
#  Row(Street Name='JOSEPH AVE'),
#  Row(Street Name='EAST 163RD STREET'),
#  Row(Street Name='INTERNATIONAL DRIVE'),
#  Row(Street Name='W 175TH ST'),
#  Row(Street Name='PS251 PLGD DAVID FOX MEMORIA'),
#  Row(Street Name='BRONX PELHAM PARKWAY NORTH'),
#  Row(Street Name='PENCADER DRIVE'),
#  Row(Street Name='MEMORIAL PLAZA'),
#  Row(Street Name='COPPER AVE'),
#  Row(Street Name='17 27 Crosby Avenue'),
#  Row(Street Name='779 40 ST'),
#  Row(Street Name='415789'),
#  Row(Street Name='WEST 54TH STREET'),
#  Row(Street Name='east 172 street'),
#  Row(Street Name='WEST  121 STREET'),
#  Row(Street Name='MOFFAT STREET'),
#  Row(Street Name='HUMBOLDT STREET'),
#  Row(Street Name='82 AVENUE'),
#  Row(Street Name='IONIA AVENUE'),
#  Row(Street Name='BARRETTO STREET'),
#  Row(Street Name='OAKLAND AVENUE'),
#  Row(Street Name='DEMOPOLIS AVENUE'),
#  Row(Street Name='WHITAKER PL'),
#  Row(Street Name='LEVERICH STREET'),
#  Row(Street Name='PAULDING AVE'),
#  Row(Street Name='CROMMELIN AVENUE'),
#  Row(Street Name='INDIAN ROAD'),
#  Row(Street Name='HOBART STREET'),
#  Row(Street Name='BLACKROCK AVENUE'),
#  Row(Street Name='OVERING STREET'),
#  Row(Street Name='WHITEPLAINS ROAD'),
#  Row(Street Name='CANTON COURT'),
#  Row(Street Name='LAYTON STREET'),
#  Row(Street Name='GOWANUS EXPY'),
#  Row(Street Name='HILLYER STREET'),
#  Row(Street Name='23 ROAD'),
#  Row(Street Name='PAERDEGAT 10 STREET'),
#  Row(Street Name='NEWKIRK PLAZA'),
#  Row(Street Name='FURMANVILL AVENUE'),
#  Row(Street Name='EAST 101ST STREET'),
#  Row(Street Name='BEACH  141 STREET'),
#  Row(Street Name='EAST AVENUE'),
#  Row(Street Name='101ST ST'),
#  Row(Street Name='GREENFIELD AVENUE'),
#  Row(Street Name='WESTCHESTER SQUARE'),
#  Row(Street Name='ST EDWARDS STREET'),
#  Row(Street Name='223 DITMAS AVE'),
#  Row(Street Name='CARDER ROAD'),
#  Row(Street Name='MARATHAN PARKWAY'),
#  Row(Street Name='HONEY LANE'),
#  Row(Street Name='MALLARD LANE'),
#  Row(Street Name='WEBSTER HOUSES BUILDING 2'),
#  Row(Street Name='CENTRAL ROAD'),
#  Row(Street Name='HILLCREST DR'),
#  Row(Street Name='123RD AVENUE'),
#  Row(Street Name='WEST 6TH STREET'),
#  Row(Street Name='75TH AVE'),
#  Row(Street Name='HALL OF FAME TERRACE'),
#  Row(Street Name='KERMIT PL'),
#  Row(Street Name='STUART AVE'),
#  Row(Street Name='GEORGE ST'),
#  Row(Street Name='GAYLORD DRIVE NORTH'),
#  Row(Street Name='W albany ST'),
#  Row(Street Name='PAEDERGAT 15 ST'),
#  Row(Street Name='willoughby st'),
#  Row(Street Name='HIGHLAND LANE'),
#  Row(Street Name='127 AVE'),
#  Row(Street Name='BELLAIRE PLACE'),
#  Row(Street Name='BEACH  110 STREET'),
#  Row(Street Name='KEW GARDEN RD'),
#  Row(Street Name='42 ST'),
#  Row(Street Name='RING PLACE'),
#  Row(Street Name='WETMORE ROAD'),
#  Row(Street Name='CIVIC CENTRE PLAZA'),
#  Row(Street Name='111 ST'),
#  Row(Street Name='ELMHURST PARK VETERANS GROV'),
#  Row(Street Name='OLGA PLACE'),
#  Row(Street Name='STRONG ST'),
#  Row(Street Name='96 STREETT'),
#  Row(Street Name='FREDERICK DOUGLASS CIRCLE'),
#  Row(Street Name='BEACH 149TH STREET'),
#  Row(Street Name='ROSEVELT AVE'),
#  Row(Street Name='BUSHWICK INLET PARK'),
#  Row(Street Name='NORMAN ST'),
#  Row(Street Name='HIGHWAY 96 EAST'),
#  Row(Street Name='BEACH DRIVE'),
#  Row(Street Name='CLEARVIEW PARK GOLF COURSE'),
#  Row(Street Name='BAY RIDGE BLVD'),
#  Row(Street Name='BERGEN TURNPIKE'),
#  Row(Street Name='DEAN PG'),
#  Row(Street Name='VAN ZANDT AVE'),
#  Row(Street Name='WALBROOKE AVE'),
#  Row(Street Name='DALEHAM ST'),
#  Row(Street Name='SYDNEY PL'),
#  Row(Street Name='BEACH 36 ST'),
#  Row(Street Name='PIKE ST'),
#  Row(Street Name='175 PL'),
#  Row(Street Name='147 PL'),
#  Row(Street Name='LAUREL HILL TERR'),
#  Row(Street Name='SHEPHERD AVE'),
#  Row(Street Name='BRADDOCK AVE'),
#  Row(Street Name='EDWARD HART PLAYGROUND'),
#  Row(Street Name='FREDERIC DOUGLAS BOULEVARD'),
#  Row(Street Name='VAN ALLEN AVE'),
#  Row(Street Name='7819 79 ST'),
#  Row(Street Name='29-06 BROOKHAVEN AVE'),
#  Row(Street Name='OVERHILL ROAD'),
#  Row(Street Name='LOU LODATI PLAYGROUND'),
#  Row(Street Name='1313 DEAN ST'),
#  Row(Street Name="FORDHAM U O'HARE HALL"),
#  Row(Street Name='STATEN ISLAND ACADEMY'),
#  Row(Street Name='Sackman AVE'),
#  Row(Street Name='VANALLEN AVENUE'),
#  Row(Street Name='HILLMEYER ROAD'),
#  Row(Street Name='211 PL'),
#  Row(Street Name='1014 coney island ave'),
#  Row(Street Name='MALVINE AVE'),
#  Row(Street Name='DANIEL A HAGGERTY PARK'),
#  Row(Street Name='183RD STREET'),
#  Row(Street Name='CHAFFEE AVE'),
#  Row(Street Name='LUNDSTEN AVE'),
#  Row(Street Name='145TH ROAD'),
#  Row(Street Name='JOHN F KENNEDY PARKWAY'),
#  Row(Street Name='WEST   37 STREET'),
#  Row(Street Name='CENTRAL PARK WEST'),
#  Row(Street Name='LENOX ROAD'),
#  Row(Street Name='SUNBURY ROAD'),
#  Row(Street Name='117 ST W'),
#  Row(Street Name='ZEREGA AVENUE'),
#  Row(Street Name='228 STREET'),
#  Row(Street Name='RIVERDALE AVENUE'),
#  Row(Street Name='GOWER STREET'),
#  Row(Street Name='HARBOR ROAD'),
#  Row(Street Name='BURTON STREET'),
#  Row(Street Name='MILTON AVENUE'),
#  Row(Street Name='EAST 236 STREET'),
#  Row(Street Name='MANSION AVENUE'),
#  Row(Street Name='SHIEL AVENUE'),
#  Row(Street Name='STOBE AVENUE'),
#  Row(Street Name='RADNOR STREET'),
#  Row(Street Name='GREENE STREET'),
#  Row(Street Name='VAN WYCK EXPRESSWAY'),
#  Row(Street Name='VANCE STREET'),
#  Row(Street Name='SEBA AVENUE'),
#  Row(Street Name='BAY   34 STREET'),
#  Row(Street Name='SENATOR STREET'),
#  Row(Street Name='PS284 PLGD WALLACE SCHOOL'),
#  Row(Street Name='BAYARD STREET'),
#  Row(Street Name='WEST 113TH STREET'),
#  Row(Street Name='43 ROAD'),
#  Row(Street Name='VAN WYCK EXPRESSWAY SR EAST'),
#  Row(Street Name='GALE PLACE'),
#  Row(Street Name='VALDEMAR AVENUE'),
#  Row(Street Name='DR MARTIN LUTHER KING JR BLVD'),
#  Row(Street Name='110 ST E'),
#  Row(Street Name='STEINWAY PLACE'),
#  Row(Street Name='NEVADA AVENUE'),
#  Row(Street Name='BENNINGER PLGD'),
#  Row(Street Name='SOUTH 6 STREET'),
#  Row(Street Name='CRESTWATER COURT'),
#  Row(Street Name='EAST 45TH STREET'),
#  Row(Street Name='MANILA AVENUE'),
#  Row(Street Name='77TH PLACE'),
#  Row(Street Name='167TH STREET'),
#  Row(Street Name='26 ST E'),
#  Row(Street Name='BEACH   98 STREET'),
#  Row(Street Name='SOUTH 10 STREET'),
#  Row(Street Name='DEGROOT PLACE'),
#  Row(Street Name='NORWALK AVENUE'),
#  Row(Street Name='REMSEN PLACE'),
#  Row(Street Name='EAST BAY AVENUE'),
#  Row(Street Name='grattan st'),
#  Row(Street Name='56 ST W'),
#  Row(Street Name='FRASER SQR'),
#  Row(Street Name='FIELDSTON RD'),
#  Row(Street Name='BATTERY RD'),
#  Row(Street Name='12 WRIGHT RD'),
#  Row(Street Name='EDGEHILL AVENUE'),
#  Row(Street Name='E 207 ST'),
#  Row(Street Name='WAVERLY PL'),
#  Row(Street Name='72ND  DRIVE'),
#  Row(Street Name='E 172 ST'),
#  Row(Street Name='MEADOW DRIVE'),
#  Row(Street Name='35 ST W'),
#  Row(Street Name='ORMOND PLACE'),
#  Row(Street Name='76TH ST'),
#  Row(Street Name='FLATLANDS AVE and VAN SICLEN AVE'),
#  Row(Street Name='MARGINAL STREET'),
#  Row(Street Name='BELL BOUL'),
#  Row(Street Name='SICKLES AVE'),
#  Row(Street Name='LAUREL HIL BOULEVARD'),
#  Row(Street Name='CROSS ISLAND PARKWAY S SVC RD'),
#  Row(Street Name='RAILROAD TERRACE'),
#  Row(Street Name='WEBSTER MEMORIAL PLGD'),
#  Row(Street Name='CORP STONE STREET'),
#  Row(Street Name='JACOB H SCHIFF PLGD'),
#  Row(Street Name='SAMUEL N BENNERSON PARK'),
#  Row(Street Name='HICORY AVE'),
#  Row(Street Name='WILLIS AVENUE BRIDGE BIKE PATH'),
#  Row(Street Name='AIR TRAIN-TERMINAL    1'),
#  Row(Street Name='EAST 93RD STREET'),
#  Row(Street Name='63RD ST'),
#  Row(Street Name='726 E 212TH ST'),
#  Row(Street Name='HOLLY HILL LANE'),
#  Row(Street Name='3 AVE BRIDGE'),
#  Row(Street Name='ALEXANDER STREET'),
#  Row(Street Name='269TH STREET'),
#  Row(Street Name='BOX 960061'),
#  Row(Street Name='PONTIAC PLACE'),
#  Row(Street Name='BLUE HERON PARK PRESERVE'),
#  Row(Street Name='BEACH 222 STREET'),
#  Row(Street Name='W 13 RD'),
#  Row(Street Name='84 DR'),
#  Row(Street Name='MORSE COURT'),
#  Row(Street Name='KENMORE COURT'),
#  Row(Street Name='RICHMOND TER'),
#  Row(Street Name='PATRICIA CT'),
#  Row(Street Name='30 RD'),
#  Row(Street Name='RIEGELMAN BOARDWALK'),
#  Row(Street Name='249TH ST'),
#  Row(Street Name='GUSTAVE L LEVY PLACE'),
#  Row(Street Name='MC DONALD PARK'),
#  Row(Street Name='SCHENCK PLACE'),
#  Row(Street Name='B  108 STREET'),
#  Row(Street Name='BEACH 106 STREET'),
#  Row(Street Name='2237 7 AVE'),
#  Row(Street Name='85 ST & 19 AV & 20 AV'),
#  Row(Street Name='BAY TERRACE SHOPPING CENTER'),
#  Row(Street Name='HUTCHINSON RVR PY NB WESTCHESTER'),
#  Row(Street Name='ADAM POWELL JR BOULEVARD'),
#  Row(Street Name='VAN CORTLND PARK SOUTH'),
#  Row(Street Name='CANAL RD'),
#  Row(Street Name='E 20TH ST'),
#  Row(Street Name='194TH STREET'),
#  Row(Street Name='EAST 227TH STREET'),
#  Row(Street Name='NOELL AVE'),
#  Row(Street Name='NORTH 3RD STREET'),
#  Row(Street Name='FIELDSTONE RD'),
#  Row(Street Name='SIEGEL COURT'),
#  Row(Street Name='STRATTON ST'),
#  Row(Street Name='BQE EXIT   28 A EASTBOUND'),
#  Row(Street Name='16TH STREET'),
#  Row(Street Name='W 77TH ST'),
#  Row(Street Name='JAMES MARSHALL POWER PLGD'),
#  Row(Street Name='18211'),
#  Row(Street Name='GRAND CNTRL PARKWAY WEST SR'),
#  Row(Street Name='WASHINGTON HALL PLGD'),
#  Row(Street Name='WATSON GLEASON PLGD'),
#  Row(Street Name='WELLINGTON AND HATHAWAY AVENUE'),
#  Row(Street Name='STEINWAY STREET'),
#  Row(Street Name='WEST   49 STREET'),
#  Row(Street Name='BOOTH MEMORIAL AVENUE'),
#  Row(Street Name='23 AVENUE'),
#  Row(Street Name='89 AVENUE'),
#  Row(Street Name='WOODHAVEN BOULEVARD'),
#  Row(Street Name='KEMBALL AVENUE'),
#  Row(Street Name='JEFFERSON STREET'),
#  Row(Street Name='GIPSON STREET'),
#  Row(Street Name='WALTON ROAD'),
#  Row(Street Name='SHELDON AVENUE'),
#  Row(Street Name='BLONDELL AVENUE'),
#  Row(Street Name='EAST 137 STREET'),
#  Row(Street Name='TOMLINSON AVENUE'),
#  Row(Street Name='CAMBRELENG AVENUE'),
#  Row(Street Name='GIVAN AVENUE'),
#  Row(Street Name='WAKEMAN PLACE'),
#  Row(Street Name='MILES AVENUE'),
#  Row(Street Name='DIGNEY AVENUE'),
#  Row(Street Name='BAY    8 STREET'),
#  Row(Street Name='EAST 99 STREET'),
#  Row(Street Name='PHILIP AVENUE'),
#  Row(Street Name='ROCHELLE STREET'),
#  Row(Street Name='MCCARREN PARK'),
#  Row(Street Name='BAY   32 STREET'),
#  Row(Street Name='WEST 185 STREET'),
#  Row(Street Name='GOLD AVENUE'),
#  Row(Street Name='BAY 11TH STREET'),
#  Row(Street Name='4TH AVENUE'),
#  Row(Street Name='192 AVENUE'),
#  Row(Street Name='NORMAL ROAD'),
#  Row(Street Name='KINGSBORO 7 WALK'),
#  Row(Street Name='OLD NEW UTRECHT ROAD'),
#  Row(Street Name='SURREY PLACE'),
#  Row(Street Name='LOVELACE AVENUE'),
#  Row(Street Name='WILLIAM COURT'),
#  Row(Street Name='NEPTUNE COURT'),
#  Row(Street Name='9 ST E'),
#  Row(Street Name='MT EDEN MALL 1'),
#  Row(Street Name='CENTRAL PARK AVE'),
#  Row(Street Name='VANKLEECK STREET'),
#  Row(Street Name='EAST BUCHANAN STREET'),
#  Row(Street Name='BARKLEY AVE'),
#  Row(Street Name='WEST 147TH STREET'),
#  Row(Street Name='NEWARK INTERNATIONAL AIRPORT'),
#  Row(Street Name='DAREWOOD LANE'),
#  Row(Street Name='1220 PARK AVE,'),
#  Row(Street Name='FREDERICK DOUGAL BOULEVARD'),
#  Row(Street Name='CENTRAL WEST PARK W'),
#  Row(Street Name='PURDY PLACE'),
#  Row(Street Name='67 AVE'),
#  Row(Street Name='CENTRAL PARK ST'),
#  Row(Street Name='ARCADIA PLACE'),
#  Row(Street Name='LOVINGHAM PLACE'),
#  Row(Street Name='NAVIGATOR COURT'),
#  Row(Street Name='585 235 street'),
#  Row(Street Name='66 AVE'),
#  Row(Street Name='MCKINNLEY AVENUE'),
#  Row(Street Name='166 ST E'),
#  Row(Street Name='BEACH 43 ST'),
#  Row(Street Name='SCHENCK AVE'),
#  Row(Street Name='WEST 80TH STREET'),
#  Row(Street Name='WEST 126TH STREET'),
#  Row(Street Name='HUNTS POINT MARKET PARK'),
#  Row(Street Name='JENNINGS ST'),
#  Row(Street Name='NEW HAVEN AVE'),
#  Row(Street Name='182 ST E'),
#  Row(Street Name='39 ave'),
#  Row(Street Name='ORCHARD BEACH RD'),
#  Row(Street Name='SUTTON SQR'),
#  Row(Street Name='WEST JERICHO TURNPIKE'),
#  Row(Street Name='PS282 PLGD'),
#  Row(Street Name='BRADY AVE'),
#  Row(Street Name='CASTLETON AVE'),
#  Row(Street Name='GIL COURT'),
#  Row(Street Name='WOOD COURT'),
#  Row(Street Name='BUSHWICK INLET'),
#  Row(Street Name='115 AVE'),
#  Row(Street Name='W 70 ST'),
#  Row(Street Name='E 6 ST'),
#  Row(Street Name='DETROIT AVE'),
#  Row(Street Name='E 173 ST'),
#  Row(Street Name='FAIRMONT PL'),
#  Row(Street Name='WILD AVE'),
#  Row(Street Name='60 DR'),
#  Row(Street Name='BRUST PARK'),
#  Row(Street Name='COMPTON AVENUE'),
#  Row(Street Name='FOREST LANE'),
#  Row(Street Name='CORLEARS PARK ROAD OVER FDR DRV'),
#  Row(Street Name='W 80TH ST'),
#  Row(Street Name='HUNTERS POINT PARK S'),
#  Row(Street Name='QUEENSBORO HALL MUNI PARKING'),
#  Row(Street Name='TRUMP BUILDING'),
#  Row(Street Name='MOMA'),
#  Row(Street Name='TRIBORO PLAZA'),
#  Row(Street Name='N CONDUIT AVE EN CROSS BAY BLVD'),
#  Row(Street Name='Fdr drv northbound service rd / e 37th st'),
#  Row(Street Name='H A WHALEN PARK'),
#  Row(Street Name='FREDERICK DOUGLASS PLAYGROUND'),
#  Row(Street Name='IS  229'),
#  Row(Street Name='JACOB RIIS TRIANGLE'),
#  Row(Street Name='MORGAN PLACE'),
#  Row(Street Name='POINT WEST BOULEVARD'),
#  Row(Street Name='MORTON SQUARE'),
#  Row(Street Name='GRAY FALLS DRIVE'),
#  Row(Street Name='DYRE AVE'),
#  Row(Street Name='W 40TH ST'),
#  Row(Street Name='212TH PLACE'),
#  Row(Street Name='W 54TH ST'),
#  Row(Street Name='W 82ND ST'),
#  Row(Street Name='KOLBERT PLAYGROUND'),
#  Row(Street Name='37TH ROAD'),
#  Row(Street Name='OLD WESTBURY ROAD'),
#  Row(Street Name='B 15 STREET'),
#  Row(Street Name='EAST 231ST STREET'),
#  Row(Street Name='EAST 158TH STREET'),
#  Row(Street Name='20TH'),
#  Row(Street Name='PIERMONT ROAD'),
#  Row(Street Name='165 street'),
#  Row(Street Name='97 AVENUE'),
#  Row(Street Name='VAN DAM STREET'),
#  Row(Street Name='CLOVE ROAD'),
#  Row(Street Name='KING AVENUE'),
#  Row(Street Name='FIFTH AVENUE'),
#  Row(Street Name='AVENUE X'),
#  Row(Street Name='EAST 94 STREET'),
#  Row(Street Name='HUBBARD STREET'),
#  Row(Street Name='M AVENUE'),
#  Row(Street Name='NASSAU STREET'),
#  Row(Street Name='EAST   26 STREET'),
#  Row(Street Name='EDGECOMBE AVENUE'),
#  Row(Street Name='97 STREET'),
#  Row(Street Name='CHARLTON STREET'),
#  Row(Street Name='PEARTREE AVENUE'),
#  Row(Street Name='WEST TREMONT AVENUE'),
#  Row(Street Name='VASSAR STREET'),
#  Row(Street Name='WESTFARM ROAD'),
#  Row(Street Name='ROCKAWAY BEACH BOARDWALK 2'),
#  Row(Street Name='MERSEREAU AVENUE'),
#  Row(Street Name='SHALE STREET'),
#  Row(Street Name='EAST 147 STREET'),
#  Row(Street Name='WEST 88 STREET'),
#  Row(Street Name='FOX TERRACE'),
#  Row(Street Name='EAST 103 STREET'),
#  Row(Street Name='NORTH 10 STREET'),
#  Row(Street Name='30 ST W'),
#  Row(Street Name='EAST  170 STREET'),
#  Row(Street Name='CANDON AVENUE'),
#  Row(Street Name='FABER TERRACE'),
#  Row(Street Name='DETECTIVE KEITH L WILLIAMS PARK'),
#  Row(Street Name='DARCEY AVENUE'),
#  Row(Street Name='CORPRL KENNEDY STREET'),
#  Row(Street Name='46TH RD'),
#  Row(Street Name='NORTH 3 STREET'),
#  Row(Street Name='EAST 212TH STREET'),
#  Row(Street Name='P O MOIRA SMITH WAY'),
#  Row(Street Name='KINGLAND AVENUE'),
#  Row(Street Name='1987'),
#  Row(Street Name='RIGBY STREET'),
#  Row(Street Name='MANOR COURT'),
#  Row(Street Name='FORDHAM PLACE'),
#  Row(Street Name='OLD LANE'),
#  Row(Street Name='WHITELAW AVENUE'),
#  Row(Street Name='CONOVER ST'),
#  Row(Street Name='BAY 14TH STREET'),
#  Row(Street Name='PAERDEGAT   13 STREET'),
#  Row(Street Name='REGINA LANE'),
#  Row(Street Name='BRIGHTON 11TH ST'),
#  Row(Street Name='BRYANT PARK'),
#  Row(Street Name='71ST ST'),
#  Row(Street Name='TROUTMAN ST'),
#  Row(Street Name='STARLIGHT PARK'),
#  Row(Street Name='ROSEBANK PLACE'),
#  Row(Street Name='ASTORIA HOUSES'),
#  Row(Street Name='EFFINGHAM AVE.'),
#  Row(Street Name='47TH RD'),
#  Row(Street Name='NORTH PLANK ROAD'),
#  Row(Street Name='RIVERSIDE HOSP SHOP & STORAGE'),
#  Row(Street Name='CO OP CITY BOULEVARD'),
#  Row(Street Name='DYKER PLACE'),
#  Row(Street Name='205'),
#  Row(Street Name='HICKSVILLE RD'),
#  Row(Street Name='W 111 ST'),
#  Row(Street Name='FLETCHER PLACE'),
#  Row(Street Name='HEMSTEAD AVENUE'),
#  Row(Street Name='202 AVENUE'),
#  Row(Street Name='HILLBROOK DRIVE'),
#  Row(Street Name='PEACHTREE LANE'),
#  Row(Street Name='BEACH  114 STREET'),
#  Row(Street Name='B  215 STREET'),
#  Row(Street Name='MARION WALK'),
#  Row(Street Name='WEA'),
#  Row(Street Name='POMPEI ROAD'),
#  Row(Street Name='MADISON SQR PARK'),
#  Row(Street Name='W 6TH ST'),
#  Row(Street Name='BEACH 129 ST'),
#  Row(Street Name='CASTLE HILL AVE'),
#  Row(Street Name='91 ST W'),
#  Row(Street Name='WEST 23RD STREET'),
#  Row(Street Name='MACDOUGAL ST'),
#  Row(Street Name='E 3RD ST'),
#  Row(Street Name='TILLOTSON AVE'),
#  Row(Street Name='white plains RD'),
#  Row(Street Name='SOUTH 4 ST'),
#  Row(Street Name='CORP EXCHANGE DRIVE'),
#  Row(Street Name='169'),
#  Row(Street Name='WILLIAMSBRIDGE SQR'),
#  Row(Street Name='VANDERVEER ST'),
#  Row(Street Name='81-06 ROOSEVELT AVE'),
#  Row(Street Name='174 ST EAST'),
#  Row(Street Name='7523/ New Utrecht AV'),
#  Row(Street Name='LILAC COURT'),
#  Row(Street Name='DELANCEY ST SOUTH'),
#  Row(Street Name='TALBOT ST'),
#  Row(Street Name='132 AVE'),
#  Row(Street Name='83 PL'),
#  Row(Street Name='RUGBY RD'),
#  Row(Street Name='FLATLANDS 9 ST'),
#  Row(Street Name='BENJAMIN DR'),
#  Row(Street Name='MCKIBBIN CT'),
#  Row(Street Name='STODDARD PL'),
#  Row(Street Name='10TH'),
#  Row(Street Name='B Q E WEST'),
#  Row(Street Name='WASHINGTON BRDG'),
#  Row(Street Name='13TH AVE'),
#  Row(Street Name='VERRAZZANO BRIDGE'),
#  Row(Street Name='LEHMAN HIGH SCHOOL'),
#  Row(Street Name='CORP KENNEDY STREETCORP KENNEDY'),
#  Row(Street Name='EAST FOURTH WALK'),
#  Row(Street Name='WEST 150 STREET AND 8TH AVENUE'),
#  Row(Street Name='620 THWAITES PL'),
#  Row(Street Name='51st street'),
#  Row(Street Name='E 209 ST'),
#  Row(Street Name='I AVENUE'),
#  Row(Street Name='BRIGHTON 12TH STREET'),
#  Row(Street Name='FOXHUNT COURT'),
#  Row(Street Name='85TH ROAD'),
#  Row(Street Name='DRY DOCK POOL'),
#  Row(Street Name='29th Street'),
#  Row(Street Name='DIETERLE CRES'),
#  Row(Street Name='malborough rd'),
#  Row(Street Name='VAN WYCK EP SOUTHERN PY RP'),
#  Row(Street Name='BROADAY'),
#  Row(Street Name='24 AVENUE'),
#  Row(Street Name='113 STREET'),
#  Row(Street Name='BEACH   29 STREET'),
#  Row(Street Name='FLAGSHIP CIRCLE'),
#  Row(Street Name='LOCKE AVENUE'),
#  Row(Street Name='EAST  208 STREET'),
#  Row(Street Name='EAST   11 STREET'),
#  Row(Street Name='EAST   59 STREET'),
#  Row(Street Name='40 AVENUE'),
#  Row(Street Name='EAST  240 STREET'),
#  Row(Street Name='BEACH  128 STREET'),
#  Row(Street Name='EAST 229 STREET'),
#  Row(Street Name='WEST  157 STREET'),
#  Row(Street Name='EDMORE AVENUE'),
#  Row(Street Name='WEST    1 STREET'),
#  Row(Street Name='WEST 75 STREET'),
#  Row(Street Name='264 STREET'),
#  Row(Street Name='ELLSWORTH PLACE'),
#  Row(Street Name='BAYVIEW AVENUE'),
#  Row(Street Name='CHEVY CHASE STREET'),
#  Row(Street Name='ELSMERE PLACE'),
#  Row(Street Name='FAIRBANKS AVENUE'),
#  Row(Street Name='SECOND STREET'),
#  Row(Street Name='BUSHWICK COURT'),
#  Row(Street Name='WHITNEY AVENUE'),
#  Row(Street Name='COLLEGE POINT BLVD'),
#  Row(Street Name='WEST 219 STREET'),
#  Row(Street Name='CLIFFORD PLACE'),
#  Row(Street Name='AVENUE NORTH'),
#  Row(Street Name='BIALYSTOKER PLACE'),
#  Row(Street Name='EAST 20 STREET'),
#  Row(Street Name='KILLARNEY STREET'),
#  Row(Street Name='85TH DRIVE'),
#  Row(Street Name='EAST 113 STREET'),
#  Row(Street Name='E 10TH ST'),
#  Row(Street Name='THROOP AVE'),
#  Row(Street Name='HAMMERSLEY AVENUE'),
#  Row(Street Name='COOPER TERRACE'),
#  Row(Street Name='HYLAN PLACE'),
#  Row(Street Name='SPRATT AVENUE'),
#  Row(Street Name='ARLO ROAD'),
#  Row(Street Name='FOREST PKWY'),
#  Row(Street Name='WILLOW LANE'),
#  Row(Street Name='DEPOT PLACE'),
#  Row(Street Name='MELBA COURT'),
#  Row(Street Name='MACOMBS DAM BRIDGE'),
#  Row(Street Name='29 ST E'),
#  Row(Street Name='PAERDEGAT 1 STREET'),
#  Row(Street Name='59 ST E'),
#  Row(Street Name='BEACH   85 STREET'),
#  Row(Street Name='WEST 141ST STREET'),
#  Row(Street Name='398street'),
#  Row(Street Name='RICHMOND COURT'),
#  Row(Street Name='METRO TECH CENTER'),
#  Row(Street Name='BOODY STREET'),
#  Row(Street Name='TURNER AVENUE'),
#  Row(Street Name='BUCKNELL ROAD'),
#  Row(Street Name='HARING ST AVENUE Y'),
#  Row(Street Name='GARRETSON AVE'),
#  Row(Street Name='BRONX RVR PKWY'),
#  Row(Street Name='FLATLANDS FIRST STREET'),
#  Row(Street Name='LINCOLN TERRACE PARK'),
#  Row(Street Name='BEEKMAN CIRCLE'),
#  Row(Street Name='AUTUMN AVE'),
#  Row(Street Name='AMSTEL BLVD'),
#  Row(Street Name='BORDEN AVE'),
#  Row(Street Name='CORONA GOLF PLGD'),
#  Row(Street Name='PS161 PLGD'),
#  Row(Street Name='CUBBERLY PLACE'),
#  Row(Street Name='PICKERSGIL AVENUE'),
#  Row(Street Name='83RD AVENUE'),
#  Row(Street Name='100 ST'),
#  Row(Street Name='ROBERTO CLEMENTE PARK'),
#  Row(Street Name='LAFEYETTE AVE'),
#  Row(Street Name='W 118 ST'),
#  Row(Street Name='SHIRLEY CHISHOLM STATE PARK'),
#  Row(Street Name='GETZ AVE'),
#  Row(Street Name='163 ST W'),
#  Row(Street Name='UNITED AIRLINES TERMINAL'),
#  Row(Street Name='257 ST'),
#  Row(Street Name='S IRVING AVE'),
#  Row(Street Name='53 ST'),
#  Row(Street Name='152 ST E'),
#  Row(Street Name='THOMPSON ST PLGD'),
#  Row(Street Name='1349'),
#  Row(Street Name='POMPEII AVENUE'),
#  Row(Street Name='SUNNYMEAD VLGE'),
#  Row(Street Name='E 65 ST'),
#  Row(Street Name='TEUNISSEN PLACE'),
#  Row(Street Name='WHITE OAK LANE'),
#  Row(Street Name='E MOSHOLU PKWY S'),
#  Row(Street Name='KEEN CT'),
#  Row(Street Name='148 RD'),
#  Row(Street Name='OUTLOOK AVE'),
#  Row(Street Name='116 ST'),
#  Row(Street Name='ROCHELLE ST'),
#  Row(Street Name='CURTIS ST'),
#  Row(Street Name='CHESTER CT'),
#  Row(Street Name='DALTON AVE'),
#  Row(Street Name='GROVE AVE'),
#  Row(Street Name='E 123 ST'),
#  Row(Street Name='E 136 ST'),
#  Row(Street Name='OAK TREE PLACE'),
#  Row(Street Name='FEATHERBED LN'),
#  Row(Street Name='STYVERSON AVE'),
#  Row(Street Name='PAULIS PLACE'),
#  Row(Street Name='OCEAN AVENUE BRIDGE'),
#  Row(Street Name='OVERLOOK DRIVE'),
#  Row(Street Name='1547 westcher Avenue'),
#  Row(Street Name='N 10TH STREET'),
#  Row(Street Name='MACOMBS DAM ROAD'),
#  Row(Street Name='VAN ARSDALE AVENUE'),
#  Row(Street Name='PUTNAM ST'),
#  Row(Street Name='TRYON AVE'),
#  Row(Street Name='157TH AVE'),
#  Row(Street Name='WEST 177TH STREET'),
#  Row(Street Name='SUTTON PLACE NORTH'),
#  Row(Street Name='B 25 STREET'),
#  Row(Street Name='TURNER PL'),
#  Row(Street Name='VAN WYCK EXPY S'),
#  Row(Street Name='73RD ROAD'),
#  Row(Street Name='WEST 149 ST'),
#  Row(Street Name='EAST 197TH STREET'),
#  Row(Street Name='NORTHERN BLVD  W/B'),
#  Row(Street Name='ESSINGHAN AVE'),
#  Row(Street Name='ORLANDO'),
#  Row(Street Name='EVERDELL AVE'),
#  Row(Street Name='COMMONWLTH BOULEVARD'),
#  Row(Street Name='GREENE AVENUE'),
#  Row(Street Name='ADAM C POWELL BOULEVARD'),
#  Row(Street Name='GILBERT PLACE'),
#  Row(Street Name='EUCLID AVENUE'),
#  Row(Street Name='EAST 128 STREET'),
#  Row(Street Name='LAKEWOOD AVENUE'),
#  Row(Street Name='LENOX AVENUE'),
#  Row(Street Name='WEST   26 STREET'),
#  Row(Street Name='BRIGHTON    5 STREET'),
#  Row(Street Name='20 STREET'),
#  Row(Street Name='KINGSTON PLACE'),
#  Row(Street Name='EAST  163 STREET'),
#  Row(Street Name='WEST 33 STREET'),
#  Row(Street Name='JEFFERSON PLACE'),
#  Row(Street Name='154 STREET'),
#  Row(Street Name='COLONIAL AVENUE'),
#  Row(Street Name='EAST  144 STREET'),
#  Row(Street Name='HASKIN STREET'),
#  Row(Street Name='85TH AVENUE'),
#  Row(Street Name='MCARTHUR AVENUE'),
#  Row(Street Name='YOUNG AVENUE'),
#  Row(Street Name='COVERLY STREET'),
#  Row(Street Name='CONNER STREET'),
#  Row(Street Name='135 DRIVE'),
#  Row(Street Name='EAST  171 STREET'),
#  Row(Street Name='HILLSIDE AVENUE BELLEROSE'),
#  Row(Street Name='BAY 53 STREET'),
#  Row(Street Name='168TH STREET'),
#  Row(Street Name='231 ST W'),
#  Row(Street Name='WILDWOOD LANE'),
#  Row(Street Name='98 AVENUE'),
#  Row(Street Name='NEW DORP PLAZA SOUTH'),
#  Row(Street Name='HUDSON AVE'),
#  Row(Street Name='WOOLEY AVENUE'),
#  Row(Street Name='PEEL PLACE'),
#  Row(Street Name='GCP - Westbound'),
#  Row(Street Name='96TH STREET'),
#  Row(Street Name='TAPPAN STREET'),
#  Row(Street Name='3375 2 avenue'),
#  Row(Street Name='DORE COURT'),
#  Row(Street Name='College AVE'),
#  Row(Street Name='COLBY COURT'),
#  Row(Street Name='ABE WOLFSON TRIANGLE'),
#  Row(Street Name='GR CONCOURSE'),
#  Row(Street Name='B 42 STREET'),
#  Row(Street Name='158TH STREET'),
#  Row(Street Name='BOLTON AVE'),
#  Row(Street Name='SOUTH FIFTH STREET'),
#  Row(Street Name='AVE L'),
#  Row(Street Name='EAST 24 ST'),
#  Row(Street Name='E 73 STREET'),
#  Row(Street Name='SEAGIRT BLVD'),
#  Row(Street Name='7 AVE CENTER PLOTS'),
#  Row(Street Name='PS59 SUMNER HOUSES PLGD'),
#  Row(Street Name='WASHINGTON SQUARE EAST'),
#  Row(Street Name='PEAR TREE AVE'),
#  Row(Street Name='217TH STREET'),
#  Row(Street Name='ANNADALE RD'),
#  Row(Street Name='OLD BROADWAY APT 19C'),
#  Row(Street Name='ISORA PLACE'),
#  Row(Street Name='117 RD'),
#  Row(Street Name='ALLEN SHANDLER PARK'),
#  Row(Street Name='ROYAL ST'),
#  Row(Street Name='lenard st'),
#  Row(Street Name='SUTTER STREET'),
#  Row(Street Name='EXCHANGE ST'),
#  Row(Street Name='SCHOOL ST'),
#  Row(Street Name='HARMON PLAZA'),
#  Row(Street Name='COLUMBUS AVE.'),
#  Row(Street Name='BEACH 29 ST'),
#  Row(Street Name='BEACH 65 ST'),
#  Row(Street Name='10 ST N'),
#  Row(Street Name='KENNEDY AIRPORT'),
#  Row(Street Name='HELENA ROAD'),
#  Row(Street Name='SNIFFEN COURT'),
#  Row(Street Name='KATAN AVE'),
#  Row(Street Name='VLEIGH PL'),
#  Row(Street Name='STANTON ST'),
#  Row(Street Name='ADA DR'),
#  Row(Street Name='ROLLING HILL GRN'),
#  Row(Street Name='QUINCY AVE'),
#  Row(Street Name='XENIA ST'),
#  Row(Street Name='GOODRIDGE AVE'),
#  Row(Street Name='B 29 STREET'),
#  Row(Street Name='B 125 STREET'),
#  Row(Street Name='ALEXANDRA COURT'),
#  Row(Street Name='ALBERTA AVE'),
#  Row(Street Name='east gun hill road'),
#  Row(Street Name='east 98 street'),
#  Row(Street Name='SEAGIRT AVENUE WETLANDS'),
#  Row(Street Name='PELHAM BRIDGE ROAD'),
#  Row(Street Name='6 1/2 AVENUE'),
#  Row(Street Name='DR KAZIMIROFF BOULEVARD'),
#  Row(Street Name='PS59 PLGD'),
#  Row(Street Name='CHARING CROSS'),
#  Row(Street Name='MERCY COLLEGE PLACE'),
#  Row(Street Name='778 Flatbush avenue'),
#  Row(Street Name='14 AVE.'),
#  Row(Street Name='107-38 122ND ST'),
#  Row(Street Name='ST PETERS PLACE'),
#  Row(Street Name='east 175th street'),
#  Row(Street Name='FULTON CENTER'),
#  Row(Street Name='15'),
#  Row(Street Name='B 144 STREET'),
#  Row(Street Name='HEALEY AVE'),
#  Row(Street Name='E 45TH ST'),
#  Row(Street Name='WEST 167TH STREET'),
#  Row(Street Name='PROPECT PARK WEST'),
#  Row(Street Name='MARTIN LUTHER KING DRIVE P.O. BOX'),
#  Row(Street Name='BRONX WHITESTONE BRG N'),
#  Row(Street Name='BEACH 56TH PLACE'),
#  Row(Street Name='WOOLSEY AVE'),
#  Row(Street Name='newport st'),
#  Row(Street Name='rd woodhaven ny11421'),
#  Row(Street Name='S VAUGH WAY'),
#  Row(Street Name='84 AMHERST STREET'),
#  Row(Street Name='clinton and degraw street'),
#  Row(Street Name='CLASON POINT LN NORTH'),
#  Row(Street Name='INGRAM AVE'),
#  Row(Street Name='22nd drive'),
#  Row(Street Name='RHINEHART ROAD'),
#  Row(Street Name='coaster'),
#  Row(Street Name='EVERGREEN AVENUE'),
#  Row(Street Name='WALTON AVENUE'),
#  Row(Street Name='BAY RIDGE PARKWAY'),
#  Row(Street Name='EVERGREEN STREET'),
#  Row(Street Name='RALPH AVENUE'),
#  Row(Street Name='147 STREET'),
#  Row(Street Name='CARROLL STREET'),
#  Row(Street Name='WOOD AVENUE'),
#  Row(Street Name='MANOR AVENUE'),
#  Row(Street Name='LORING PLACE NORTH'),
#  Row(Street Name='MARION STREET'),
#  Row(Street Name='OXFORD AVENUE'),
#  Row(Street Name='EAST 74 STREET'),
#  Row(Street Name='REEDER STREET'),
#  Row(Street Name='DAVIDSON AVE'),
#  Row(Street Name='92 ROAD'),
#  Row(Street Name='BAY 13 STREET'),
#  Row(Street Name='MCGUINNESS BOULEVARD'),
#  Row(Street Name='EAST 215 STREET'),
#  Row(Street Name='WEST 96 STREET'),
#  Row(Street Name='ATLANTIC COMMONS'),
#  Row(Street Name='EAST 152 STREET'),
#  ...]

# %% [markdown]
# "City" column has nonuniform casing (ex: one row has "New York" while majority of the rows are all uppercased like "ROCKVILLE CENTER").

# %%
# View column "City"
df.select("City").distinct().collect()
# Out:
# [Row(City='PRINCETON'),
#  Row(City='HUDSON COUNTY'),
#  Row(City='HUSTON'),
#  Row(City='NESCONSET'),
#  Row(City='WATERTOWN'),
#  Row(City='RARITAN'),
#  Row(City='SOUTH FLORAL PARK'),
#  Row(City='Corona'),
#  Row(City='VALLEY STREAM'),
#  Row(City='STAMFORD'),
#  Row(City='ISLAND'),
#  Row(City='SELINA'),
#  Row(City='CHINO'),
#  Row(City='RIDGEFIELD PARK'),
#  Row(City='ELMHERST'),
#  Row(City='BOLTIMORE'),
#  Row(City='ALPHARATTA'),
#  Row(City='DEAR PARK'),
#  Row(City='LIDO BEACH'),
#  Row(City='SOMERVILLE'),
#  Row(City='NEW JERSEY'),
#  Row(City='WANTGAH'),
#  Row(City='VALLY STREAM'),
#  Row(City='BROOKYLN'),
#  Row(City='WESTBURY'),
#  Row(City='ORLANDO'),
#  Row(City='SAVANNAH'),
#  Row(City='SOUTH GATE'),
#  Row(City='DEER PARK'),
#  Row(City='Queens'),
#  Row(City='NS'),
#  Row(City='STE'),
#  Row(City='Rego Park'),
#  Row(City='FAIR LAWN'),
#  Row(City='NEWARK AIRPORT'),
#  Row(City='NEWHYDE PARK'),
#  Row(City='HEWLETT TOWN'),
#  Row(City='RIDGEFIELD'),
#  Row(City='TUXEDO PARK'),
#  Row(City='HUNGTINGTON'),
#  Row(City='SPRING VALLEY'),
#  Row(City='REDBANK'),
#  Row(City='MASSEPEQUA'),
#  Row(City='MOUNT VERNON'),
#  Row(City='ATLANTA'),
#  Row(City='ST JAMES'),
#  Row(City='AROUND NEW HYDE PARK EXIT'),
#  Row(City='CHEEKTOWAGA'),
#  Row(City='COLLEYVILLE'),
#  Row(City='PORT JEFFERSON'),
#  Row(City='JEARSEY CITY'),
#  Row(City='GUTTEMBERG'),
#  Row(City='OLANDO'),
#  Row(City='SAG HARBOR'),
#  Row(City='CORONA'),
#  Row(City='CENTRAL PARK'),
#  Row(City='OCEANSIDE'),
#  Row(City='MIAMI'),
#  Row(City='TAMPON SPRINGS'),
#  Row(City='NEW JERCY'),
#  Row(City='LIVERMORE'),
#  Row(City='BROOKILYN'),
#  Row(City='WOBURN'),
#  Row(City='FOREST HILL'),
#  Row(City='Jackson Heights'),
#  Row(City='Bayside'),
#  Row(City='KEARNY'),
#  Row(City='HUNTINGTON STATION'),
#  Row(City='ST. PETERSBURG'),
#  Row(City='RICHFIELD'),
#  Row(City='NORTH  BERGEN'),
#  Row(City='PEAKSKILL'),
#  Row(City='STATEB ISLAND'),
#  Row(City='FORT LEE'),
#  Row(City='OAKS'),
#  Row(City='KATANAH'),
#  Row(City='DES MONES'),
#  Row(City='JERSEY'),
#  Row(City='NEW BRUNSWICK'),
#  Row(City='NJ'),
#  Row(City='RENO'),
#  Row(City='GIG HARBOR'),
#  Row(City='SCRANTON'),
#  Row(City='BAY SHORE'),
#  Row(City='GETZVILLE'),
#  Row(City='SCEAUCUS'),
#  Row(City='LONG ISLAND'),
#  Row(City='WHITE PLAINS'),
#  Row(City='HARISHAW'),
#  Row(City='MORGAN HILL'),
#  Row(City='OKSPA'),
#  Row(City='RASPBERRY'),
#  Row(City='ROSELAND'),
#  Row(City='BLOOMINGDALE'),
#  Row(City='DFD'),
#  Row(City='DES MOINES'),
#  Row(City='NEWARK NJ'),
#  Row(City='WOODBERRY'),
#  Row(City='SANTA ROSA'),
#  Row(City='COPIAGUE'),
#  Row(City='BAYSIDE'),
#  Row(City='SOUTH ORANGE'),
#  Row(City='MOUNT LAUREL'),
#  Row(City='TARLIN'),
#  Row(City='CIERO'),
#  Row(City='PARSIPPINY'),
#  Row(City='GREENVILLE'),
#  Row(City='NORWOOD'),
#  Row(City='ELMFORD'),
#  Row(City='EAST MEADOW'),
#  Row(City='BERGEN COUNTY'),
#  Row(City='PORTLAND'),
#  Row(City='OCEAN SIDE'),
#  Row(City='HALLANDALE BEACH'),
#  Row(City='MANHATAN'),
#  Row(City='HEMPSTEAD BAY'),
#  Row(City='MILIPTAS'),
#  Row(City='ISLANDIA'),
#  Row(City='ROCKVILLE CENTRE'),
#  Row(City='CITY OF INTERESION'),
#  Row(City='MINNEAPOLIS'),
#  Row(City='VANCOUVER'),
#  Row(City='KENNESAW'),
#  Row(City='LEVITT TOWN'),
#  Row(City='NEWYOK'),
#  Row(City='MALVERN'),
#  Row(City='BATESBURGE'),
#  Row(City='PERRIS'),
#  Row(City='PARKRIDGE'),
#  Row(City='POMONA'),
#  Row(City='NBLOOMINGTON'),
#  Row(City='GOSHEN'),
#  Row(City='FARMINDELE'),
#  Row(City='OLD BETHPAGE'),
#  Row(City='HARRISBURGH'),
#  Row(City='Oakland Gardens'),
#  Row(City='WESTLAKE'),
#  Row(City='MOUNT PLEASENT'),
#  Row(City='INWOOD'),
#  Row(City='HUNTIGTON STATION'),
#  Row(City='SADDLEBROOK'),
#  Row(City='THORNWOOD'),
#  Row(City='FORT JEFFERSON STATION'),
#  Row(City='SARASOTA'),
#  Row(City='GREENWICH'),
#  Row(City='ANTIONO'),
#  Row(City='COUBERSTORT'),
#  Row(City='NORTHPORT'),
#  Row(City='SLEEPY HOLLOW'),
#  Row(City='LONDON'),
#  Row(City='DES PLAINES'),
#  Row(City='RAYNHAM'),
#  Row(City='Little Neck'),
#  Row(City='LOWELL'),
#  Row(City='NORTHFOLK'),
#  Row(City='STEWART MANOR'),
#  Row(City='BRICK'),
#  Row(City='DENVER'),
#  Row(City='MT. VERNON'),
#  Row(City='SKANEATELESS FALLS'),
#  Row(City='BEAR'),
#  Row(City='Flushing'),
#  Row(City='FAR ROCKAWAY'),
#  Row(City='CROTONA PARK'),
#  Row(City='NOREROSS'),
#  Row(City='WEST DES MOINES'),
#  Row(City='KNOX VALLEY'),
#  Row(City='MILLSTONE'),
#  Row(City='NA'),
#  Row(City='0'),
#  Row(City='ROCKAWAY  BLVD'),
#  Row(City='ROSELLE'),
#  Row(City='THOROFARE'),
#  Row(City='ARDSLEY'),
#  Row(City='SUFFIX'),
#  Row(City='WOODALE'),
#  Row(City='KEW GARDENS'),
#  Row(City='FARMING DALE'),
#  Row(City='TRENTON'),
#  Row(City='ANTIOCH'),
#  Row(City='SPRINGDALE'),
#  Row(City='ROCKDALE CENTER'),
#  Row(City='East Elmhurst'),
#  Row(City='WHITEPLAINS'),
#  Row(City='BAYONNE'),
#  Row(City='GREENLAWN'),
#  Row(City='JERICHO'),
#  Row(City='TOLEDO'),
#  Row(City='UKNOWN'),
#  Row(City='CAROL PLACE'),
#  Row(City='SOUTH PORT'),
#  Row(City='SPRING'),
#  Row(City='DIG HARBOR'),
#  Row(City='WOODLAND PARK'),
#  Row(City='SOMERS'),
#  Row(City='PHOENIX'),
#  Row(City='INDUSTRY'),
#  Row(City='MAGNOLIA'),
#  Row(City='MENDOTA  HEIGHTS'),
#  Row(City='FLORAL PARK'),
#  Row(City='BELLEVILLE'),
#  Row(City='BELLEVIEW'),
#  Row(City='Whitestone'),
#  Row(City='LEVITTTOWN'),
#  Row(City='BALTIMORE'),
#  Row(City='NORTH RIDGE'),
#  Row(City='FLORIDA'),
#  Row(City='POMPANO'),
#  Row(City='PORCHESTER'),
#  Row(City=None),
#  Row(City='WOODSTOCK'),
#  Row(City='BX'),
#  Row(City='HARLEM'),
#  Row(City='E'),
#  Row(City='RIVER FOREST'),
#  Row(City='RAPID'),
#  Row(City='CENTRAL ISLIP'),
#  Row(City='CARROLLTON'),
#  Row(City='PISCUTAWAY'),
#  Row(City='OAK DALE'),
#  Row(City='BRONXVILLE'),
#  Row(City='NEW JER'),
#  Row(City='RICHMOND NY'),
#  Row(City='CLARA BARTON'),
#  Row(City='ESDONDIDO'),
#  Row(City='HEWLETT'),
#  Row(City='HOBKEN'),
#  Row(City='LAKEWOOD'),
#  Row(City='VALLEY  STREAM'),
#  Row(City='NYACK'),
#  Row(City='Glen Oaks'),
#  Row(City='BREEZY POINT'),
#  Row(City='PEEKSKILL'),
#  Row(City='PLEASANTON'),
#  Row(City='HOUSTON'),
#  Row(City='MADISON'),
#  Row(City='BRONXSVILLE'),
#  Row(City='NORTH BRUNSWICK'),
#  Row(City='CHESTER HEIGHTS'),
#  Row(City='MARIETTA'),
#  Row(City='ROCKVILLA CENTER'),
#  Row(City='JERSEY AVE'),
#  Row(City='WYCKOFF'),
#  Row(City='SHORT HILLS'),
#  Row(City='GREAT RIVER'),
#  Row(City='MASON'),
#  Row(City='PALISADES PARK'),
#  Row(City='NEWYORK'),
#  Row(City='JACKSONVILLE'),
#  Row(City='STATEN ISAND'),
#  Row(City='WESTPORT'),
#  Row(City='ROCHESTER'),
#  Row(City='EAST OWALL'),
#  Row(City='MCALLEN'),
#  Row(City='WHITESTONE'),
#  Row(City='GREAT NECK'),
#  Row(City='ELIZABETH'),
#  Row(City='GARWOOD'),
#  Row(City='PEESKILL'),
#  Row(City='PHILIDELPHIA'),
#  Row(City='Richmond Hill'),
#  Row(City='WOODMERE'),
#  Row(City='FRANKILN SQUARE'),
#  Row(City='BLOOMINGTON'),
#  Row(City='BELTSZILLE'),
#  Row(City='N?A'),
#  Row(City='QUENS'),
#  Row(City='FRMNGDALE'),
#  Row(City='LOG BEACH'),
#  Row(City='CAMBRIA HEIGHTS'),
#  Row(City='WEST LYNNWOOD'),
#  Row(City='BELLMORE'),
#  Row(City='LONG BEACH'),
#  Row(City='CHAPPAQUA'),
#  Row(City='REGO PARK'),
#  Row(City='WARREN'),
#  Row(City='CARRY TOWN'),
#  Row(City='FLUSING'),
#  Row(City='TWINS BURG'),
#  Row(City='ABERDEEN'),
#  Row(City='JUPITER'),
#  Row(City='SACREMENTO'),
#  Row(City='SADDLE BROOK'),
#  Row(City='BLOOMFIELD'),
#  Row(City='PECK SLIP'),
#  Row(City='MANHASSET'),
#  Row(City='ORCHARD PARK'),
#  Row(City='GREENICH'),
#  Row(City='WILLIAMSPORT'),
#  Row(City='WIXOM'),
#  Row(City='BAKERSFIELD'),
#  Row(City='VALLEYSTEAM'),
#  Row(City='SPARKS'),
#  Row(City='SANTA ANA'),
#  Row(City='FRANKLIN SQUARE'),
#  Row(City='SYOSSET'),
#  Row(City='FLUSH MEADOWS'),
#  Row(City='SUMMERSET'),
#  Row(City='CASTLETON'),
#  Row(City='SAIRPORT'),
#  Row(City='GLENCOVE'),
#  Row(City='LANCASTER'),
#  Row(City='ANONYMOUS'),
#  Row(City='TREVOSE'),
#  Row(City='MORRISTOWN'),
#  Row(City='PITSBURG'),
#  Row(City='MIDDLEVILLAGE'),
#  Row(City='FORT LAUDERDALE'),
#  Row(City='RONTER CENTER'),
#  Row(City='CLIFSIDE PARK'),
#  Row(City='PARK RIDGE'),
#  Row(City='SUNSET'),
#  Row(City='SACRAMENTO'),
#  Row(City='AURORA'),
#  Row(City='HASTINGS ON HUDSON'),
#  Row(City='BRAINTREE'),
#  Row(City='CA'),
#  Row(City='PORT CHESTER'),
#  Row(City='WILLIAMSVILLE'),
#  Row(City='AUSTIN'),
#  Row(City='WATERLOO'),
#  Row(City='SOUTH OZONE PARK'),
#  Row(City='LEONIA'),
#  Row(City='MALVERNE'),
#  Row(City='ENGLEWOOD CLIFF'),
#  Row(City='MALT BONER'),
#  Row(City='FARROCKWAY'),
#  Row(City='ROSLYN'),
#  Row(City='Astoria'),
#  Row(City='LITTLE NECK'),
#  Row(City='Floral Park'),
#  Row(City='WARRENVILLE'),
#  Row(City='OAKLAND GARDENS'),
#  Row(City='NEW ROCHELLE'),
#  Row(City='ELMSDORF'),
#  Row(City='HUNTINGTION'),
#  Row(City='GREENWOOD VILLAGE'),
#  Row(City='South Richmond Hill'),
#  Row(City='FLORAL OARK'),
#  Row(City='INDIANAPOLLIS'),
#  Row(City='NASHVILLE'),
#  Row(City='WEST BABYLON AVE'),
#  Row(City='MONROE'),
#  Row(City='BUFFOLA'),
#  Row(City='SANDERSVILLE'),
#  Row(City='BRADENTON'),
#  Row(City='FANWOOD'),
#  Row(City='WARWICK'),
#  Row(City='FORT WASHINGTON'),
#  Row(City='PARLIN'),
#  Row(City='EL PASO'),
#  Row(City='CITY OF INDUSTRY'),
#  Row(City='SLYVANIA'),
#  Row(City='RICHARDSON'),
#  Row(City='MONTCLAIR'),
#  Row(City='WEST HEMPTSTEAD'),
#  Row(City='PITTSBURGH'),
#  Row(City='LINDEN'),
#  Row(City='RONKONKOMA'),
#  Row(City='STATEN'),
#  Row(City='GROVE CITY'),
#  Row(City='BRIDGEPORT'),
#  Row(City='NEW WINDSOR'),
#  Row(City='Middle Village'),
#  Row(City='New Hyde Park'),
#  Row(City='MAPLEWOOD'),
#  Row(City='WESCHESTER COUNTY'),
#  Row(City='WEST BABYLON'),
#  Row(City='ALBERTSON'),
#  Row(City='TRAVIS'),
#  Row(City='QUEENS'),
#  Row(City='BETHPAGE'),
#  Row(City='MERRICK'),
#  Row(City='WIXON'),
#  Row(City='HILLSDALE'),
#  Row(City='WILLIAMSTOWN'),
#  Row(City='ANDOVER'),
#  Row(City='GRAPE VINE'),
#  Row(City='VALHALLA'),
#  Row(City='PETERBOROUGH'),
#  Row(City='ELMHUSRT'),
#  Row(City='SOMERSET'),
#  Row(City='NORTH SALEM'),
#  Row(City='SECAUCUS'),
#  Row(City='SECACUS'),
#  Row(City='NORTH PLAINFIELD'),
#  Row(City='BABYLON'),
#  Row(City='ROCKAWAY PARK'),
#  Row(City='LEHIGH VALLEY'),
#  Row(City='SINGAPORE'),
#  Row(City='BREWSTER'),
#  Row(City='WASHINGTON'),
#  Row(City='GREATNECK'),
#  Row(City='ROOSEVELT ISLAND'),
#  Row(City='Sunnyside'),
#  Row(City='PARSIPPANY'),
#  Row(City='HAMMOND'),
#  Row(City='BROOKLYN'),
#  Row(City='Saint Albans'),
#  Row(City='ELMHURST'),
#  Row(City='EAST ELMHURST'),
#  Row(City='WEST PALM BEACH'),
#  Row(City='SMITHTOWN'),
#  Row(City='LYNDHURST'),
#  Row(City='NEW  YORK'),
#  Row(City='HAYWARD'),
#  Row(City='College Point'),
#  Row(City='MILLBURN'),
#  Row(City='FAIRPORT'),
#  Row(City='EDINA'),
#  Row(City='STONY POINT'),
#  Row(City='MANALABAN'),
#  Row(City='CORAL SPRINGS'),
#  Row(City='FLUSHING'),
#  Row(City='Long Island City'),
#  Row(City='CLIFFSIDE PARK'),
#  Row(City='NEW'),
#  Row(City='NORTH BALDWIN'),
#  Row(City='COPIAUE'),
#  Row(City='SENTEREACH'),
#  Row(City='Queens Village'),
#  Row(City='WESTCHESTER'),
#  Row(City='BOHENIA'),
#  Row(City='VOORHEES'),
#  Row(City='NORWELL'),
#  Row(City='P.O. BOX 1233'),
#  Row(City='WEST NYACK'),
#  Row(City='ISLAND PARK'),
#  Row(City='RICH FIELD PARK'),
#  Row(City='RYBROOK'),
#  Row(City='JERSY CITY'),
#  Row(City='BAYSHORE'),
#  Row(City='ST.ALBANS'),
#  Row(City='SALEM'),
#  Row(City='Ridgewood'),
#  Row(City='JACKSON HEIGHTS'),
#  Row(City='PHILDELPHIA'),
#  Row(City='UNK'),
#  Row(City='WANTAGH'),
#  Row(City='SCARSDALE'),
#  Row(City='HORSHAM'),
#  Row(City='WOODHAVEN'),
#  Row(City='PLAINVIEUW (NEW YORK'),
#  Row(City='MELLVILLE'),
#  Row(City='LEVITS TOWN'),
#  Row(City='BONX'),
#  Row(City='QWYNN OAKS'),
#  Row(City='HAMDEN'),
#  Row(City='GREELEY'),
#  Row(City='NORTH BABYLON'),
#  Row(City='DUBLIN'),
#  Row(City='VALLEY VIEW'),
#  Row(City='NILES'),
#  Row(City='DALLAS'),
#  Row(City='FAMINDALE'),
#  Row(City='CHARLOTTE'),
#  Row(City='LOCAL'),
#  Row(City='MIDDLE VILLAGE'),
#  Row(City='MASPETH'),
#  Row(City='GLEN ALLEN'),
#  Row(City='BIRMINGHAM'),
#  Row(City='N. CANTON'),
#  Row(City='NEWTON'),
#  Row(City='LINDBROOK'),
#  Row(City='LONG ISLAND CITY'),
#  Row(City='NEWARK'),
#  Row(City='HOBOKEN'),
#  Row(City='WOODBURY'),
#  Row(City='PORT JEFFERSON STATION'),
#  Row(City='NORTH HILLS'),
#  Row(City='FAIRLAWN'),
#  Row(City='LONGWOOD'),
#  Row(City='BERGEN FIELD'),
#  Row(City='BELLEROSE'),
#  Row(City='SOUTH AMBOY'),
#  Row(City='AMYTVILLE'),
#  Row(City='CRANFORD'),
#  Row(City='PATCHOGUE'),
#  Row(City='SAN ANTOINIO'),
#  Row(City='ELMIRA'),
#  Row(City='HOLLYWOOD'),
#  Row(City='CLOSTER'),
#  Row(City='PORT ELIZABETH'),
#  Row(City='METAIRE'),
#  Row(City='UNKNOWN'),
#  Row(City='NOWELL'),
#  Row(City='BK'),
#  Row(City='ENGELWOOD CLIFFS'),
#  Row(City='ATLANTIC BEACH'),
#  Row(City='SOUTHGATE'),
#  Row(City='EAST ROCKAWAY'),
#  Row(City='GLEN COVE'),
#  Row(City='WEST NEW YORK'),
#  Row(City='POUKEPSIE'),
#  Row(City='FRANKLYN SQ'),
#  Row(City='GRAND JUNCTION'),
#  Row(City='BROOKVILLE'),
#  Row(City='PARAMUS'),
#  Row(City='OZONE PARK'),
#  Row(City='SCARDALES'),
#  Row(City='VALLEY SPRING'),
#  Row(City='N.Y'),
#  Row(City='SOLON'),
#  Row(City='LYNWOOD'),
#  Row(City='NASSAU'),
#  Row(City='GRAND RAPIDS'),
#  Row(City='OXFORD'),
#  Row(City='GARDEN CITY'),
#  Row(City='WHTESTONE'),
#  Row(City='CORTLANDT MANOR'),
#  Row(City='PARSITPANY'),
#  Row(City='FLORENCE'),
#  Row(City='HOLTVILLE'),
#  Row(City='TARRYTOWN'),
#  Row(City='HIGHLAND PARK'),
#  Row(City='OZONE  PARK'),
#  Row(City='VILLA PARK'),
#  Row(City='UNION CITY'),
#  Row(City='YORKTOWN'),
#  Row(City='CINCINNATI'),
#  Row(City='OORT WASHINGTON'),
#  Row(City='UNIONDALE'),
#  Row(City='CHICAGO'),
#  Row(City='ST. LOUIS'),
#  Row(City='SOUND BEACH'),
#  Row(City='RENTON'),
#  Row(City='GREENWITCH'),
#  Row(City='PLAINVIEW'),
#  Row(City='NEWBRUGH'),
#  Row(City='WEST ISLIP'),
#  Row(City='REGAL PARK'),
#  Row(City='WAVERLY'),
#  Row(City='WAYLAND'),
#  Row(City='MIDDLE VILLAGE,'),
#  Row(City='FAR ROCKAWY'),
#  Row(City='Arverne'),
#  Row(City='Cambria Heights'),
#  Row(City='ANDERSON'),
#  Row(City='WHYOMING'),
#  Row(City='PEACHTREE CORNERS'),
#  Row(City='COMMACK'),
#  Row(City='PERTH AMBOY'),
#  Row(City='BALDWIN, NASSAU'),
#  Row(City='LAKEWOOD RANCH'),
#  Row(City='HOUSON'),
#  Row(City='PORT WASHINGTON,'),
#  Row(City='EAST AMHERST'),
#  Row(City='X'),
#  Row(City='Brooklyn'),
#  Row(City='EVERETT'),
#  Row(City='BRONX'),
#  Row(City='LEVITTOWN'),
#  Row(City='TAMPA'),
#  Row(City='LONGBEACH'),
#  Row(City='BELLROSE'),
#  Row(City='CARLSTADT'),
#  Row(City='OLD BRIDGE'),
#  Row(City='CHELSEA'),
#  Row(City='BRIELLE'),
#  Row(City='CARLSBAD'),
#  Row(City='SOUTH DAYTONA'),
#  Row(City='FARMINGDALE'),
#  Row(City='SD'),
#  Row(City='WOODCLIFF LAKE'),
#  Row(City='JUANA DIAZ'),
#  Row(City='LINWOOD'),
#  Row(City='FRISCO'),
#  Row(City='BROOKYN'),
#  Row(City='NEWBURGH'),
#  Row(City='MIDLOTHIAN'),
#  Row(City='ROANOKE'),
#  Row(City='LOCKPORT'),
#  Row(City='TERRY TOWN'),
#  Row(City='ISLANDIA,'),
#  Row(City='CITY ISLAND'),
#  Row(City='COLUMBUS'),
#  Row(City='GETTSVILLE'),
#  Row(City='MANALAPAN'),
#  Row(City='LAWRENCE'),
#  Row(City='MEDFORD'),
#  Row(City='NEWPORT BEACH'),
#  Row(City='VALLEY STREET'),
#  Row(City='WILTON'),
#  Row(City='NEW HYDE PRK'),
#  Row(City='EDGEWATER'),
#  Row(City='Woodhaven'),
#  Row(City='HERIETTA'),
#  Row(City='NANUET'),
#  Row(City='EAST WINDSOR'),
#  Row(City='Woodside'),
#  Row(City='HIGHLND PARK'),
#  Row(City='MIAMI BEACH'),
#  Row(City='SEACUCUS'),
#  Row(City='MAHWAH'),
#  Row(City='EAST NORTHPORT'),
#  Row(City='EVANSTON'),
#  Row(City='SONOMA'),
#  Row(City='Fresh Meadows'),
#  Row(City='FREEPORT'),
#  Row(City='NASSAU COUNTY'),
#  Row(City='SATEN ISLAND'),
#  Row(City='BRANDON'),
#  Row(City='COVINA'),
#  Row(City='FRESH MEADOWS'),
#  Row(City='SOUTH RICHMOND HILL'),
#  Row(City='PORTHCHESTER'),
#  Row(City='LOS ANGELES'),
#  Row(City='MINNIAPOLIS'),
#  Row(City='SYOSET'),
#  Row(City='NEW HYDE PARK'),
#  Row(City='NY'),
#  Row(City='PHILADELPHIA'),
#  Row(City='CARLTON'),
#  Row(City='N/A'),
#  Row(City='SOUTH EASTERN'),
#  Row(City='ISLANDER'),
#  Row(City='IRVERING BLVD'),
#  Row(City='HUDSON'),
#  Row(City='BUFFALO'),
#  Row(City='VALLEY STEAM'),
#  Row(City='FORT WORTH'),
#  Row(City='EAST ELM HURST'),
#  Row(City='WEST ORANGE'),
#  Row(City='ALLENVILLE'),
#  Row(City='HUNTINGTON'),
#  Row(City='SAN HOSE'),
#  Row(City='ASTORIA'),
#  Row(City='SAN DIEGO'),
#  Row(City='ST LOUIS'),
#  Row(City='HOLBROOK'),
#  Row(City='PARSITTANY'),
#  Row(City='Maspeth'),
#  Row(City='Springfield Gardens'),
#  Row(City='BOCA RATON'),
#  Row(City='ARCADE'),
#  Row(City='BROOKYN NY'),
#  Row(City='CENTRAL STREAM MORICHES'),
#  Row(City='EASTON'),
#  Row(City='CASPER'),
#  Row(City='BRENTWOOD'),
#  Row(City='HICKSVILLE'),
#  Row(City='ST. PAUL'),
#  Row(City='ST PAUL'),
#  Row(City='HALBROOK'),
#  Row(City='HEMSTEAD'),
#  Row(City='VILLAPARK'),
#  Row(City='QUEEN'),
#  Row(City='MEMPIS'),
#  Row(City='MORNINGSIDE STATION'),
#  Row(City='Jamaica'),
#  Row(City='Bellerose'),
#  Row(City='CEDARHURST'),
#  Row(City='ENGLEWOOD CLIFFS'),
#  Row(City='CARLSPRINGS'),
#  Row(City='GUTTENBURG'),
#  Row(City='MAMARONECK'),
#  Row(City='SPRINGFIELD GARDENS'),
#  Row(City='WALLINGTON'),
#  Row(City='HAUPPAUGE'),
#  Row(City='DOBBS FERRY'),
#  Row(City='VINELAND'),
#  Row(City='TRUMBULL'),
#  Row(City='WARRENTON'),
#  Row(City='HEMPSTEAD'),
#  Row(City='LAKE SUCCESS'),
#  Row(City='EDEN PRAIRIE'),
#  Row(City='WILMINGTON'),
#  Row(City='BROOKLN'),
#  Row(City='CHERRY HILL'),
#  Row(City='EDWARD CLIFTON'),
#  Row(City='WAPPINGERS FALL'),
#  Row(City='GARFIELD'),
#  Row(City='South Ozone Park'),
#  Row(City='NIAGARA FALLS'),
#  Row(City='INGLEWOOD'),
#  Row(City='WEHAWKEEN'),
#  Row(City='LINBROOK'),
#  Row(City='PORTLAND MANOR'),
#  Row(City='WEST HEMPSTEAD'),
#  Row(City='HEMPHSTEAD'),
#  Row(City='PELHAM'),
#  Row(City='KATONAH'),
#  Row(City='MENEAPOLIS'),
#  Row(City='MONTICELLO'),
#  Row(City='PHOROFARA'),
#  Row(City='NORTH PLAIN FIELD'),
#  Row(City='DOYLES TOWN'),
#  Row(City='JERSEY CITY'),
#  Row(City='ELMONT'),
#  Row(City='MASSAPEQUA'),
#  Row(City='PONOMA'),
#  Row(City='LAGUARDIA AIRPORT'),
#  Row(City='ATLANTIC CITY'),
#  Row(City='JACKSONSVILLE'),
#  Row(City='HOWELL'),
#  Row(City='POUND RIDGE'),
#  Row(City='EAST ATLANTIC BEACH'),
#  Row(City='BALDWIN'),
#  Row(City='NEW PORT RICHY'),
#  Row(City='WOODBRIDGE'),
#  Row(City='PISCATAWAY'),
#  Row(City='ARVERNE'),
#  Row(City='WEEHAWKEN'),
#  Row(City='UTICA'),
#  Row(City='AMHERST'),
#  Row(City='GLENRIDGE'),
#  Row(City='INDIANA WELCH'),
#  Row(City='SYRACUSE'),
#  Row(City='OYSTER BAY'),
#  Row(City='P.O. BOX 3615'),
#  Row(City='HUTCHINSON'),
#  Row(City='NEWPORT NEWS'),
#  Row(City='LAKEWORTH'),
#  Row(City='Howard Beach'),
#  Row(City='Breezy Point'),
#  Row(City='N. MERRICK'),
#  Row(City='BROOKSVILLE'),
#  Row(City='MARGATE'),
#  Row(City='RIVER EDGE'),
#  Row(City='TETERBORO'),
#  Row(City='COLUMBIA'),
#  Row(City='MENIFEE'),
#  Row(City='SOMMERSVILLE'),
#  Row(City='NEW YORK'),
#  Row(City='HOWARD BEACH'),
#  Row(City='MINESOTA'),
#  Row(City='LAWERENCE'),
#  Row(City='LAS VEGAS'),
#  Row(City='LOCUST'),
#  Row(City='KNOXVILLE'),
#  Row(City='Ozone Park'),
#  Row(City='WEST MORELAND'),
#  Row(City='TENAFLY'),
#  Row(City='Rosedale'),
#  Row(City='NORTH BERGEN'),
#  Row(City='BROOKHAVEN'),
#  Row(City='CLEVELAND'),
#  Row(City='FORT LAUDERALE'),
#  Row(City='SUNNYSIDE'),
#  Row(City='LYNBROOK'),
#  Row(City='CHESTNUT RIDGE'),
#  Row(City='STATEN ISLAD'),
#  Row(City='NORFORK'),
#  Row(City='STOCKTON'),
#  Row(City='Forest Hills'),
#  Row(City='CLIFTON'),
#  Row(City='AMITYVILLE'),
#  Row(City='RIVERSIDE'),
#  Row(City='PANAMA'),
#  Row(City='SAINT ALBANS'),
#  Row(City='ELMSFORD'),
#  Row(City='BEDFORD'),
#  Row(City='TUIPEA BUFFALO GROVE'),
#  Row(City='PEARL RIVER'),
#  Row(City='RICHARDFIELD PARK'),
#  Row(City='RIVERDALE'),
#  Row(City='DES-PLAINES'),
#  Row(City='MANY'),
#  Row(City='WEST BERRY'),
#  Row(City='BELLEOSE'),
#  Row(City='NORTH BELLMORE'),
#  Row(City='THIELLS'),
#  Row(City='ROACKWAY BEACH'),
#  Row(City='JAMAICA'),
#  Row(City='MINEOLA'),
#  Row(City='FOREST HILLS'),
#  Row(City='PORT WASHINGTON'),
#  Row(City='WEEHAUKEN'),
#  Row(City='000'),
#  Row(City='SAINT CHARLES'),
#  Row(City='MATAWAN'),
#  Row(City='ROSEDALE'),
#  Row(City='SALT LAKE CITY'),
#  Row(City='BOCAROPON'),
#  Row(City='MERINO VALLEY'),
#  Row(City='Far Rockaway'),
#  Row(City='NEWPORT'),
#  Row(City='HORSEHAM'),
#  Row(City='BROX'),
#  Row(City='FARMDALE'),
#  Row(City='RICHMOND HILL'),
#  Row(City='Kew Gardens'),
#  Row(City='YONKER'),
#  Row(City='NEW JERSY'),
#  Row(City='HUNTINGTON BEACH'),
#  Row(City='PORT MONMOUTH'),
#  Row(City='ISELING'),
#  Row(City='RIDGEWOOD'),
#  Row(City='FARMINGVILLE'),
#  Row(City='FAR ROACKAWAY'),
#  Row(City='ALLEN'),
#  Row(City='BALDWIN HARBOUR'),
#  Row(City='HARRISON'),
#  Row(City='LARCHMONT'),
#  Row(City='SAN DEIGO'),
#  Row(City='PATTERSON'),
#  Row(City='IRVINGTON'),
#  Row(City='MINEAPOLIS'),
#  Row(City='HARTSDALE'),
#  Row(City='CALDWELL'),
#  Row(City='CLINTONDALE'),
#  Row(City='STANFORD'),
#  Row(City='TAYLOR'),
#  Row(City='SCHOMBURG'),
#  Row(City='MANHATTAN'),
#  Row(City='OLD BETH PAGE'),
#  Row(City='ENGLEWOOD'),
#  Row(City='SIOUX FALL'),
#  Row(City='BLOOMINTON'),
#  Row(City='SEAFORD'),
#  Row(City='DELMORE'),
#  Row(City='Rockaway Park'),
#  Row(City='FLUSHNG'),
#  Row(City='HARRISBURG'),
#  Row(City='EAST HARTFORD'),
#  Row(City='FARMNGDALE'),
#  Row(City='COLLEGEPOINT'),
#  Row(City='QUEENS VILLAGE'),
#  Row(City='NORWALK'),
#  Row(City='JACKSON'),
#  Row(City='MIDDLETOWN'),
#  Row(City='STATEN ISLAND'),
#  Row(City='YONKERS'),
#  Row(City='ISELIN'),
#  Row(City='CAMBRIDGE'),
#  Row(City='TEANECK'),
#  Row(City='EAST RUTHERFORD'),
#  Row(City='FAIRFIELD'),
#  Row(City='DID NOT DISCLOSE'),
#  Row(City='GRAY NECK'),
#  Row(City='WINSTON-SALEM'),
#  Row(City='SIOUX FALLS'),
#  Row(City='YORKTOWN HEIGHTS'),
#  Row(City='LONG SLAND'),
#  Row(City='New York'),
#  Row(City='ROCKVILLE CENTER'),
#  Row(City='FOLSOM'),
#  Row(City='STANDFORD'),
#  Row(City='LANGHORNE'),
#  Row(City='HOLLIS'),
#  Row(City='SAINT PAUL'),
#  Row(City='NORFOLK'),
#  Row(City='PLANO'),
#  Row(City='INDIAN WELLS'),
#  Row(City='COSTA MESA'),
#  Row(City='WOODSIDE'),
#  Row(City='GLEN OAKS'),
#  Row(City='CANOOGA PARK'),
#  Row(City='OKLAHOMA CITY'),
#  Row(City='Manhattan'),
#  Row(City='WLLINGTON'),
#  Row(City='LINDENHURST'),
#  Row(City='POMPANO BEACH'),
#  Row(City='HASBROUCK'),
#  Row(City='SAN FRANCISCO'),
#  Row(City='Bronx'),
#  Row(City='SANDIEGO'),
#  Row(City='CARLE   PL'),
#  Row(City='CARLE PLACE'),
#  Row(City='PUTNAM VALLEY'),
#  Row(City='CARSON CITY'),
#  Row(City='HAMILTON'),
#  Row(City='MELVILLE'),
#  Row(City='SUMMIT'),
#  Row(City='ELMUNT'),
#  Row(City='WILLINGBORO'),
#  Row(City='STATEN  ISLAND'),
#  Row(City='SAINT ALBANY'),
#  Row(City='FRAKLIN SQUARE'),
#  Row(City='WILKES BARRE'),
#  Row(City='OLD BECHPAGE'),
#  Row(City='MANATTAN'),
#  Row(City='NEW TOWN'),
#  Row(City='COLLEGE POINT'),
#  Row(City='HACKENSACK'),
#  Row(City='DEERFIELD BEACH'),
#  Row(City='VESTAL'),
#  Row(City='NEW YORK CITY'),
#  Row(City='BKLYN'),
#  Row(City='MELVILL'),
#  Row(City='Hollis'),
#  Row(City='WILLISTON PARK'),
#  Row(City='OVERLAND PARK'),
#  Row(City='HAWTHORNE'),
#  Row(City='NYC'),
#  Row(City='ST. CHARLES'),
#  Row(City='CRESSAILL'),
#  Row(City='Elmhurst'),
#  Row(City='EDISON'),
#  Row(City='ALBANY'),
#  Row(City='OMAHA'),
#  Row(City='BOSTON'),
#  Row(City='HASBROUK HEIGHTS')]

# %% [markdown]
# ## II. Accuracy
#
# We describe accurate data as data that is close to the true, expected values. As we explored our dataset, we found that there are several inaccurate cities in the city column. To explore the accuracy in the city column, we found and downloadeded a dataset ([uszips.csv](https://drive.google.com/file/d/1qd2cXgTx-h-hRd0C7z2s_U4O8VYLAXA7/view?usp=sharing)) that contains information such as US zipcode, state name, city, etc. We use this dataset as baseline to compare to our dataset to find any inaccuracies, such as misspellings.

# %% [markdown]
# Before we start, make sure to download and upload the [uszips.csv](https://drive.google.com/file/d/1qd2cXgTx-h-hRd0C7z2s_U4O8VYLAXA7/view?usp=sharing) dataset into the same folder/directory as where our dataset resides (i.e. for this colab notebook environment, the current working directory path should be /content/drive/MyDrive/evq_311_service_proj and the datasets should all be placed in the dataset/ folder inside the current working directory).

# %%
# Define path for US zip dataset
uszip_path = "./dataset/uszips.csv"

# %%
# Read the US zip dataset
us = spark.read.csv(uszip_path, header=True)
us = us.withColumn("zip",us["zip"].cast(IntegerType()))
us = us.withColumn("lat",us["lat"].cast(DoubleType()))
us = us.withColumn("lng",us["lng"].cast(DoubleType()))
us.show()
# Out:
# +---+--------+---------+-------------+--------+-----------+----+-----------+----------+-------+-----------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |zip|     lat|      lng|         city|state_id| state_name|zcta|parent_zcta|population|density|county_fips|  county_name|      county_weights|    county_names_all|     county_fips_all|           imprecise|            military|            timezone|
# +---+--------+---------+-------------+--------+-----------+----+-----------+----------+-------+-----------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |601|18.18005|-66.75218|     Adjuntas|      PR|Puerto Rico|TRUE|       null|     17113|  102.7|      72001|     Adjuntas|"{""72001"": ""99...| ""72141"": ""0.5...|     Adjuntas|Utuado|         72001|72141|               FALSE|               FALSE|
# |602|18.36074|-67.17519|       Aguada|      PR|Puerto Rico|TRUE|       null|     37751|  476.0|      72003|       Aguada|"{""72003"": ""10...|              Aguada|               72003|               FALSE|               FALSE| America/Puerto_Rico|
# |603| 18.4544|-67.12201|    Aguadilla|      PR|Puerto Rico|TRUE|       null|     47081|  574.9|      72005|    Aguadilla|"{""72005"": ""10...|           Aguadilla|               72005|               FALSE|               FALSE| America/Puerto_Rico|
# |606|18.16721|-66.93828|      Maricao|      PR|Puerto Rico|TRUE|       null|      6392|   58.3|      72093|      Maricao|"{""72093"": ""94...| ""72153"": ""3.78""| ""72121"": ""1.3...|Maricao|Yauco|Sab...|   72093|72153|72121|               FALSE|
# |610|18.29032|-67.12244|       Anasco|      PR|Puerto Rico|TRUE|       null|     26686|  286.9|      72011|       Añasco|"{""72011"": ""99...| ""72003"": ""0.5...|       Añasco|Aguada|         72011|72003|               FALSE|               FALSE|
# |612|18.40699|-66.70805|      Arecibo|      PR|Puerto Rico|TRUE|       null|     59369|  339.1|      72013|      Arecibo|"{""72013"": ""99...| ""72017"": ""0.1...| Arecibo|Barceloneta|         72013|72017|               FALSE|               FALSE|
# |616|18.41752|-66.66814|     Bajadero|      PR|Puerto Rico|TRUE|       null|     10022|  335.6|      72013|      Arecibo|"{""72013"": ""10...|             Arecibo|               72013|               FALSE|               FALSE| America/Puerto_Rico|
# |617|18.44125|-66.55916|  Barceloneta|      PR|Puerto Rico|TRUE|       null|     23750|  603.5|      72017|  Barceloneta|"{""72017"": ""99...| ""72054"": ""0.5...| Barceloneta|Florida|         72017|72054|               FALSE|               FALSE|
# |622|17.99174|-67.15248|     Boqueron|      PR|Puerto Rico|TRUE|       null|      6741|   89.8|      72023|    Cabo Rojo|"{""72023"": ""10...|           Cabo Rojo|               72023|               FALSE|               FALSE| America/Puerto_Rico|
# |623|18.08354|-67.15418|    Cabo Rojo|      PR|Puerto Rico|TRUE|       null|     41746|  424.5|      72023|    Cabo Rojo|"{""72023"": ""10...|           Cabo Rojo|               72023|               FALSE|               FALSE| America/Puerto_Rico|
# |624|18.06465|-66.71823|     Penuelas|      PR|Puerto Rico|TRUE|       null|     21936|  196.2|      72111|     Peñuelas|"{""72111"": ""92...| ""72113"": ""7.4...|      Peñuelas|Ponce|         72111|72113|               FALSE|               FALSE|
# |627|  18.419|-66.86033|        Camuy|      PR|Puerto Rico|TRUE|       null|     31598|  263.2|      72027|        Camuy|"{""72027"": ""10...|               Camuy|               72027|               FALSE|               FALSE| America/Puerto_Rico|
# |631|18.18555|-66.83327|     Castaner|      PR|Puerto Rico|TRUE|       null|      1499|  143.9|      72081|        Lares|"{""72081"": ""67...| ""72001"": ""32....|      Lares|Adjuntas|         72081|72001|               FALSE|               FALSE|
# |637| 18.0798|-66.94274|Sabana Grande|      PR|Puerto Rico|TRUE|       null|     22383|  250.9|      72121|Sabana Grande|"{""72121"": ""99...| ""72153"": ""0.4...| Sabana Grande|Yauco|         72121|72153|               FALSE|               FALSE|
# |638|18.28905| -66.5151|       Ciales|      PR|Puerto Rico|TRUE|       null|     16412|   95.9|      72039|       Ciales|"{""72039"": ""98...| ""72091"": ""1.7...|       Ciales|Manatí|         72039|72091|               FALSE|               FALSE|
# |641|18.26408|-66.71376|       Utuado|      PR|Puerto Rico|TRUE|       null|     26712|  110.3|      72141|       Utuado|"{""72141"": ""99...| ""72001"": ""0.2...|     Utuado|Adjuntas|         72141|72001|               FALSE|               FALSE|
# |646|18.43401| -66.2833|       Dorado|      PR|Puerto Rico|TRUE|       null|     37095|  691.0|      72051|       Dorado|"{""72051"": ""99...| ""72143"": ""0.1...|    Dorado|Vega Alta|         72051|72143|               FALSE|               FALSE|
# |647|17.96612|-66.94383|     Ensenada|      PR|Puerto Rico|TRUE|       null|      5809|  147.5|      72055|      Guánica|"{""72055"": ""98...| ""72079"": ""1.1...|       Guánica|Lajas|         72055|72079|               FALSE|               FALSE|
# |650|18.34321|-66.58601|      Florida|      PR|Puerto Rico|TRUE|       null|     14534|  183.9|      72054|      Florida|"{""72054"": ""83...| ""72141"": ""11....| ""72017"": ""1.91""| ""72013"": ""1.51""| ""72039"": ""1.1...|Florida|Utuado|Ba...|
# |652|18.45542|-66.60635|  Garrochales|      PR|Puerto Rico|TRUE|       null|      3565|  199.0|      72013|      Arecibo|"{""72013"": ""10...|             Arecibo|               72013|               FALSE|               FALSE| America/Puerto_Rico|
# +---+--------+---------+-------------+--------+-----------+----+-----------+----------+-------+-----------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# Once the dataset is uploaded, run the following cells to observe the problem.

# %%
# All distinct cities present in the dataset
temp_df_1 = df.select("City").distinct() 
list_of_cities = list(temp_df_1.toPandas()['City']) 

# All cities present in the US zip dataset
list_of_correct_cities =  list(us.select("city").distinct().toPandas()['city'])

# %%
list_of_wrong_cities = []

for i in list_of_cities:
  if i not in list_of_correct_cities:
    list_of_wrong_cities.append(i)

# First 20 mispelled words
list_of_wrong_cities[:20]
# Out:
# ['PRINCETON',
#  'HUDSON COUNTY',
#  'HUSTON',
#  'NESCONSET',
#  'WATERTOWN',
#  'RARITAN',
#  'SOUTH FLORAL PARK',
#  'VALLEY STREAM',
#  'STAMFORD',
#  'ISLAND',
#  'SELINA',
#  'CHINO',
#  'RIDGEFIELD PARK',
#  'ELMHERST',
#  'BOLTIMORE',
#  'ALPHARATTA',
#  'DEAR PARK',
#  'LIDO BEACH',
#  'SOMERVILLE',
#  'NEW JERSEY']

# %% [markdown]
# As we can observe from the results of running the cells, there are inaccuracies in the cities that are listed in the city column of our 311 service dataset. For instance, "NEW JERSEY" is a state, not a city and "HUSTON" is a misspelling for Houston, a city in Texas.

# %% [markdown]
# ## III. Inconsistency
#
# We describe inconsistent data as data that contains values that contradict each other or contains value that is not what we would expect based on the column that it is in. As we explored our dataset, we observed inconsistency problems in both the Agency and Agency Name columns in the 311 service dataset. We attempted to find a dataset that might contain all agency names and information, but we could not find a complete dataset. Instead, we decided to create our own custom dataset using the data from https://www1.nyc.gov/nyc-resources/agencies.page along with the addition of other agencies that showed up on the NYC open data website. Our dataset can be downloaded/accessed via this link: [NYC-Agency-Names.csv](https://drive.google.com/file/d/1EHpyXNOwCpv-NM0OTTqFBHeKikKpBtd1/view?usp=sharing). We use this dataset as baseline to compare to the corresponding columns in our 311 service dataset.

# %% [markdown]
# Just as before, make sure to download and upload the [NYC-Agency-Names.csv](https://drive.google.com/file/d/1EHpyXNOwCpv-NM0OTTqFBHeKikKpBtd1/view?usp=sharing) dataset into the same folder/directory as where our dataset resides (i.e. for this colab notebook environment, the current working directory path should be /content/drive/MyDrive/evq_311_service_proj and the datasets should all be placed in the dataset/ folder inside the current working directory).

# %% [markdown]
# ### Explore Agency column

# %%
# Define path for NYC Agency Names dataset
nycAgencyNames_path = "./dataset/NYC-Agency-Names.csv"

# %%
# Read NYC Agency Names dataset 
agency_df = spark.read.csv(nycAgencyNames_path, header=True)

# %%
# Show Schema for NYC Agency Names dataset
agency_df.printSchema()
# Out:
# root
#  |-- Agency Acronym: string (nullable = true)
#  |-- Agency: string (nullable = true)

# %% [markdown]
# Once the dataset is uploaded, run the following cells to observe the problem.

# %%
# View data from Agency column
from pyspark.sql.functions import asc

df.select("Agency").distinct().orderBy(asc("Agency")).show(df.count(), False)
# Out:
# +---------------------------------------+
# |Agency                                 |
# +---------------------------------------+
# |3-1-1                                  |
# |ACS                                    |
# |CEO                                    |
# |COIB                                   |
# |DCA                                    |
# |DCAS                                   |
# |DCP                                    |
# |DEP                                    |
# |DFTA                                   |
# |DHS                                    |
# |DOB                                    |
# |DOE                                    |
# |DOF                                    |
# |DOHMH                                  |
# |DOITT                                  |
# |DORIS                                  |
# |DOT                                    |
# |DPR                                    |
# |DSNY                                   |
# |DVS                                    |
# |EDC                                    |
# |FDNY                                   |
# |HPD                                    |
# |HRA                                    |
# |MAYORâS OFFICE OF SPECIAL ENFORCEMENT|
# |MOC                                    |
# |NYCEM                                  |
# |NYPD                                   |
# |TAT                                    |
# |TAX                                    |
# |TLC                                    |
# +---------------------------------------+

# %%
# All distinct Agency present in the dataset
temp_df2 = df.select("Agency").distinct() 
list_of_agencies = list(temp_df2.toPandas()['Agency']) 

# All Agency present in the NYC Agency Names dataset
list_of_correct_agencies = list(agency_df.select("Agency Acronym").distinct().toPandas()['Agency Acronym'])

# %%
# Show list of Agency that were not in the dataset with uniform names
list_of_wrong_agencies = []

for i in list_of_agencies:
  if i not in list_of_correct_agencies:
    list_of_wrong_agencies.append(i)

# Show the first 20 in the list
list_of_wrong_agencies[:20]
# Out:
# ['MAYORâ\x80\x99S OFFICE OF SPECIAL ENFORCEMENT', '3-1-1', 'TAX', 'MOC', 'CEO']

# %%
# Count how many rows have MAYORâ in the Agency column
df.filter(df["Agency"][0:6] == "MAYORâ").count()
# Out:
# 14237

# %% [markdown]
# As we can observe from the results of running the previous cells, there is inconsistent data where every other value in the column in an acronym, but we also have "MAYORâ\x80\x99S OFFICE OF SPECIAL ENFORCEMENT", which is not an acronym. By counting, we find that the number of rows in Agency column that has "MAYORâ" as part of the value is 14,237. Theoretically, we would solve the issue by finding out if the corresponding "Agency Name" is in our database, but for this smaller dataset and for simpliciy sake, we plan to just filter these values out.
#
# Additionally, there is one minor problem where the apostrophe in "Mayor's" did not store correctly and turned into gibberish. Since this only happens in one specific case of "MAYORâS OFFICE OF SPECIAL ENFORCEMENT", the solution will be very specific to fix this problem.
#
# There also might be some inaccuracies which resulted in the other values like "TAX" and "CEO". Note that even though "3-1-1" showed up in the list above, it is actually correct; this is because it is listed in the NYC Agency Names dataset as "311" without the dashes.

# %% [markdown]
# ### Explore Agency Name column

# %%
# View data from Agency Name column
df.select("Agency Name").distinct().orderBy(asc("Agency Name")).show(df.count(), False)
# Out:
# +--------------------------------------------------------------------------------------------------+
# |Agency Name                                                                                       |
# +--------------------------------------------------------------------------------------------------+
# |3-1-1                                                                                             |
# |3-1-1 Call Center                                                                                 |
# |311 Administrative Supervisor                                                                     |
# |A - Bronx                                                                                         |
# |A - Brooklyn                                                                                      |
# |A - Canine Task Force Citywide                                                                    |
# |A - Illegal Posting Manhattan and Bronx                                                           |
# |A - Illegal Posting Staten Island, Queens and Brooklyn                                            |
# |A - Manhattan                                                                                     |
# |A - Queens                                                                                        |
# |A - Staten Island                                                                                 |
# |ACS                                                                                               |
# |Accounts Examination                                                                              |
# |Adjudication - Appeals Unit                                                                       |
# |Adjudication - Hearing by Mail                                                                    |
# |Alternative Superintendency                                                                       |
# |BCC - Bronx                                                                                       |
# |BCC - Brooklyn North                                                                              |
# |BCC - Brooklyn South                                                                              |
# |BCC - Manhattan                                                                                   |
# |BCC - Queens East                                                                                 |
# |BCC - Queens West                                                                                 |
# |BCC - Staten Island                                                                               |
# |Bronx 03                                                                                          |
# |Bronx 04                                                                                          |
# |Bronx 05                                                                                          |
# |Bronx 08                                                                                          |
# |Bronx 10                                                                                          |
# |Bronx 11                                                                                          |
# |Brooklyn North 03                                                                                 |
# |Brooklyn South 10                                                                                 |
# |CEO                                                                                               |
# |CFC - Bronx                                                                                       |
# |CFC - Staten Island                                                                               |
# |COIB                                                                                              |
# |Central - Department of Education                                                                 |
# |Child Care and Camps Complaint Unit                                                               |
# |Commercial Exemption Unit                                                                         |
# |Condo or CoOp Unit                                                                                |
# |Correspondence - Taxi and Limousine Commission                                                    |
# |Correspondence Unit                                                                               |
# |DCA                                                                                               |
# |DCAS                                                                                              |
# |DCP                                                                                               |
# |DFTA                                                                                              |
# |DHS Advantage Programs                                                                            |
# |DOB                                                                                               |
# |DOB Inspections - Bronx                                                                           |
# |DOB Inspections - Brooklyn                                                                        |
# |DOB Inspections - Manhattan                                                                       |
# |DOB Inspections - Queens                                                                          |
# |DOB Inspections - Staten Island                                                                   |
# |DOF                                                                                               |
# |DOF Legal Affairs - Taxpayer Services Unit                                                        |
# |DOHMH                                                                                             |
# |DOT                                                                                               |
# |DPR                                                                                               |
# |DRIE Unit                                                                                         |
# |DVS                                                                                               |
# |Department for the Aging                                                                          |
# |Department of Buildings                                                                           |
# |Department of Consumer Affairs                                                                    |
# |Department of Education                                                                           |
# |Department of Environmental Protection                                                            |
# |Department of Health and Mental Hygiene                                                           |
# |Department of Homeless Services                                                                   |
# |Department of Housing Preservation and Development                                                |
# |Department of Information Technology and Telecommunications                                       |
# |Department of Parks and Recreation                                                                |
# |Department of Sanitation                                                                          |
# |Department of Transportation                                                                      |
# |Disability Rent Increase Exemption Unit                                                           |
# |Discrepancy and Billing                                                                           |
# |Division of Alternative Management                                                                |
# |DoITT                                                                                             |
# |Dunning Unit                                                                                      |
# |Early Care and Education Information Unit                                                         |
# |Economic Development Corporation                                                                  |
# |Exemption Policy Unit                                                                             |
# |Exemption Unit                                                                                    |
# |External Affairs Unit                                                                             |
# |Fire Department of New York                                                                       |
# |HPD                                                                                               |
# |HRA Benefit Card Replacement                                                                      |
# |HealthCare Connections                                                                            |
# |Investigation Review Section                                                                      |
# |Land Records                                                                                      |
# |LinkNYC Unit                                                                                      |
# |Lot Cleaning                                                                                      |
# |MOC                                                                                               |
# |Manhattan 01                                                                                      |
# |Manhattan 02                                                                                      |
# |Manhattan 03                                                                                      |
# |Manhattan 04                                                                                      |
# |Manhattan 05                                                                                      |
# |Manhattan 06                                                                                      |
# |Manhattan 07                                                                                      |
# |Manhattan 08                                                                                      |
# |Mayorâs Office of Special Enforcement                                                           |
# |Mosquito Control                                                                                  |
# |Municipal Archives                                                                                |
# |NYC Emergency Management                                                                          |
# |NYCEM Property Damage                                                                             |
# |NYPD                                                                                              |
# |New York City Police Department                                                                   |
# |Office of the Sheriff                                                                             |
# |Office of the Taxpayer Advocate                                                                   |
# |Operations Unit - Department of Homeless Services                                                 |
# |P - Brooklyn and Staten Island                                                                    |
# |P - Commercial Recycling Citywide                                                                 |
# |P - Manhattan and Bronx                                                                           |
# |P - Queens                                                                                        |
# |Payment Operations                                                                                |
# |Personal Exemption Unit                                                                           |
# |Property Exec Office                                                                              |
# |Queens East 10                                                                                    |
# |Queens East 12                                                                                    |
# |Queens West 02                                                                                    |
# |Queens West 03                                                                                    |
# |Queens West 04                                                                                    |
# |Queens West 06                                                                                    |
# |RPIE Unit                                                                                         |
# |Refunds and Adjustments                                                                           |
# |Revenue Accounting                                                                                |
# |School - 47 The American Sign Language and English Secondary School                               |
# |School - A Philip Randolph Campus High School                                                     |
# |School - ACE Academy for Scholars at the Geraldine Ferraro Campus                                 |
# |School - ACORN Community High School                                                              |
# |School - ALC Brooklyn Choices                                                                     |
# |School - ALC Choir Academy                                                                        |
# |School - ALC Fundamentals Academy                                                                 |
# |School - ALC John Jay                                                                             |
# |School - Abraham Lincoln High School                                                              |
# |School - Academy for College Preparation and Career Exploration: A College Board School           |
# |School - Academy for Environmental Leadership                                                     |
# |School - Academy for Health Careers                                                               |
# |School - Academy for Personal Leadership and Excellence                                           |
# |School - Academy for Social Action                                                                |
# |School - Academy of American Studies                                                              |
# |School - Academy of Arts and Letters                                                              |
# |School - Academy of Collaborative Education                                                       |
# |School - Academy of Finance and Enterprise                                                        |
# |School - Access GED - East at South Shore High School                                             |
# |School - Achievement First Apollo Charter School                                                  |
# |School - Achievement First Brownsville Charter School                                             |
# |School - Achievement First Crown Heights Charter School                                           |
# |School - Acorn High School for Social Justice                                                     |
# |School - Adlai E Stevenson High School                                                            |
# |School - Adult and Continuing Education                                                           |
# |School - Albert Shanker School for Visual and Performing Arts                                     |
# |School - Ampark Neighborhood                                                                      |
# |School - Andries Hudde                                                                            |
# |School - Archimedes Academy for Math, Science and Technology Applications                         |
# |School - Art and Design High School                                                               |
# |School - August Martin High School                                                                |
# |School - Automotive High School                                                                   |
# |School - Aviation Career and Technical Education High School                                      |
# |School - Baccalaureate School for Global Education                                                |
# |School - Baruch College Campus High School                                                        |
# |School - Bayard Rustin Educational Complex                                                        |
# |School - Bayside High School                                                                      |
# |School - Beach Channel High School                                                                |
# |School - Beacon High School                                                                       |
# |School - Bedford Park Elementary School                                                           |
# |School - Bedford Stuyvesant New Beginnings Charter School                                         |
# |School - Bedford Stuyvesant Preparatory High School                                               |
# |School - Benjamin Banneker Academy                                                                |
# |School - Benjamin N Cardozo High School                                                           |
# |School - Boys and Girls High School                                                               |
# |School - Bread and Roses Integrated Arts High School                                              |
# |School - Bronx Academy for Software Engineering (BASE)                                            |
# |School - Bronx Academy of Health Careers                                                          |
# |School - Bronx Aerospace High School                                                              |
# |School - Bronx Career and College Preparatory High School                                         |
# |School - Bronx Center for Science and Mathematics                                                 |
# |School - Bronx Charter School for Children                                                        |
# |School - Bronx Collaborative High School                                                          |
# |School - Bronx Delta School                                                                       |
# |School - Bronx Green Middle School                                                                |
# |School - Bronx Health Sciences High School                                                        |
# |School - Bronx High School for Medical Science                                                    |
# |School - Bronx High School for the Visual Arts                                                    |
# |School - Bronx International High School                                                          |
# |School - Bronx Leadership Academy High School                                                     |
# |School - Bronx Lighthouse Charter School                                                          |
# |School - Bronx River High School                                                                  |
# |School - Bronx School for Law, Government and Justice                                             |
# |School - Bronx Theatre High School                                                                |
# |School - Bronx Writing Academy                                                                    |
# |School - Brooklyn Brownstone School                                                               |
# |School - Brooklyn Democracy Academy                                                               |
# |School - Brooklyn Dreams Charter School                                                           |
# |School - Brooklyn High School for Leadership and Community Service                                |
# |School - Brooklyn High School of the Arts                                                         |
# |School - Brooklyn Institute for Liberal Arts                                                      |
# |School - Brooklyn Landmark Elementary School                                                      |
# |School - Brooklyn Scholars Charter School                                                         |
# |School - Brooklyn School for Music and Theatre                                                    |
# |School - Brooklyn School of Inquiry                                                               |
# |School - Brooklyn Secondary School for Collaborative Studies                                      |
# |School - Brooklyn Studio Secondary School                                                         |
# |School - Brooklyn Technical High School                                                           |
# |School - Brooklyn Urban Garden Charter School                                                     |
# |School - Bushwick Community High School                                                           |
# |School - Bushwick Leaders High School for Academic Excellence                                     |
# |School - Business, Computer Applications, and Entrepreneurship High School                        |
# |School - CSI High School for International Studies                                                |
# |School - Cambria Heights Academy                                                                  |
# |School - Canarsie Ascend Charter School                                                           |
# |School - Carl C Icahn Bronx North Charter School                                                  |
# |School - Carl C Icahn South Bronx Charter School                                                  |
# |School - Castle Bridge School                                                                     |
# |School - Catherine and Count Basie MS 72                                                          |
# |School - Celia Cruz Bronx High School of Music                                                    |
# |School - Central Park East I                                                                      |
# |School - Challenge Preparatory Charter School                                                     |
# |School - Choir Academy of Harlem                                                                  |
# |School - City College Academy of the Arts                                                         |
# |School - Clara Barton High School                                                                 |
# |School - Cobble Hill School of American Studies                                                   |
# |School - Collaborative Academy of Science, Technology, and Law                                    |
# |School - Collaborative Arts Middle School                                                         |
# |School - Columbia Secondary School                                                                |
# |School - Community Action School MS 258                                                           |
# |School - Community Health Academy of the Heights                                                  |
# |School - Community Math and Science Prep                                                          |
# |School - Community Voices Middle School                                                           |
# |School - Comprehensive Model School Project MS 327                                                |
# |School - Conselyea Preparatory School                                                             |
# |School - Cornerstone Academy for Social Action                                                    |
# |School - Curtis High School                                                                       |
# |School - Cynthia Jenkins School                                                                   |
# |School - DREAM Charter School                                                                     |
# |School - DeWitt Clinton High School                                                               |
# |School - Democracy Prep Endurance Charter School                                                  |
# |School - Democracy Prep Harlem Charter School                                                     |
# |School - Dock Street School for STEAM Studies                                                     |
# |School - Dr Jacqueline Peek-Davis School                                                          |
# |School - EBC High School for Public Service Bushwick                                              |
# |School - Eagle Academy for Young Men II                                                           |
# |School - Eagle Academy for Young Men III                                                          |
# |School - East Brooklyn Community High School                                                      |
# |School - East Flatbush Community Research School                                                  |
# |School - East Harlem Scholars Academy Charter School                                              |
# |School - East Harlem Scholars Academy Charter School II                                           |
# |School - East New York Elementary School of Excellence                                            |
# |School - East New York Family Academy                                                             |
# |School - East Side Community School                                                               |
# |School - Ebbets Field Middle School                                                               |
# |School - Edward A Reynolds West Side High School                                                  |
# |School - Edward R Murrow High School                                                              |
# |School - El Puente Academy for Peace and Justice                                                  |
# |School - Eleanor Roosevelt High School                                                            |
# |School - Elijah Stroud Middle School                                                              |
# |School - Ella Baker School                                                                        |
# |School - Elm Tree Elementary School                                                               |
# |School - Enterprise, Business, and Technology High School                                         |
# |School - Esperanza Preparatory Academy                                                            |
# |School - Essence School                                                                           |
# |School - Essex Street Academy                                                                     |
# |School - Evander Childs Evening High School                                                       |
# |School - Explorations Academy High School                                                         |
# |School - Explore Charter School                                                                   |
# |School - Explore Exceed Charter School                                                            |
# |School - Fairmont Neighborhood School                                                             |
# |School - Family Life Academy Charter School                                                       |
# |School - Family Life Academy Charter School II                                                    |
# |School - Fannie Lou Hamer Freedom High School                                                     |
# |School - Fiorello H LaGuardia High School of Music and Art and Performing Arts                    |
# |School - Flushing High School                                                                     |
# |School - Food and Finance High School                                                             |
# |School - Fordham Leadership Academy                                                               |
# |School - Forest Hills High School                                                                 |
# |School - Fort Hamilton High School                                                                |
# |School - Foundations Academy                                                                      |
# |School - Francis Lewis High School                                                                |
# |School - Frank Mccourt High School                                                                |
# |School - Franklin Delano Roosevelt High School                                                    |
# |School - Franklin K Lane Campus YABC                                                              |
# |School - Franklin K Lane High School                                                              |
# |School - Frederick Douglass Academy                                                               |
# |School - Frederick Douglass Academy II Secondary School                                           |
# |School - Frederick Douglass Academy III Secondary School                                          |
# |School - Frederick Douglass Academy IV Secondary School                                           |
# |School - Frederick Douglass Academy VI High School                                                |
# |School - Frederick Douglass Academy VII High School                                               |
# |School - Frederick Douglass Academy VIII Middle School                                            |
# |School - Gateway School for Environmental Research and Technology                                 |
# |School - Gaynor McCown Expeditionary Learning School                                              |
# |School - George Washington Carver High School for the Sciences                                    |
# |School - George Washington YABC                                                                   |
# |School - George Westinghouse Career and Technical Education High School                           |
# |School - Global Neighborhood Secondary School                                                     |
# |School - Goldie Maple Academy                                                                     |
# |School - Grace Dodge Career and Technical Education High School                                   |
# |School - Gramercy Arts High School                                                                |
# |School - Grant Avenue Elementary School                                                           |
# |School - Gregorio Luperon High School for Science and Mathematics                                 |
# |School - Grover Cleveland High School                                                             |
# |School - Growing Up Green Charter School                                                          |
# |School - Harlem Children's Zone Promise Academy II                                                |
# |School - Harlem Children's Zone Promise Academy II Charter School                                 |
# |School - Harriet Tubman Charter School                                                            |
# |School - Harry S Truman High School                                                               |
# |School - Harvest Collegiate High School                                                           |
# |School - Hebrew Language Academy Charter School                                                   |
# |School - Herbert H Lehman High School                                                             |
# |School - Herbert H Lehman YABC                                                                    |
# |School - High School for Community Leadership                                                     |
# |School - High School for Construction Trades, Engineering and Architecture                        |
# |School - High School for Environmental Studies                                                    |
# |School - High School for Excellence and Innovation                                                |
# |School - High School for Health Professions and Human Services                                    |
# |School - High School for Law, Advocacy, and Community Justice                                     |
# |School - High School for Leadership and Public Service                                            |
# |School - High School for Mathematics, Science and Engineering at City College                     |
# |School - High School for Medical Professions                                                      |
# |School - High School for Service and Learning at Erasmus                                          |
# |School - High School for Youth and Community Development at Erasmus                               |
# |School - High School of Arts and Technology                                                       |
# |School - High School of Economics and Finance                                                     |
# |School - High School of Graphic Communication Arts                                                |
# |School - High School of Hospitality Management                                                    |
# |School - High School of Sports Management                                                         |
# |School - High School of Telecommunication Arts and Technology                                     |
# |School - Hillcrest High School                                                                    |
# |School - Hostos-Lincoln Academy of Science                                                        |
# |School - Hunters Point Community Middle School                                                    |
# |School - Hyde Leadership Charter School Bronx                                                     |
# |School - IS 10 Horace Greeley                                                                     |
# |School - IS 117 Joseph H Wade                                                                     |
# |School - IS 119 The Glendale                                                                      |
# |School - IS 125 Thom J McCann Woodside                                                            |
# |School - IS 131 Dr Sun Yat Sen                                                                    |
# |School - IS 136 Charles O Dewey                                                                   |
# |School - IS 141 The Steinway                                                                      |
# |School - IS 145 Joseph Pulitzer                                                                   |
# |School - IS 171 Abraham Lincoln                                                                   |
# |School - IS 181 Pablo Casals                                                                      |
# |School - IS 192 The Linden                                                                        |
# |School - IS 195 Roberto Clemente                                                                  |
# |School - IS 2 George L Egbert                                                                     |
# |School - IS 206 Ann Mersereau                                                                     |
# |School - IS 211 John Wilson                                                                       |
# |School - IS 218 Salome Urena                                                                      |
# |School - IS 219 New Venture School                                                                |
# |School - IS 227 Louis Armstrong                                                                   |
# |School - IS 228 David A Boody                                                                     |
# |School - IS 229 Roland Patterson                                                                  |
# |School - IS 230                                                                                   |
# |School - IS 231 Magnetech 2000                                                                    |
# |School - IS 237                                                                                   |
# |School - IS 238 Susan B Anthony Academy                                                           |
# |School - IS 24 Myra S Barnes                                                                      |
# |School - IS 25 Adrien Block                                                                       |
# |School - IS 250 The Robert F Kennedy Community Middle School                                      |
# |School - IS 27 Anning S Prall                                                                     |
# |School - IS 281 Joseph B Cavallaro                                                                |
# |School - IS 285 Meyer Levin                                                                       |
# |School - IS 296 The Anna Gonzalez Community School                                                |
# |School - IS 303 Herbert S Eisenberg                                                               |
# |School - IS 303 Leadership and Community Service                                                  |
# |School - IS 318 Eugenio Maria De Hostos                                                           |
# |School - IS 318 Math, Science, and Technology Through Arts                                        |
# |School - IS 339                                                                                   |
# |School - IS 34 Tottenville                                                                        |
# |School - IS 340                                                                                   |
# |School - IS 347 School of Humanities                                                              |
# |School - IS 349 Math, Science, and Technology                                                     |
# |School - IS 364 Gateway                                                                           |
# |School - IS 381                                                                                   |
# |School - IS 61 Leonardo Da Vinci                                                                  |
# |School - IS 61 William A Morris                                                                   |
# |School - IS 68 Isaac Bildersee                                                                    |
# |School - IS 7 Elias Bernstein                                                                     |
# |School - IS 72 Rocco Laurie                                                                       |
# |School - IS 73 The Frank Sansivieri Intermediate School                                           |
# |School - IS 75 Frank D Paulo                                                                      |
# |School - IS 77                                                                                    |
# |School - IS 93 Ridgewood                                                                          |
# |School - IS 96 Seth Low                                                                           |
# |School - IS 98 Bay Academy                                                                        |
# |School - Icahn Charter School 2                                                                   |
# |School - In-Tech Academy (MS-HS 368)                                                              |
# |School - Independence High School                                                                 |
# |School - Information Technology High School                                                       |
# |School - Institute for Collaborative Education                                                    |
# |School - International High School at LaGuardia Community College                                 |
# |School - International High School at Prospect Heights                                            |
# |School - International Leadership Charter High School                                             |
# |School - International Leadership Charter School                                                  |
# |School - International School for Liberal Arts                                                    |
# |School - Inwood Academy for Leadership Charter School                                             |
# |School - Irwin Altman MS 172                                                                      |
# |School - Isaac Newton Middle School for Math and Science                                          |
# |School - It Takes a Village Academy                                                               |
# |School - JHS 104 Simon Baruch                                                                     |
# |School - JHS 118 William W Niles                                                                  |
# |School - JHS 123 James M Kieran                                                                   |
# |School - JHS 125 Henry Hudson                                                                     |
# |School - JHS 127 The Castle Hill                                                                  |
# |School - JHS 13 Jackie Robinson                                                                   |
# |School - JHS 143 Eleanor Roosevelt                                                                |
# |School - JHS 145 Arturo Toscaninni                                                                |
# |School - JHS 158 Marie Curie                                                                      |
# |School - JHS 162 Lola Rodriguez De Tio                                                            |
# |School - JHS 167 Robert F Wagner                                                                  |
# |School - JHS 185 Edward Bleeker                                                                   |
# |School - JHS 189 Daniel Carter Beard                                                              |
# |School - JHS 190 Russell Sage                                                                     |
# |School - JHS 194 William Carr                                                                     |
# |School - JHS 201 The Dyker Heights                                                                |
# |School - JHS 202 Robert H Goddard                                                                 |
# |School - JHS 210 Elizabeth Blackwell                                                              |
# |School - JHS 216 George J Ryan                                                                    |
# |School - JHS 217 Robert A Van Wyck                                                                |
# |School - JHS 218 James P Sinnott                                                                  |
# |School - JHS 22 Jordan L Mott                                                                     |
# |School - JHS 220 John J Pershing                                                                  |
# |School - JHS 226 Virgil I Grissom                                                                 |
# |School - JHS 227 Edward B Shallow                                                                 |
# |School - JHS 234 Arthur W Cunningham                                                              |
# |School - JHS 259 William Mckinley                                                                 |
# |School - JHS 278 Marine Park                                                                      |
# |School - JHS 292 Margaret S Douglas                                                               |
# |School - JHS 318 Eugenio Maria De Hostos                                                          |
# |School - JHS 383 Philippa Schuyler                                                                |
# |School - JHS 54 Booker T Washington                                                               |
# |School - JHS 62 Ditmas                                                                            |
# |School - JHS 67 Louis Pasteur                                                                     |
# |School - JHS 72 Catherine and Count Basie                                                         |
# |School - JHS 74 Nathaniel Hawthorne                                                               |
# |School - JHS 78 Roy H Mann                                                                        |
# |School - JHS 8 Richard S Grossley                                                                 |
# |School - JHS 80 The Mosholu Parkway                                                               |
# |School - JHS 88 Peter Rouget                                                                      |
# |School - JHS 98 Herman Ridder                                                                     |
# |School - Jacqueline Kennedy Onassis High School                                                   |
# |School - Jamaica High School                                                                      |
# |School - James Madison High School                                                                |
# |School - James Weldon Johnson                                                                     |
# |School - Jane Addams High School for Academic Careers                                             |
# |School - Jean Nuzzi Intermediate School                                                           |
# |School - John Adams High School                                                                   |
# |School - John Bowne High School                                                                   |
# |School - John Dewey High School                                                                   |
# |School - John Ericsson Middle School 126                                                          |
# |School - John F Kennedy High School                                                               |
# |School - Juan Morel Campos Secondary School                                                       |
# |School - KAPPA IV                                                                                 |
# |School - KIPP AMP Charter School                                                                  |
# |School - KIPP Infinity Charter School                                                             |
# |School - KIPP STAR College Prep Charter School                                                    |
# |School - Kappa                                                                                    |
# |School - Kingsborough Early College School                                                        |
# |School - Kingsbridge International High School                                                    |
# |School - Kipp STAR College Preparatory                                                            |
# |School - Knowledge and Power Preparatory Academy International High School (Kappa)                |
# |School - Kurt Hahn Expeditionary Learning School                                                  |
# |School - Landmark High School                                                                     |
# |School - Leaders of Tomorrow                                                                      |
# |School - Leadership Prep Bedford Stuyvesant Uncommon Prep Charter School                          |
# |School - Leadership Preparatory Ocean Hill Charter School                                         |
# |School - Learners and Leaders                                                                     |
# |School - Legacy School                                                                            |
# |School - Legacy School for Integrated Studies                                                     |
# |School - Leon M Goldstein High School for the Sciences                                            |
# |School - Life Academy High School for Film and Music                                              |
# |School - Life Sciences Secondary School                                                           |
# |School - Lighthouse Elementary School                                                             |
# |School - Linden Tree Elementary School                                                            |
# |School - Long Island City High School                                                             |
# ...
# |School - Queens Collegiate: A College Board School                                                |
# |School - Queens High School for Information, Research, and Technology                             |
# |School - Queens High School of Teaching, Liberal Arts, and the Sciences                           |
# |School - Queens Metropolitan High School                                                          |
# |School - Queens Preparatory Academy                                                               |
# |School - Ralph A Fabrizio School                                                                  |
# |School - Red Hook Neighborhood School                                                             |
# |School - Repertory Company High School for Theatre Arts                                           |
# |School - Richard R Green High School of Teaching                                                  |
# |School - Richmond Hill High School                                                                |
# |School - Robert E Peary School                                                                    |
# |School - Robert F Wagner Jr Secondary School for Arts and Technology                              |
# |School - Ross Global Academy Charter School                                                       |
# |School - STEM Institute of Manhattan                                                              |
# |School - Satellite Three                                                                          |
# |School - Scholars Academy                                                                         |
# |School - Scholars' Academy                                                                        |
# |School - School for Environmental Citizenship                                                     |
# |School - School for Excellence                                                                    |
# |School - School for Global Leaders                                                                |
# |School - School for Tourism and Hospitality                                                       |
# |School - School of Math, Science, and Healthy Living                                              |
# |School - School of Performing Arts                                                                |
# |School - School of Science and Technology                                                         |
# |School - Science Skills Center High School for Science, Technology, and the Creative Arts         |
# |School - Secondary School for Journalism                                                          |
# |School - Sheepshead Bay High School                                                               |
# |School - Sheridan Academy for Young Leaders                                                       |
# |School - Soundview Academy for Culture and Scholarship                                            |
# |School - South Bronx Academy for Applied Media                                                    |
# |School - South Bronx Charter School for International Cultures and the Arts                       |
# |School - South Bronx Preparatory: A College Board School                                          |
# |School - South Richmond High School IS-PS 25                                                      |
# |School - South Shore Educational Complex YABC                                                     |
# |School - Space Shuttle Columbia School                                                            |
# |School - Spring Creek Community School                                                            |
# |School - Spruce Street School                                                                     |
# |School - Staten Island School of Civic Leadership                                                 |
# |School - Staten Island Technical High School                                                      |
# |School - Stephen T Mather Building Arts and Craftsmanship High School                             |
# |School - Stevenson YABC                                                                           |
# |School - Stuyvesant High School                                                                   |
# |School - Success Academy Union Square Manhattan 1                                                 |
# |School - Sunset Park High School                                                                  |
# |School - Susan E Wagner High School                                                               |
# |School - Suspension Center School - Sankofa Academy Middle School                                 |
# |School - Tag Young Scholars                                                                       |
# |School - Talent Unlimited High School                                                             |
# |School - Teachers College Community School                                                        |
# |School - Teachers Preparatory High School                                                         |
# |School - The 47 American Sign Language and English Lower School                                   |
# |School - The Academy for Excellence through the Arts                                              |
# |School - The Academy of Talented Scholars                                                         |
# |School - The Academy of Urban Planning and Engineering                                            |
# |School - The Angelo Patri Middle School                                                           |
# |School - The Barbara Esselborn School                                                             |
# |School - The Bellaire School                                                                      |
# |School - The Bilingual Bicultural School                                                          |
# |School - The Boerum Hill School for International Studies                                         |
# |School - The Bronx High School of Science                                                         |
# |School - The Bronx Mathematics Preparatory School                                                 |
# |School - The Bronxwood Preparatory Academy                                                        |
# |School - The Brooklyn Latin School                                                                |
# |School - The Brooklyn School for Social Justice                                                   |
# |School - The Celia Cruz Bronx High School of Music                                                |
# |School - The Cinema School                                                                        |
# |School - The East Village Community School                                                        |
# |School - The Emerson School                                                                       |
# |School - The Facing History School                                                                |
# |School - The Felisa Rincon de Gautier Institute for Law and Public Policy                         |
# |School - The Fresh Creek School                                                                   |
# |School - The Gordon Parks School                                                                  |
# |School - The Gregory Jocko Jackson School of Sports, Art, and Technology                          |
# |School - The Heritage School                                                                      |
# |School - The High School of Fashion Industries                                                    |
# |School - The James J Ambrose School                                                               |
# |School - The Jermaine L Green STEM Institute of Queens                                            |
# |School - The Laboratory School of Finance and Technology: X223                                    |
# |School - The Lexington Academy                                                                    |
# |School - The Longwood Academy of Discovery                                                        |
# |School - The Marie Curie School for Medicine, Nursing, and Health Professions                     |
# |School - The Math and Science Exploratory School                                                  |
# |School - The Metropolitan High School                                                             |
# |School - The Michael J Petrides School                                                            |
# |School - The Mott Hall School                                                                     |
# |School - The New School for Leadership and Journalism                                             |
# |School - The Peck Slip School                                                                     |
# |School - The Queens School of Inquiry                                                             |
# |School - The Richard H Hungerford School                                                          |
# |School - The River School                                                                         |
# |School - The Riverside School for Makers and Artists                                              |
# |School - The SEEALL Academy                                                                       |
# |School - The STAR Academy PS63                                                                    |
# |School - The Science and Medicine Middle School                                                   |
# |School - The Stephanie A Vierno School                                                            |
# |School - The Urban Assembly Academy for Future Leaders                                            |
# |School - The Urban Assembly Academy for History and Citizenship for Young Men                     |
# |School - The Urban Assembly Academy of Government and Law                                         |
# |School - The Urban Assembly Gateway School for Technology                                         |
# |School - The Urban Assembly Institute for New Technologies                                        |
# |School - The Urban Assembly Institute of Math and Science for Young Women                         |
# |School - The Urban Assembly Maker Academy                                                         |
# |School - The Urban Assembly School for Global Commerce                                            |
# |School - The Urban Assembly School for Law and Justice                                            |
# |School - The Urban Assembly School for the Performing Arts                                        |
# |School - The Urban Assembly School of Business for Young Women                                    |
# |School - The Williamsburg High School of Art and Technology                                       |
# |School - The Young Scholars Academy of the Bronx                                                  |
# |School - Theatre Arts Production Company School                                                   |
# |School - Theodore Roosevelt Evening High School - Mondays and Wednesdays                          |
# |School - Thomas C Giordano Middle School 45                                                       |
# |School - Thomas Jefferson YABC                                                                    |
# |School - Thurgood Marshall Academy Lower School                                                   |
# |School - Thurgood Marshall Academy for Learning and Social Change                                 |
# |School - Tito Puente Education Complex                                                            |
# |School - Tompkins Square Middle School                                                            |
# |School - Tottenville High School                                                                  |
# |School - Transit Tech Career and Technical Education High School                                  |
# |School - Union Square Academy for Health Sciences                                                 |
# |School - Unity Center for Urban Technologies                                                      |
# |School - University Heights Secondary School                                                      |
# |School - University Neighborhood High School                                                      |
# |School - Upper School at PS 25                                                                    |
# |School - Urban Institute of Mathematics                                                           |
# |School - Van Siclen Community Middle School                                                       |
# |School - Veritas Academy                                                                          |
# |School - Vista Academy                                                                            |
# |School - W H Maxwell Career and Technical Education High School                                   |
# |School - WEB Dubois Academic High School                                                          |
# |School - Wadleigh Secondary School for the Performing and Visual Arts                             |
# |School - Washington Heights Academy                                                               |
# |School - Washington Heights Expeditionary Learning School                                         |
# |School - Washington Irving High School                                                            |
# |School - Waterside Children's Studio School                                                       |
# |School - Waterside Childrens Studio School                                                        |
# |School - Wave Preparatory Elementary School                                                       |
# |School - William Cullen Bryant High School                                                        |
# |School - William E Grady Career and Technical Education High School                               |
# |School - Williamsburg Charter High School                                                         |
# |School - Williamsburg High School for Architecture and Design                                     |
# |School - Women's Academy of Excellence                                                            |
# |School - Yorkville Community School                                                               |
# |School - Young Leaders Elementary School                                                          |
# |School - Young Scholars' Academy for Discovery and Exploration                                    |
# |School - Young Voices Academy of the Bronx                                                        |
# |School - Young Women's Leadership School                                                          |
# |School - Young Women's Leadership School of Astoria                                               |
# |School - Young Women's Leadership School of Queens                                                |
# |School - Young Women's Leadership School of the Bronx                                             |
# |Senior Citizen Rent Increase Exemption Unit                                                       |
# |TAT                                                                                               |
# |TAX                                                                                               |
# |TLC                                                                                               |
# |Tax Lien Unit                                                                                     |
# |Taxi and Limousine Commission                                                                     |
# |Traffic Management Center                                                                         |
# |Valuation Policy                                                                                  |
# +--------------------------------------------------------------------------------------------------+

# %%
# All distinct Agency Name present in the dataset
temp_df3 = df.select("Agency Name").distinct() 
list_of_agency_names = list(temp_df3.toPandas()['Agency Name']) 

# All Agency present in the NYC Agency Names dataset
list_of_correct_agency_names=  list(agency_df.select("Agency").distinct().toPandas()['Agency'])

# %%
# Show list of non uniform names in the Agency Name Column
list_of_wrong_agency_names = []

for i in list_of_agency_names:
  if (i[0:6] != "School") and i not in list_of_correct_agency_names:
    list_of_wrong_agency_names.append(i)

# Show entire list
for j in list_of_wrong_agency_names:
  print(j)
# Out:
# Exemption Unit
# Manhattan 02
# Early Care and Education Information Unit
# NYCEM Property Damage
# Brooklyn South 10
# BCC - Brooklyn North
# Alternative Superintendency
# A - Manhattan
# ACS
# DOT
# Taxi and Limousine Commission
# DCA
# HPD
# DPR
# Property Exec Office
# Division of Alternative Management
# Child Care and Camps Complaint Unit
# TLC
# NYC Emergency Management
# External Affairs Unit
# BCC - Queens West
# Valuation Policy
# Correspondence - Taxi and Limousine Commission
# Department of Housing Preservation and Development
# Queens East 10
# Commercial Exemption Unit
# Queens West 03
# DCP
# Discrepancy and Billing
# DOF
# Queens West 06
# LinkNYC Unit
# Department of Homeless Services
# 3-1-1
# DHS Advantage Programs
# Operations Unit - Department of Homeless Services
# NYPD
# TAX
# DOB Inspections - Queens
# DOF Legal Affairs - Taxpayer Services Unit
# MOC
# DVS
# Fire Department of New York
# 3-1-1 Call Center
# Investigation Review Section
# DOB
# BCC - Staten Island
# Queens East 12
# Office of the Sheriff
# Tax Lien Unit
# COIB
# Manhattan 07
# CFC - Bronx
# P - Queens
# DFTA
# 311 Administrative Supervisor
# Land Records
# Adjudication - Appeals Unit
# DoITT
# Queens West 04
# A - Queens
# Bronx 03
# Payment Operations
# A - Brooklyn
# DOB Inspections - Manhattan
# CEO
# Municipal Archives
# RPIE Unit
# CFC - Staten Island
# A - Staten Island
# Manhattan 06
# Accounts Examination
# Bronx 08
# BCC - Queens East
# HealthCare Connections
# DOB Inspections - Brooklyn
# A - Illegal Posting Manhattan and Bronx
# Department of Health and Mental Hygiene
# Department of Information Technology and Telecommunications
# Bronx 04
# Revenue Accounting
# Manhattan 04
# Refunds and Adjustments
# BCC - Manhattan
# Lot Cleaning
# P - Brooklyn and Staten Island
# Bronx 11
# Condo or CoOp Unit
# Exemption Policy Unit
# Dunning Unit
# Mayorâs Office of Special Enforcement
# Queens West 02
# Manhattan 08
# A - Illegal Posting Staten Island, Queens and Brooklyn
# Central - Department of Education
# BCC - Bronx
# Bronx 05
# DOB Inspections - Bronx
# Personal Exemption Unit
# DOHMH
# Manhattan 03
# New York City Police Department
# Manhattan 05
# DOB Inspections - Staten Island
# Disability Rent Increase Exemption Unit
# DCAS
# Mosquito Control
# DRIE Unit
# Bronx 10
# Office of the Taxpayer Advocate
# A - Canine Task Force Citywide
# P - Manhattan and Bronx
# Senior Citizen Rent Increase Exemption Unit
# Correspondence Unit
# Traffic Management Center
# Department of Parks and Recreation
# A - Bronx
# BCC - Brooklyn South
# Manhattan 01
# TAT
# Brooklyn North 03
# Adjudication - Hearing by Mail
# HRA Benefit Card Replacement
# P - Commercial Recycling Citywide

# %%
# Count how many rows have "School" as part of the value in the Agency Name column
df.filter((df["Agency Name"][0:6] == "School")).count()
# Out:
# 3144

# %%
# Count how many rows have "School" as part of the value in Agency Name and "DOE" in Agency column
df.filter((df["Agency Name"][0:6] == "School") & (df["Agency"] == "DOE")).count()
# Out:
# 3144

# %% [markdown]
# As we can observe from the results above, there are several inconsistencies and other problems, including misspellings, uneven uppercase/lowercase usage, different titles (ex: "The Department of..." vs "Department of..."), and acronyms are being used despite there being an actual name to the department (ex: NYPD vs using New York Police Department). There are also many schools that are listed that are not technically agencies due to the DOE. However, for this specific case, if a school is listed with DOE for the Agency in the same row, we will leave this alone as we know this is most likely correct because we can observe that the number of agency names that are schools is equivalent to the number of values that have agency name that is a school and agency that is DOE. This school data is too detailed and can potentially be used for other purposes, so we decided that it should not be taken out of the dataset.

# %% [markdown]
# ## IV. Completeness
#
# We describe a complete dataset as a dataset that contains all required data. While exploring our dataset, we found that several values in the city column are null (i.e. missing).
#
# Run the following cells to view the observation.

# %% [markdown]
# ### Explore City column

# %%
from pyspark.sql.functions import desc

# Display number of values in city column
df.groupBy('City').count().orderBy(desc("count")).show(df.count(), False)
# Out:
# +-------------------------+-------+
# |City                     |count  |
# +-------------------------+-------+
# |BROOKLYN                 |1592913|
# |NEW YORK                 |1024723|
# |BRONX                    |990824 |
# |null                     |337731 |
# |STATEN ISLAND            |262032 |
# |JAMAICA                  |75304  |
# |FLUSHING                 |56319  |
# |Jamaica                  |54074  |
# |ASTORIA                  |52854  |
# |RIDGEWOOD                |41676  |
# |Flushing                 |37942  |
# |Astoria                  |32108  |
# |CORONA                   |28253  |
# |Ridgewood                |25369  |
# |WOODSIDE                 |25196  |
# |FRESH MEADOWS            |25104  |
# |OZONE PARK               |23299  |
# |ELMHURST                 |22163  |
# |EAST ELMHURST            |21381  |
# |LONG ISLAND CITY         |20901  |
# |SOUTH RICHMOND HILL      |20650  |
# |FAR ROCKAWAY             |20220  |
# |FOREST HILLS             |19267  |
# |QUEENS VILLAGE           |19098  |
# |SOUTH OZONE PARK         |18785  |
# |Far Rockaway             |18725  |
# |JACKSON HEIGHTS          |17872  |
# |WOODHAVEN                |17280  |
# |MASPETH                  |17113  |
# |Woodside                 |15947  |
# |Elmhurst                 |15936  |
# |Corona                   |15448  |
# |RICHMOND HILL            |14551  |
# |Ozone Park               |14098  |
# |Queens Village           |13973  |
# |MIDDLE VILLAGE           |13777  |
# |BAYSIDE                  |13361  |
# |REGO PARK                |13118  |
# |WHITESTONE               |12970  |
# |South Richmond Hill      |12711  |
# |Long Island City         |12695  |
# |Forest Hills             |12266  |
# |South Ozone Park         |11581  |
# |Fresh Meadows            |11478  |
# |SPRINGFIELD GARDENS      |11273  |
# |Jackson Heights          |10944  |
# |COLLEGE POINT            |10552  |
# |SAINT ALBANS             |10546  |
# |East Elmhurst            |10307  |
# |Springfield Gardens      |9615   |
# |HOLLIS                   |9605   |
# |Saint Albans             |9183   |
# |Maspeth                  |8981   |
# |HOWARD BEACH             |8894   |
# |Richmond Hill            |8828   |
# |Bayside                  |8827   |
# |LITTLE NECK              |8409   |
# |SUNNYSIDE                |8376   |
# |Woodhaven                |8163   |
# |OAKLAND GARDENS          |8147   |
# |ROSEDALE                 |7997   |
# |Whitestone               |7824   |
# |Rego Park                |7677   |
# |Middle Village           |7330   |
# |Hollis                   |7095   |
# |Howard Beach             |7034   |
# |KEW GARDENS              |6782   |
# |Rosedale                 |6317   |
# |Rockaway Park            |6108   |
# |Oakland Gardens          |6072   |
# |Sunnyside                |5979   |
# |BELLEROSE                |5657   |
# |ROCKAWAY PARK            |5558   |
# |College Point            |5516   |
# |CAMBRIA HEIGHTS          |5468   |
# |Little Neck              |5346   |
# |Arverne                  |4783   |
# |Kew Gardens              |4667   |
# |ARVERNE                  |4565   |
# |Cambria Heights          |4442   |
# |GLEN OAKS                |3439   |
# |Bellerose                |3046   |
# |QUEENS                   |2145   |
# |Glen Oaks                |2101   |
# |FLORAL PARK              |1454   |
# |MANHATTAN                |1011   |
# |NEW HYDE PARK            |989    |
# |Floral Park              |707    |
# |Breezy Point             |549    |
# |New Hyde Park            |399    |
# |BREEZY POINT             |339    |
# |NEWARK                   |251    |
# |N/A                      |160    |
# |CENTRAL PARK             |84     |
# |JERSEY CITY              |72     |
# |YONKERS                  |51     |
# |NA                       |48     |
# |VALLEY STREAM            |45     |
# |NY                       |31     |
# |GREAT NECK               |28     |
# |HOBOKEN                  |27     |
# |LONG ISLAND              |24     |
# |HICKSVILLE               |23     |
# |FARMINGDALE              |23     |
# |NEW ROCHELLE             |21     |
# |MELVILLE                 |21     |
# |WESTBURY                 |20     |
# |BUFFALO                  |19     |
# |WHITE PLAINS             |18     |
# |GARDEN CITY              |17     |
# |ELMONT                   |17     |
# |WOODBURY                 |17     |
# |HOUSTON                  |16     |
# |UNIONDALE                |16     |
# |MOUNT VERNON             |15     |
# |FREEPORT                 |14     |
# |COLUMBUS                 |14     |
# |JACKSONVILLE             |13     |
# |LONG BEACH               |13     |
# |COMMACK                  |12     |
# |NEW JERSEY               |12     |
# |UNKNOWN                  |12     |
# |ATLANTA                  |11     |
# |BLOOMINGTON              |11     |
# |ELMSFORD                 |10     |
# |FORT LEE                 |10     |
# |BELLMORE                 |10     |
# |SCARSDALE                |9      |
# |UNION CITY               |9      |
# |PLAINVIEW                |9      |
# |EDGEWATER                |9      |
# |GREENWICH                |9      |
# |PARSIPPANY               |9      |
# |HARRISBURG               |9      |
# |ISLANDIA                 |9      |
# |ORLANDO                  |9      |
# |WOODMERE                 |8      |
# |NORWELL                  |8      |
# |LYNBROOK                 |8      |
# |Brooklyn                 |7      |
# |WILMINGTON               |7      |
# |LAKE SUCCESS             |7      |
# |LAGUARDIA AIRPORT        |7      |
# |WEEHAWKEN                |7      |
# |MINEOLA                  |7      |
# |EAST RUTHERFORD          |7      |
# |NYC                      |7      |
# |SYOSSET                  |7      |
# |WEST BABYLON             |7      |
# |SAN DIEGO                |7      |
# |ROCKVILLE CENTRE         |7      |
# |MINNEAPOLIS              |6      |
# |WHITEPLAINS              |6      |
# |MANHASSET                |6      |
# |FRANKLIN SQUARE          |6      |
# |RONKONKOMA               |6      |
# |HORSHAM                  |6      |
# |HUNTINGTON               |6      |
# |LAWRENCE                 |6      |
# |BALDWIN                  |6      |
# |NORWALK                  |6      |
# |NORFOLK                  |6      |
# |Manhattan                |6      |
# |Queens                   |6      |
# |GLEN COVE                |6      |
# |LEVITTOWN                |6      |
# |STAMFORD                 |6      |
# |PLEASANTON               |5      |
# |WESTCHESTER              |5      |
# |DALLAS                   |5      |
# |BIRMINGHAM               |5      |
# |WEST NEW YORK            |5      |
# |CEDARHURST               |5      |
# |LOS ANGELES              |5      |
# |HEMPSTEAD                |5      |
# |WEST HEMPSTEAD           |5      |
# |NORTH BELLMORE           |5      |
# |PORT WASHINGTON          |5      |
# |ENGLEWOOD                |5      |
# |Bronx                    |5      |
# |MIAMI                    |5      |
# |CARLE PLACE              |5      |
# |EDISON                   |5      |
# |GREENVILLE               |5      |
# |TEANECK                  |5      |
# |LOWELL                   |5      |
# |NASSAU COUNTY            |5      |
# |OCEANSIDE                |4      |
# |FAIR LAWN                |4      |
# |EAST MEADOW              |4      |
# |ROCHESTER                |4      |
# |MORRISTOWN               |4      |
# |RICHARDSON               |4      |
# |BETHPAGE                 |4      |
# |SECAUCUS                 |4      |
# |CLIFFSIDE PARK           |4      |
# |PATCHOGUE                |4      |
# |WANTAGH                  |4      |
# |NASSAU                   |4      |
# |TARRYTOWN                |4      |
# |CHICAGO                  |4      |
# |ENGLEWOOD CLIFFS         |4      |
# |HAUPPAUGE                |4      |
# |PELHAM                   |4      |
# |LINDENHURST              |4      |
# |PALISADES PARK           |4      |
# |NEW YORK CITY            |4      |
# |NORTH BERGEN             |4      |
# |BOSTON                   |4      |
# |RIVERSIDE                |4      |
# |ALBANY                   |4      |
# |PRINCETON                |4      |
# |BAYONNE                  |4      |
# |TOLEDO                   |3      |
# |BX                       |3      |
# |PHOENIX                  |3      |
# |CENTRAL ISLIP            |3      |
# |TREVOSE                  |3      |
# |NASHVILLE                |3      |
# |LYNDHURST                |3      |
# |SECACUS                  |3      |
# |EDINA                    |3      |
# |SOLON                    |3      |
# |NEWBURGH                 |3      |
# |ROCKVILLE CENTER         |3      |
# |BROOKSVILLE              |3      |
# |NEWARK AIRPORT           |3      |
# |BALTIMORE                |3      |
# |CARROLLTON               |3      |
# |BRONXVILLE               |3      |
# |MARIETTA                 |3      |
# |ELIZABETH                |3      |
# |WILLIAMSVILLE            |3      |
# |ROSLYN                   |3      |
# |WARWICK                  |3      |
# |FORT WASHINGTON          |3      |
# |ALBERTSON                |3      |
# |BABYLON                  |3      |
# |MILLBURN                 |3      |
# |ISLAND PARK              |3      |
# |NEWTON                   |3      |
# |SOUTH AMBOY              |3      |
# |EAST ROCKAWAY            |3      |
# |HIGHLAND PARK            |3      |
# |TAMPA                    |3      |
# |HEMSTEAD                 |3      |
# |QUEEN                    |3      |
# |MASSAPEQUA               |3      |
# |SIOUX FALLS              |3      |
# |HACKENSACK               |3      |
# |HAWTHORNE                |3      |
# |HARRISON                 |3      |
# |MIDDLETOWN               |3      |
# |RIDGEFIELD PARK          |3      |
# |DEER PARK                |3      |
# |RIDGEFIELD               |3      |
# |COPIAGUE                 |3      |
# |NJ                       |3      |
# |DENVER                   |3      |
# |0                        |3      |
# |ARDSLEY                  |3      |
# |JERICHO                  |3      |
# |REDBANK                  |2      |
# |SAIRPORT                 |2      |
# |HUDSON COUNTY            |2      |
# |COLLEYVILLE              |2      |
# |SPRING VALLEY            |2      |
# |HUNTINGTON STATION       |2      |
# |INWOOD                   |2      |
# |NEW BRUNSWICK            |2      |
# |SLEEPY HOLLOW            |2      |
# |NYACK                    |2      |
# |BELTSZILLE               |2      |
# |MALVERNE                 |2      |
# |PORT CHESTER             |2      |
# |GREENWOOD VILLAGE        |2      |
# |LINDEN                   |2      |
# |VALHALLA                 |2      |
# |VALLEY VIEW              |2      |
# |BAYSHORE                 |2      |
# |CLOSTER                  |2      |
# |OLD BRIDGE               |2      |
# |ROANOKE                  |2      |
# |HOLBROOK                 |2      |
# |ARCADE                   |2      |
# |KATONAH                  |2      |
# |CHESTNUT RIDGE           |2      |
# |IRVINGTON                |2      |
# |BROOKYLN                 |2      |
# |SEAFORD                  |2      |
# |OKLAHOMA CITY            |2      |
# |ISLANDER                 |2      |
# |PORT JEFFERSON           |2      |
# |OAKS                     |2      |
# |JERSEY                   |2      |
# |BAY SHORE                |2      |
# |NORTHPORT                |2      |
# |ROSELLE                  |2      |
# |THOROFARE                |2      |
# |TRENTON                  |2      |
# |WOODSTOCK                |2      |
# |PEEKSKILL                |2      |
# |MASON                    |2      |
# |WARREN                   |2      |
# |WIXOM                    |2      |
# |SPARKS                   |2      |
# |AUSTIN                   |2      |
# |EL PASO                  |2      |
# |CITY OF INDUSTRY         |2      |
# |MONTCLAIR                |2      |
# |PITTSBURGH               |2      |
# |MAPLEWOOD                |2      |
# |MERRICK                  |2      |
# |GREATNECK                |2      |
# |WEST PALM BEACH          |2      |
# |STONY POINT              |2      |
# |NORTH BABYLON            |2      |
# |GLEN ALLEN               |2      |
# |PARAMUS                  |2      |
# |LYNWOOD                  |2      |
# |RENTON                   |2      |
# |WEST ISLIP               |2      |
# |WOODCLIFF LAKE           |2      |
# |MIDLOTHIAN               |2      |
# |MEDFORD                  |2      |
# |NANUET                   |2      |
# |MAHWAH                   |2      |
# |BOCA RATON               |2      |
# |ST PAUL                  |2      |
# |VINELAND                 |2      |
# |BROOKLN                  |2      |
# |CHERRY HILL              |2      |
# |SYRACUSE                 |2      |
# |LAS VEGAS                |2      |
# |CLIFTON                  |2      |
# |AMITYVILLE               |2      |
# |000                      |2      |
# |PATTERSON                |2      |
# |SCHOMBURG                |2      |
# |JACKSON                  |2      |
# |ISELIN                   |2      |
# |SAINT PAUL               |2      |
# |PHILADELPHIA             |2      |
# |MANATTAN                 |2      |
# |DEERFIELD BEACH          |2      |
# |OVERLAND PARK            |2      |
# |HORSEHAM                 |2      |
# |PLANO                    |2      |
# |HUSTON                   |1      |
# |NESCONSET                |1      |
# |BROOKILYN                |1      |
# |STATEN ISAND             |1      |
# |WATERTOWN                |1      |
# |WOBURN                   |1      |
# |COUBERSTORT              |1      |
# |WESTPORT                 |1      |
# |SLYVANIA                 |1      |
# |AMYTVILLE                |1      |
# |RARITAN                  |1      |
# |FOREST HILL              |1      |
# |NORWOOD                  |1      |
# |LONDON                   |1      |
# |MENDOTA  HEIGHTS         |1      |
# |EAST OWALL               |1      |
# |GLENCOVE                 |1      |
# |WEST HEMPTSTEAD          |1      |
# |COPIAUE                  |1      |
# |CRANFORD                 |1      |
# |SOUND BEACH              |1      |
# |SOUTH FLORAL PARK        |1      |
# |STE                      |1      |
# |KEARNY                   |1      |
# |HARISHAW                 |1      |
# |ELMFORD                  |1      |
# |PERRIS                   |1      |
# |DES PLAINES              |1      |
# |SUFFIX                   |1      |
# |BELLEVILLE               |1      |
# |CLARA BARTON             |1      |
# |MCALLEN                  |1      |
# |TWINS BURG               |1      |
# |LANCASTER                |1      |
# |LEONIA                   |1      |
# |STATEN                   |1      |
# |NORTH SALEM              |1      |
# |SENTEREACH               |1      |
# |BONX                     |1      |
# |SAN ANTOINIO             |1      |
# |SCARDALES                |1      |
# |GREENWITCH               |1      |
# |EAST AMHERST             |1      |
# |ISLAND                   |1      |
# |DEAR PARK                |1      |
# |NEWHYDE PARK             |1      |
# |CHEEKTOWAGA              |1      |
# |ST. PETERSBURG           |1      |
# |STATEB ISLAND            |1      |
# |MORGAN HILL              |1      |
# |NEWARK NJ                |1      |
# |BERGEN COUNTY            |1      |
# |MILIPTAS                 |1      |
# |PARKRIDGE                |1      |
# |WESTLAKE                 |1      |
# |RAYNHAM                  |1      |
# |SKANEATELESS FALLS       |1      |
# |WOODALE                  |1      |
# |CAROL PLACE              |1      |
# |BELLEVIEW                |1      |
# |HARLEM                   |1      |
# |ESDONDIDO                |1      |
# |NORTH BRUNSWICK          |1      |
# |GARWOOD                  |1      |
# |N?A                      |1      |
# |ABERDEEN                 |1      |
# |GREENICH                 |1      |
# |ANONYMOUS                |1      |
# |PARK RIDGE               |1      |
# |ENGLEWOOD CLIFF          |1      |
# |INDIANAPOLLIS            |1      |
# |GROVE CITY               |1      |
# |WIXON                    |1      |
# |NORTH PLAINFIELD         |1      |
# |SMITHTOWN                |1      |
# |BOHENIA                  |1      |
# |JERSY CITY               |1      |
# |QWYNN OAKS               |1      |
# |LOCAL                    |1      |
# |ELMIRA                   |1      |
# |BK                       |1      |
# |VALLEY SPRING            |1      |
# |FLORENCE                 |1      |
# |NEWBRUGH                 |1      |
# |ANDERSON                 |1      |
# |X                        |1      |
# |CARLSBAD                 |1      |
# |SELINA                   |1      |
# |CHINO                    |1      |
# |LIDO BEACH               |1      |
# |VALLY STREAM             |1      |
# |HEWLETT TOWN             |1      |
# |HUNGTINGTON              |1      |
# |JEARSEY CITY             |1      |
# |SAG HARBOR               |1      |
# |PHOROFARA                |1      |
# |RICHFIELD                |1      |
# |KATANAH                  |1      |
# |GIG HARBOR               |1      |
# |OKSPA                    |1      |
# |ROSELAND                 |1      |
# |WOODBERRY                |1      |
# |MOUNT LAUREL             |1      |
# |PORTLAND                 |1      |
# |OCEAN SIDE               |1      |
# |CITY OF INTERESION       |1      |
# |LEVITT TOWN              |1      |
# |POMONA                   |1      |
# |GOSHEN                   |1      |
# |MOUNT PLEASENT           |1      |
# |THORNWOOD                |1      |
# |NORTHFOLK                |1      |
# |BEAR                     |1      |
# |WEST DES MOINES          |1      |
# |FARMING DALE             |1      |
# |SPRINGDALE               |1      |
# |SOUTH PORT               |1      |
# |WOODLAND PARK            |1      |
# |LEVITTTOWN               |1      |
# |NORTH RIDGE              |1      |
# |E                        |1      |
# |PISCUTAWAY               |1      |
# |HEWLETT                  |1      |
# |LAKEWOOD                 |1      |
# |CHESTER HEIGHTS          |1      |
# |WYCKOFF                  |1      |
# |PEESKILL                 |1      |
# |QUENS                    |1      |
# |WEST LYNNWOOD            |1      |
# |JUPITER                  |1      |
# |SADDLE BROOK             |1      |
# |WILLIAMSPORT             |1      |
# |SANTA ANA                |1      |
# |PITSBURG                 |1      |
# |MIDDLEVILLAGE            |1      |
# |SUNSET                   |1      |
# |HASTINGS ON HUDSON       |1      |
# |MALT BONER               |1      |
# |WARRENVILLE              |1      |
# |WEST BABYLON AVE         |1      |
# |SANDERSVILLE             |1      |
# |BRIDGEPORT               |1      |
# |HILLSDALE                |1      |
# |GRAPE VINE               |1      |
# |LEHIGH VALLEY            |1      |
# |BREWSTER                 |1      |
# |NEW  YORK                |1      |
# |MANALABAN                |1      |
# |VOORHEES                 |1      |
# |P.O. BOX 1233            |1      |
# |ST.ALBANS                |1      |
# |UNK                      |1      |
# |HAMDEN                   |1      |
# |DUBLIN                   |1      |
# |N. CANTON                |1      |
# |NORTH HILLS              |1      |
# |HOLLYWOOD                |1      |
# |ENGELWOOD CLIFFS         |1      |
# |POUKEPSIE                |1      |
# |N.Y                      |1      |
# |OXFORD                   |1      |
# |HOLTVILLE                |1      |
# |YORKTOWN                 |1      |
# |REGAL PARK               |1      |
# |WAVERLY                  |1      |
# |WHYOMING                 |1      |
# |BALDWIN, NASSAU          |1      |
# |EVERETT                  |1      |
# |BELLROSE                 |1      |
# |SOUTH DAYTONA            |1      |
# |LINWOOD                  |1      |
# |TERRY TOWN               |1      |
# |MANALAPAN                |1      |
# |ELMHERST                 |1      |
# |BOLTIMORE                |1      |
# |SONOMA                   |1      |
# |SOMERVILLE               |1      |
# |SAVANNAH                 |1      |
# |SOUTH GATE               |1      |
# |SAN HOSE                 |1      |
# |TUXEDO PARK              |1      |
# |MASSEPEQUA               |1      |
# |ST JAMES                 |1      |
# |WALLINGTON               |1      |
# |GUTTEMBERG               |1      |
# |TAMPON SPRINGS           |1      |
# |NEW JERCY                |1      |
# |NORTH PLAIN FIELD        |1      |
# |ATLANTIC CITY            |1      |
# |EAST ATLANTIC BEACH      |1      |
# |NORTH  BERGEN            |1      |
# |OYSTER BAY               |1      |
# |DES MONES                |1      |
# |SCRANTON                 |1      |
# |GETZVILLE                |1      |
# |WEST MORELAND            |1      |
# |RASPBERRY                |1      |
# |BLOOMINGDALE             |1      |
# |DFD                      |1      |
# |WEST BERRY               |1      |
# |SANTA ROSA               |1      |
# |TARLIN                   |1      |
# |CIERO                    |1      |
# |PORT MONMOUTH            |1      |
# |ALLEN                    |1      |
# |HALLANDALE BEACH         |1      |
# |MANHATAN                 |1      |
# |BLOOMINTON               |1      |
# |VANCOUVER                |1      |
# |NEWYOK                   |1      |
# |MALVERN                  |1      |
# |LANGHORNE                |1      |
# |NBLOOMINGTON             |1      |
# |FARMINDELE               |1      |
# |OLD BETHPAGE             |1      |
# |STATEN  ISLAND           |1      |
# |HUNTIGTON STATION        |1      |
# |FORT JEFFERSON STATION   |1      |
# |SARASOTA                 |1      |
# |STEWART MANOR            |1      |
# |BRICK                    |1      |
# |CROTONA PARK             |1      |
# |KNOX VALLEY              |1      |
# |MILLSTONE                |1      |
# |ANTIOCH                  |1      |
# |ROCKDALE CENTER          |1      |
# |GREENLAWN                |1      |
# |SPRING                   |1      |
# |SOMERS                   |1      |
# |INDUSTRY                 |1      |
# |FLORIDA                  |1      |
# |POMPANO                  |1      |
# |RIVER FOREST             |1      |
# |OAK DALE                 |1      |
# |NEW JER                  |1      |
# |HOBKEN                   |1      |
# |VALLEY  STREAM           |1      |
# |MADISON                  |1      |
# |ROCKVILLA CENTER         |1      |
# |SHORT HILLS              |1      |
# |GREAT RIVER              |1      |
# |PHILIDELPHIA             |1      |
# |FRMNGDALE                |1      |
# |CHAPPAQUA                |1      |
# |CARRY TOWN               |1      |
# |SACREMENTO               |1      |
# |BLOOMFIELD               |1      |
# |PECK SLIP                |1      |
# |BAKERSFIELD              |1      |
# |FLUSH MEADOWS            |1      |
# |SUMMERSET                |1      |
# |FORT LAUDERDALE          |1      |
# |RONTER CENTER            |1      |
# |SACRAMENTO               |1      |
# |BRAINTREE                |1      |
# |CA                       |1      |
# |FARROCKWAY               |1      |
# |ELMSDORF                 |1      |
# |HUNTINGTION              |1      |
# |MONROE                   |1      |
# |BRADENTON                |1      |
# |FANWOOD                  |1      |
# |NEW WINDSOR              |1      |
# |WESCHESTER COUNTY        |1      |
# |WILLIAMSTOWN             |1      |
# |PETERBOROUGH             |1      |
# |ELMHUSRT                 |1      |
# |SINGAPORE                |1      |
# |WASHINGTON               |1      |
# |ROOSEVELT ISLAND         |1      |
# |HAYWARD                  |1      |
# |CORAL SPRINGS            |1      |
# |NEW                      |1      |
# |WEST NYACK               |1      |
# |RICH FIELD PARK          |1      |
# |SALEM                    |1      |
# |PLAINVIEUW (NEW YORK     |1      |
# |MELLVILLE                |1      |
# |GREELEY                  |1      |
# |NILES                    |1      |
# |FAMINDALE                |1      |
# |LINDBROOK                |1      |
# |FAIRLAWN                 |1      |
# |LONGWOOD                 |1      |
# |PORT ELIZABETH           |1      |
# |METAIRE                  |1      |
# |ATLANTIC BEACH           |1      |
# |FRANKLYN SQ              |1      |
# |GRAND JUNCTION           |1      |
# |GRAND RAPIDS             |1      |
# |WHTESTONE                |1      |
# |CORTLANDT MANOR          |1      |
# |OZONE  PARK              |1      |
# |CINCINNATI               |1      |
# |OORT WASHINGTON          |1      |
# |WAYLAND                  |1      |
# |MIDDLE VILLAGE,          |1      |
# |PEACHTREE CORNERS        |1      |
# |LAKEWOOD RANCH           |1      |
# |HOUSON                   |1      |
# |LONGBEACH                |1      |
# |CARLSTADT                |1      |
# |CHELSEA                  |1      |
# |SD                       |1      |
# |FRISCO                   |1      |
# |BROOKYN                  |1      |
# |ISLANDIA,                |1      |
# |CITY ISLAND              |1      |
# |NEWPORT BEACH            |1      |
# |VALLEY STREET            |1      |
# |NEW HYDE PRK             |1      |
# |EAST WINDSOR             |1      |
# |MIAMI BEACH              |1      |
# |ALPHARATTA               |1      |
# |SATEN ISLAND             |1      |
# |BRANDON                  |1      |
# |PORTHCHESTER             |1      |
# |WANTGAH                  |1      |
# |SOUTH EASTERN            |1      |
# |HUDSON                   |1      |
# |FORT WORTH               |1      |
# |NS                       |1      |
# |ST LOUIS                 |1      |
# |PARSITTANY               |1      |
# |CENTRAL STREAM MORICHES  |1      |
# |CASPER                   |1      |
# |ST. PAUL                 |1      |
# |VILLAPARK                |1      |
# |MORNINGSIDE STATION      |1      |
# |AROUND NEW HYDE PARK EXIT|1      |
# |DOBBS FERRY              |1      |
# |TRUMBULL                 |1      |
# |EDEN PRAIRIE             |1      |
# |OLANDO                   |1      |
# |NIAGARA FALLS            |1      |
# |WEHAWKEEN                |1      |
# |PORTLAND MANOR           |1      |
# |LIVERMORE                |1      |
# |DOYLES TOWN              |1      |
# |JACKSONSVILLE            |1      |
# |HOWELL                   |1      |
# |NEW PORT RICHY           |1      |
# |WOODBRIDGE               |1      |
# |UTICA                    |1      |
# |PEAKSKILL                |1      |
# |P.O. BOX 3615            |1      |
# |HUTCHINSON               |1      |
# |LAKEWORTH                |1      |
# |RENO                     |1      |
# |TETERBORO                |1      |
# |MENIFEE                  |1      |
# |MINESOTA                 |1      |
# |SCEAUCUS                 |1      |
# |TENAFLY                  |1      |
# |BROOKHAVEN               |1      |
# |FORT LAUDERALE           |1      |
# |NORFORK                  |1      |
# |PANAMA                   |1      |
# |TUIPEA BUFFALO GROVE     |1      |
# |RICHARDFIELD PARK        |1      |
# |DES MOINES               |1      |
# |BELLEOSE                 |1      |
# |THIELLS                  |1      |
# |WEEHAUKEN                |1      |
# |SOUTH ORANGE             |1      |
# |BOCAROPON                |1      |
# |NEWPORT                  |1      |
# |FARMDALE                 |1      |
# |PARSIPPINY               |1      |
# |ISELING                  |1      |
# |FARMINGVILLE             |1      |
# |BALDWIN HARBOUR          |1      |
# |LARCHMONT                |1      |
# |MINEAPOLIS               |1      |
# |CALDWELL                 |1      |
# |STANFORD                 |1      |
# |HEMPSTEAD BAY            |1      |
# |DELMORE                  |1      |
# |FLUSHNG                  |1      |
# |FARMNGDALE               |1      |
# |KENNESAW                 |1      |
# |DID NOT DISCLOSE         |1      |
# |WINSTON-SALEM            |1      |
# |LONG SLAND               |1      |
# |BATESBURGE               |1      |
# |INDIAN WELLS             |1      |
# |COSTA MESA               |1      |
# |WLLINGTON                |1      |
# |HASBROUCK                |1      |
# |SANDIEGO                 |1      |
# |PUTNAM VALLEY            |1      |
# |HAMILTON                 |1      |
# |HARRISBURGH              |1      |
# |SAINT ALBANY             |1      |
# |FRAKLIN SQUARE           |1      |
# |OLD BECHPAGE             |1      |
# |SADDLEBROOK              |1      |
# |MELVILL                  |1      |
# |ST. CHARLES              |1      |
# |OMAHA                    |1      |
# |ANTIONO                  |1      |
# |MT. VERNON               |1      |
# |NOREROSS                 |1      |
# |ROCKAWAY  BLVD           |1      |
# |UKNOWN                   |1      |
# |DIG HARBOR               |1      |
# |MAGNOLIA                 |1      |
# |PORCHESTER               |1      |
# |RAPID                    |1      |
# |RICHMOND NY              |1      |
# |BRONXSVILLE              |1      |
# |JERSEY AVE               |1      |
# |NEWYORK                  |1      |
# |FRANKILN SQUARE          |1      |
# |LOG BEACH                |1      |
# |FLUSING                  |1      |
# |ORCHARD PARK             |1      |
# |VALLEYSTEAM              |1      |
# |CASTLETON                |1      |
# |CLIFSIDE PARK            |1      |
# |AURORA                   |1      |
# |WATERLOO                 |1      |
# |FLORAL OARK              |1      |
# |BUFFOLA                  |1      |
# |PARLIN                   |1      |
# |TRAVIS                   |1      |
# |ANDOVER                  |1      |
# |SOMERSET                 |1      |
# |HAMMOND                  |1      |
# |FAIRPORT                 |1      |
# |NORTH BALDWIN            |1      |
# |RYBROOK                  |1      |
# |PHILDELPHIA              |1      |
# |LEVITS TOWN              |1      |
# |CHARLOTTE                |1      |
# |PORT JEFFERSON STATION   |1      |
# |BERGEN FIELD             |1      |
# |NOWELL                   |1      |
# |SOUTHGATE                |1      |
# |BROOKVILLE               |1      |
# |PARSITPANY               |1      |
# |VILLA PARK               |1      |
# |ST. LOUIS                |1      |
# |FAR ROCKAWY              |1      |
# |PERTH AMBOY              |1      |
# |PORT WASHINGTON,         |1      |
# |BRIELLE                  |1      |
# |JUANA DIAZ               |1      |
# |LOCKPORT                 |1      |
# |GETTSVILLE               |1      |
# |WILTON                   |1      |
# |HERIETTA                 |1      |
# |HIGHLND PARK             |1      |
# |SEACUCUS                 |1      |
# |EAST NORTHPORT           |1      |
# |EVANSTON                 |1      |
# |COVINA                   |1      |
# |MINNIAPOLIS              |1      |
# |SYOSET                   |1      |
# |CARLTON                  |1      |
# |IRVERING BLVD            |1      |
# |VALLEY STEAM             |1      |
# |EAST ELM HURST           |1      |
# |WEST ORANGE              |1      |
# |ALLENVILLE               |1      |
# |BROOKYN NY               |1      |
# |EASTON                   |1      |
# |BRENTWOOD                |1      |
# |HALBROOK                 |1      |
# |MEMPIS                   |1      |
# |CARLSPRINGS              |1      |
# |GUTTENBURG               |1      |
# |MAMARONECK               |1      |
# |WARRENTON                |1      |
# |EDWARD CLIFTON           |1      |
# |WAPPINGERS FALL          |1      |
# |GARFIELD                 |1      |
# |INGLEWOOD                |1      |
# |LINBROOK                 |1      |
# |HEMPHSTEAD               |1      |
# |MENEAPOLIS               |1      |
# |MONTICELLO               |1      |
# |PONOMA                   |1      |
# |POUND RIDGE              |1      |
# |PISCATAWAY               |1      |
# |AMHERST                  |1      |
# |GLENRIDGE                |1      |
# |INDIANA WELCH            |1      |
# |NEWPORT NEWS             |1      |
# |N. MERRICK               |1      |
# |MARGATE                  |1      |
# |RIVER EDGE               |1      |
# |COLUMBIA                 |1      |
# |SOMMERSVILLE             |1      |
# |LAWERENCE                |1      |
# |LOCUST                   |1      |
# |KNOXVILLE                |1      |
# |CLEVELAND                |1      |
# |STATEN ISLAD             |1      |
# |STOCKTON                 |1      |
# |BEDFORD                  |1      |
# |PEARL RIVER              |1      |
# |RIVERDALE                |1      |
# |DES-PLAINES              |1      |
# |MANY                     |1      |
# |ROACKWAY BEACH           |1      |
# |SAINT CHARLES            |1      |
# |MATAWAN                  |1      |
# |SALT LAKE CITY           |1      |
# |MERINO VALLEY            |1      |
# |BROX                     |1      |
# |YONKER                   |1      |
# |NEW JERSY                |1      |
# |HUNTINGTON BEACH         |1      |
# |FAR ROACKAWAY            |1      |
# |SAN DEIGO                |1      |
# |HARTSDALE                |1      |
# |CLINTONDALE              |1      |
# |TAYLOR                   |1      |
# |OLD BETH PAGE            |1      |
# |SIOUX FALL               |1      |
# |EAST HARTFORD            |1      |
# |COLLEGEPOINT             |1      |
# |CAMBRIDGE                |1      |
# |FAIRFIELD                |1      |
# |GRAY NECK                |1      |
# |YORKTOWN HEIGHTS         |1      |
# |New York                 |1      |
# |FOLSOM                   |1      |
# |STANDFORD                |1      |
# |CANOOGA PARK             |1      |
# |POMPANO BEACH            |1      |
# |SAN FRANCISCO            |1      |
# |CARLE   PL               |1      |
# |CARSON CITY              |1      |
# |SUMMIT                   |1      |
# |ELMUNT                   |1      |
# |WILLINGBORO              |1      |
# |WILKES BARRE             |1      |
# |NEW TOWN                 |1      |
# |VESTAL                   |1      |
# |BKLYN                    |1      |
# |WILLISTON PARK           |1      |
# |CRESSAILL                |1      |
# |HASBROUK HEIGHTS         |1      |
# +-------------------------+-------+

# %% [markdown]
# From the results above, we can see that there are 337,731 rows in the City column that contain null values.

# %% [markdown]
# ### Explore Address Type column

# %% [markdown]
# Another factor of Completeness that we should keep a look out for involves the Address Type Column. This Column is integral for figuring out what columns holds the location information we are looking for. For example, the address type "ADDRESS" Most likely corresponds with the Incident Address field.
#
# To figure out what Address Type corresponds to what location values, we would have to map out the amount of times non null values appeared in each column per different type. If there is a significant amount of data that appears when calling a certain address type, then that column most likely is associated with that type.
#
# Ideally, this Address Type Column should not be null, and if it is, then the columns that could hold information about the Address should also be null.
#
# If the Address Type Column is not NULL, then we should also be checking if the correct Address Columns are filled while the rest of the address columns are null.

# %%
# Show the distinct address types
df.select("Address Type").distinct().show(df.count(), False)
# Out:
# +------------+
# |Address Type|
# +------------+
# |INTERSECTION|
# |UNRECOGNIZED|
# |null        |
# |BLOCKFACE   |
# |LATLONG     |
# |ADDRESS     |
# |PLACENAME   |
# +------------+

# %%
from pyspark.sql.functions import desc

# Count how many rows of each address types there are
df.groupBy('Address Type').count().orderBy(desc("count")).show(df.count(), False)
# Out:
# +------------+-------+
# |Address Type|count  |
# +------------+-------+
# |ADDRESS     |3724266|
# |null        |853003 |
# |INTERSECTION|682565 |
# |BLOCKFACE   |115632 |
# |LATLONG     |36369  |
# |PLACENAME   |2098   |
# |UNRECOGNIZED|758    |
# +------------+-------+

# %%
# Check to see if Incident Addressing is associated with the ADDRESS type
df.filter((df["Address Type"] == "ADDRESS") & df["Incident Address"].isNotNull()).count()
# Out:
# 3610393

# %% [markdown]
# ## V. Outlier
#
# We describe an outlier as data that is significantly different from all other data in the dataset. To find potential outliers, we looked at the minimum and maximum dates in columns with timestamp types (i.e. "Created Date", "Closed Date", "Due Date", and "Resolution Action Updated Date"). We found outliers in three of the four columns with timestamp types.
#
# Run the following cells to explore the columns with timestamp types.

# %%
from pyspark.sql import Row
from pyspark.sql.functions import min, max

# %% [markdown]
# "Created Date" column seems to have the expected minimum and maximum values for dates in our 311 service dataset.

# %%
# View min and max dates for Created Date
df.select(min("Created Date"),max("Created Date")).show(df.count(), False)
# Out:
# +-------------------+-------------------+
# |min(Created Date)  |max(Created Date)  |
# +-------------------+-------------------+
# |2010-01-01 00:00:00|2021-11-13 02:10:18|
# +-------------------+-------------------+

# %% [markdown]
# "Closed Date", "Due Date", and "Resolution Action Updated Date" columns can be observed to have outlier dates that clearly should not exist in our dataset.

# %%
# View min and max dates for Closed Date
df.select(min("Closed Date"),max("Closed Date")).show(df.count(), False)
# Out:
# +-------------------+-------------------+
# |min(Closed Date)   |max(Closed Date)   |
# +-------------------+-------------------+
# |1899-12-31 19:00:00|2201-03-25 00:00:00|
# +-------------------+-------------------+

# %%
# View min and max dates for Due Date
df.select(min("Due Date"),max("Due Date")).show(df.count(), False)
# Out:
# +-------------------+-------------------+
# |min(Due Date)      |max(Due Date)      |
# +-------------------+-------------------+
# |1900-01-02 00:00:00|2021-12-12 13:43:56|
# +-------------------+-------------------+

# %%
# View min and max dates for Resolution Action Updated Date
df.select(min("Resolution Action Updated Date"),max("Resolution Action Updated Date")).show(df.count(), False)
# Out:
# +-----------------------------------+-----------------------------------+
# |min(Resolution Action Updated Date)|max(Resolution Action Updated Date)|
# +-----------------------------------+-----------------------------------+
# |2000-12-31 23:21:26                |2926-10-30 11:51:00                |
# +-----------------------------------+-----------------------------------+

# %% [markdown]
# ## Conclusion
#
# In this notebook, we explored different aspects of our dataset and uncovered problems with the dataset that needs to be cleaned and improved. The next step is actually trying to clean and create a new version of the dataset. The cleaning of the dataset is shown in the [Cleaning_The_Dataset.ipynb](https://colab.research.google.com/drive/1_EYqXb2oN889RPqRc8jwQaWygmpzKBiF?usp=sharing) notebook.
